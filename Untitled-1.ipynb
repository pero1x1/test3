# %%
print('test')

# %% [markdown]
# Клиент банка открыл вклад под 10 % годовых и положил на этот счёт Y рублей. Напишите программу, позволяющую определить, через сколько лет клиент будет иметь на счету сумму не менее Z рублей. На вход программа принимает два числа — Y, Z.
#
# В результате работы программа должна вывести на экран число лет, которое потребуется для накопления требуемой суммы. Ответ должен быть выведен на экран в виде целого числа без какого-либо дополнительного поясняющего текста.

# %%
year = 0 
Y = int(input())
Z = int(input()) 

while Y <= Z:
    Y *= 1.1
    year += 1

print(year)

# %% [markdown]
# Пассажирский лифт имеет ограничение на перевозку — не более 400 кг единовременно. Представим, что в лифт друг за другом заходят люди, имеющие одинаковый вес (weight), который поступает на вход программе. Программа должна следить за изменением нагрузки на лифт, сравнивая её с грузоподъёмностью, и в момент наступления перевеса выдавать предупреждение 'Перевес N кг'.
#
# Например, при перевесе в 15 кг должно быть выведено сообщение 'Перевес 15 кг'. Обратите внимание, что в эталонной фразе не используются знаки препинания.

# %%
weight = 52
n = 0 

while weight * n < 400:
    n += 1 
else:
    print(f'Перевес {weight*n - 400} кг')

# %% [markdown]
# Вы играете в компьютерную игру, дошли до схватки с финальным боссом, но вот беда: ваш компьютер «заглючил», и вы не можете управлять персонажем в игре. Босс атакует и каждую секунду наносит один удар, который отнимает у вашего персонажа 80 единиц здоровья. На схватку с боссом вы вышли с 500 единицами здоровья. Создайте цикл, позволяющий понять, через сколько секунд босс убьёт персонажа.
#
# В результате работы программа должна вывести на экран число секунд, в течение которых будет длиться схватка.
#
# Ответ должен быть выведен на экран в виде целого числа без какого-либо дополнительного поясняющего текста.
#
# Используйте переменную current_health для сохранения текущего уровня здоровья (изменяйте её по ходу цикла), а также переменную attack = 80 для хранения значения атаки Босса.

# %%
current_health = 500
attack = 80 
sec = 0 

while current_health >= 0:
    sec += 1
    current_health -= attack
else:
    print(sec)

# %% [markdown]
# На банковской карте хранится balance = 10 000 рублей. Владелец карты написал программу, в которую он вводит свои расходы spent, а программа после этого показывает баланс balance. Баланс выводится в виде целого числа без каких-либо дополнительных сообщений.
#
# Например, при остатке 3500 рублей на экран выводится число 3500. Когда сумма средств на карте становится ниже нуля, программа выводит сообщение 'Слишком большие расходы'.
#
# Напишите программу, которая выводит на экран начальный баланс карты (число 10000), баланс после каждого списания и сообщение 'Слишком большие расходы' при достижении отрицательного баланса.
#
# Переменная spent не должна меняться по ходу цикла. Переменная balance должна меняться после каждого шага цикла.

# %%
balance = 10000


if balance == 10000:
    print(balance)
while balance >= 3500:
    spent = int(input())
    balance -= spent 
    print(balance)
else:
    print('Слишком большие расходы')

# %% [markdown]
# Представьте, что перед вами большая цистерна объёмом 1000 литров, которую необходимо заполнить водой. У вас есть робот, который доставляет в цистерну сначала 5 литров, а затем каждый раз на 5 литров больше, чем в предыдущий. Изначально в цистерне нет воды. Через сколько заходов робота вода польётся через край?
#
# В результате работы программа должна вывести на экран число заходов, необходимых роботу для заполнения цистерны до краёв. Ответ должен быть выведен на экран в виде целого числа без какого-либо дополнительного поясняющего текста.
#
# Для проверки используйте переменную volume, равную свободному объёму в цистерне, и меняйте её по ходу цикла (на последнем шаге она должна быть меньше нуля).

# %%
volume = 0 
increment = 5
score = 0

while volume <= 1000:
    volume += increment 
    increment = increment + 5
    score += 1  

print(score)

# %%
volume = 1000
counter = 0
step = 0
while volume > 0:
    counter+=1
    step+=5
    volume = volume - step
else:
    print(counter)

# %%
n = int(input())

fib_1 = 1
fib_2 = 1
sum_fib = 0

if n == 0:
    print(0)
elif n <= 2:
    print(fib_1)
else:
    for i in range(3, n + 1):
        sum_fib = fib_1 + fib_2
        fib_1 = fib_2 
        fib_2 = sum_fib 
    print(sum_fib)

# %%
my_list = [5, 9, 19] 


for i in my_list:
    print(f'Элемент = {i}')

# %%
incomes = [120, 38.5, 40.5, 80]
sum = 0 


for i in incomes:
    sum += i 
    
print(sum)

# %% [markdown]
# Напишите программу, которая находит произведение элементов списка num_list. В качестве начального значения произведения задайте 1.
#
# Далее в цикле перебирайте элементы списка num_list и умножайте значение произведения на элемент списка.
#
# Результирующее произведение занесите в переменную p.
#
# Примеры работы программы:
#
#
# num_list = [98, 24, 23, 12, 3]
# ## p = 1947456
#
# num_list = [1, 10, 0.5, 21, 0.13]
# ## p = 13.65

# %%
p = 1 

num_list = [98, 24, 23, 12, 3]


for i in num_list:
    p *= i

print(p)

# %%
s = 0 
n = 5 

for i in range(1, n + 1):
    s += i 

print(s)

# %% [markdown]
# В математике факториал числа n — это произведение чисел от 1 до n включительно. Это записывается как:
#
# n! = 1 · 2 · 3 · ... · (n-1) · n
#
# Например:
#
# 3! = 1 · 2 · 3 = 6
#
# 5! = 1 · 2 · 3 · 4 · 5 = 120
#
# Факториал часто применяется в высшей математике, например в комбинаторике, теории вероятностей и дифференциальном исчислении.
#
# В переменной n хранится натуральное число. Напишите программу для вычисления факториала числа n. Результат запишите в переменную p.
#
# Пример работы программы:
#
#
# n = 3
# ## p = 6
# n = 5
# ## p = 120
# n = 10
# ## p = 3628800

# %%
p = 1

n = int(input())


for i in range(n, 1, -1):
    p *= i

print(p)

# %% [markdown]
# Напишите программу, которая будет печатать «лесенку» из символов '*' в зависимости от значения переменной n. Число n может быть любым натуральным числом (1, 2, 3…) и задаётся внешней программой при тестировании.
#
# Примеры работы программы:
#
#
# n = 3
# *
# **
# ***
#
# n = 4
# *
# **
# ***
# ****

# %%
n = int(input())

for i in range (1, n+1):
    print('*' * i)

# %%
weight_of_products= [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]


max_weight = 100


for i in weight_of_products:
    if i < max_weight:
        print('Легковая')
    else:
        print('Грузовая')

# %%
# Задаём список значений массы товаров
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15] 


# Задаём максимальное значение веса груза
max_weight = 100 
# Задаём начальный номер груза
num = 1 
# Создаём цикл по элементам списка со значениями массы товаров
# weight — текущее значение веса
for weight in weight_of_products: 
    # Если текущий вес меньше максимального,
    if weight < max_weight: 
        # выводим номер груза, его вес и отправляем его в легковую машину.
        print('Product {}, weight: {} -passenger car'.format(num, weight)) 
    else:
        # В противном случае
        # выводим номер груза, его вес и отправляем его в грузовую машину.
        print('Product {}, weight: {} -truck'.format(num, weight))
    # Увеличиваем значение номера груза на 1
    num += 1

# %%
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]  

max_weight = 100

num = 1 


for i in weight_of_products:
    if i < max_weight:
        print('Продукт {}, Вес: {} - легковая'.format(num, i))
    else:
        print('Продукт {}, Вес: {} - грузовая'.format(num, i))
    num += 1

# %%
weight_of_products = [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]  

max_weight = 100 
score = 0

for i in range(0, len(weight_of_products)):
    if weight_of_products[i] < 100:
        print('Продукт {}, Вес: {} - легковая'.format(i + 1, weight_of_products[i]))
    else:
        print('Продукт {}, Вес: {} - грузовая'.format(i + 1, weight_of_products[i]))

# %% [markdown]
# По эпидемиологическим причинам пользователь не может посетить места, которые находятся вне территории России. Наша задача — заменить заграничные места в списке places на значение 'Unavailable'.

# %%
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
] 

location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}


for i in places:
    country = location[i]
    if country != 'Russia':
        place = 'Unavailable' 


print(place)

# %%
# Список мест, которые хотим посетить.
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
# Словарь соответствия мест и стран
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}
# Создаём цикл по списку мест, которые хотим посетить.
# place — текущее название места
for place in places: 
    # Получаем страну из словаря location по ключу
    country = location[place] 
    # Сравниваем название страны
    if country != 'Russia': 
        # Помечаем место как недоступное
        place = 'Unavailable' 
# Выводим результирующий список
print(places)


## Будет выведено:
## ['Red Square', 'Swallow Nest', 'Niagara Falls', 'Grand Canyon', 'Louvre', 'Hermitage']

# %%
# Список мест, которые хотим посетить.
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
# Словарь соответствия мест и стран
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}
flag = 0
for i in places:
    if location[i] != 'Russia':
        places[flag] = 'Unavailable'
    flag += 1

places

# %%
# Список мест, которые хотим посетить.
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]
# Словарь соответствия мест и стран
location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
} 


for i in range(len(places)):
    if location[places[i]] != 'Russia':
        places[i] = 'Unavailable'

print(places)

# %% [markdown]
# Вам задан список num_list, состоящий из чисел (int и float) например:
#
#
# num_list = [1, 10, 3, -5].
# Отсортируйте его с помощью метода sort() для списков, а затем последовательно выведите на экран элементы этого списка с помощью цикла for в следующем формате: "element {i}: {elem}", где i - индекс элемента в списке, elem - элемент.
#
# Пример работы программы:
#
#
# num_list = [1, 10, 3, -5]
# ## element 0: -5
# ## element 1: 1
# ## element 2: 3
# ## element 3: 10

# %%
num_list = [1, 10, 3, -5] 
num_list.sort()
x = len(num_list)

for i in range(x):
    print(f'element {i}: {num_list[i]}')

# %% [markdown]
# Дан список num_list, состоящий из целых чисел (int). Например:
#
#
# num_list = list(range(0, 100, 3))
# С помощью цикла for посчитайте количество чётных элементов в списке. Результат запишите в переменную count_even.
#
# Примеры работы программы:
#
#
# num_list = list(range(0, 100, 3))
# ## count_even = 17
#
# num_list = [10, 4, 4, 21, 2, 0, -10]
# ## count_even = 6
#
# num_list = list(range(0, 81, 5))
# ## count_even = 9

# %%
num_list = list(range(0, 81, 5))

count_even = 0 
for i in num_list:
    if i % 2 == 0:
        count_even += 1

print (count_even)

# %% [markdown]
# Дан список mixture_list, элементами которого могут являться любые типы данных Python. Например:
#
#
# mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']
# С помощью цикла for посчитайте количество элементов типа str в списке. Результат запишите в переменную count_str.
#
# Примеры работы программы:
#
#
# mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']
# ## count_str = 3
#
# mixture_list = ['My', 'Simple', -10, True, 'False', 'string_1', False, 2.5, [1, 2], 'True']
# ## count_str = 5

# %%
mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']  
count_str = 0

for i in mixture_list:
    if type(i) is str:
        count_str += 1
        


print(count_str)

# %% [markdown]
# Мы генерируем текст с помощью нейронной сети. В списке word_list в виде строк задана сгенерированная нейронной сетью последовательность слов. Например:
#
#
# word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]
# Напишите программу для объединения строк из списка word_list в предложения.
#
# Гарантируется, что конец каждого предложения обозначается специальной последовательностью символов — "EOS" (End Of Sentence). Вместо этого символа в предложении ставится точка — ".". Для простоты условимся, что другие знаки препинания (запятые, восклицательные знаки и т. д.) нейронная сеть генерировать не умеет.
#
# Для решения задачи воспользуйтесь циклом for. Результирующий текст запишите в переменную text.
#
# Примеры работы программы:
#
#
# word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]
# ## text = "My name is Sergei. I'm from Moscow."
#
# word_list = ["Человек", "он", "умный", "EOS", "Но", "чтоб", "умно", "поступать", "одного", "ума", "мало", "EOS"]
# ## "Человек он умный. Но чтоб умно поступать одного ума мало."

# %%
word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"] 

for i in range(len(word_list)):
    if word_list[i] != 'EOS':
        text = word_list[i]
        print(text, end = ' ')
    else:
        word_list[i] = '.'
        print(word_list[i].rstrip(), end = '')

# %%
word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]  


result = []


for i in word_list:
    if i == 'EOS':
        result.append('.')
    else:
        result.append(i)




text = " ".join(result).replace(" .", ".")


print(text)

# %%
age = 25
print("Age:", age, 'years')

# %%
a = 3.14 

type(a)

# %% [markdown]
# a / b = q (r)
#
# a = b * q
#
# b = q * a

# %%
a = - 5 
b = 2 

q = a // b 
print(q)

r = a % b 
print(r)

# %%
a = -5 
b = 2 


a // b = -5 // 2  получаем в целом при обычном делении -2.5 округляем до меньшего целого числа а -1 больше поэтому -3 

и получаем что a = b * q + r = 2 * -3 + ? => 1

# %%
11 и 4  // = 2; % = 3 

- 11 и 4  // = -3; % = 1 

11 и -4  // = -3; % = -1 

- 11 и -4  // = 2; % = -3 

13 и 5   // = 2; % = 3 
-13 и 5  // = -3; % = 2
13 и -5  // = -3; % = - 2
-13 и -5 // = 2; % = - 3 


-112 и 11; // = -11; % = 9

# %% [markdown]
# -37 и 6 = -7; 5;
# 37 и -6 = -7; -5;
# -37 и -6 = 6; -1
# -95 и 8
# 95 и -8
# -95 и -8
# -41 и 9
# 41 и -9

# %% [markdown]
# -95 и 8 = -12; 1
# 95 и -8 = -12; -1
# -95 и -8 = 11; -7
# -41 и 9 = -5; 4
# 41 и - 9 = -5; -4

# %% [markdown]
# print ((31 % 2) + (-31 % 2))

# %% [markdown]
# print (13 % -3 * 3 - 3**2)
#
# -2 * 3 (-6)   -  9  - 15

# %%
x = 11 * 2.5 / 3 

print(round(11 * 2.5 / 3, 2))

# %%
pi = 3.14159 

print(round((pi**2)/2))

# %%
print(1.57 * 3/1.5)

# %%
print(3**3-3*(6*3 - 4.5 * 2))

# %%
s = "Hello!" 

print(s[::-1])

print(s[-1])

print(s[-5:-1])

# %%
new_string = "Perfect" 

new_string[1:]
new_string[::2]
new_string[-1]

# %%
Напишите программу, которая выводит построчно каждое число из строки numbers.

# %%
Напишите программу, которая выводит построчно каждое число из строки numbers.
fsa

# %% [markdown]
# Задана переменная numbers, которая ссылается на некоторую строку, состоящую из чисел и пробелов. Пример такой строки:
#
# numbers = '1 2 3 4 5 6 7'
#
# Напишите программу, которая выводит построчно каждое число из строки numbers.

# %%
numbers = '1 2 3 4 5 6 7' 

numbers_split = numbers.split(' ')

print(' and '.join(numbers_split))

# %% [markdown]
# Пусть информация о пользователе нашего фитнес-приложения содержится в следующих переменных:
#
# name — имя пользователя;
# dayofweek — название дня недели.
# Пример таких переменных:
#
#
# name = 'John'
# dayofweek = 'Friday'
# Напишите программу, которая выводит на экран фразу в формате:
#
# Hello, <name>! Today is <dayofweek>. Have a nice day!,
#
# где вместо <name> и <dayofweek> подставляются значения соответствующих переменных.
#
# # Входные данные:
# name = 'John'
# dayofweek = 'Friday'
#
# # Вывод программы:
# Hello, John! Today is Friday. Have a nice day!
#
#
# # Входные данные:
# name = 'Andrey'
# dayofweek = 'Sunday'
#
# # Вывод программы:
# Hello, Andrey! Today is Sunday. Have a nice day!
#
# Обязательное условие: задача должна быть решена с использованием метода format.

# %%
name = 'John'
dayofweek = 'Friday'

print('Hello, {}! Today is {}. Have a nice day!'.format(name, dayofweek))

# %% [markdown]
# В резюме соискатели указывают желаемую заработную плату. Пусть информация о ней находится в переменной salary в формате: '<заработная плата>  руб.'
#
# Гарантируется, что структура текста не изменяется. Примеры возможных значений переменной:
#
#
# salary = '29000 руб.'
# salary = '35000 руб.'
# salary = '128500 руб.'
# Ваша задача — превратить строку с заработной платой и указанием валюты в численное представление заработной платы. Напишите программу, которая выполняет следующие действия:
#
# разделяет строку salary на части (символ по которому стоит производить разбиение выберите самостоятельно);
# сохраняет в переменную salary_number значение заработной платы, выраженной в тысячах рублей.
# Например, если переменная salary задана следующим образом: salary = '128500 руб.', то в переменной salary_number должно содержаться число 128.5.
#
# Примеры работы программы:
#
#
# # Входные данные
# salary = '29000 руб.'
#
# # Значение переменной:
# # salary_number = 29.0
#
# # Входные данные
# salary = '128500 руб.'
#
# # Значение переменной:
# # salary_number = 128.5
# При решении обратите внимание на имена переменных и их типы данных: они должны соответствовать условию задачи, чтобы тестирование кода произошло корректным образом. Прежде чем отправить решение на проверку, самостоятельно проверьте работу вашей программы, сравнив результат с ожидаемым для приведённого в задании примера. Протестируйте программу при других значениях переменной salary, приведённых в описании задания.

# %%
salary = '29000  руб.'

salary_split = salary.split()

salary_float = float(salary_split[0])/1000

print(salary_float)

# %% [markdown]
# Теперь разберёмся с опытом работы.
#
# Пусть текст с описанием опыта работы хранится в переменной experience и строится по такому шаблону: 'Work experience <количество месяцев> months'
#
# Гарантируется, что структура текста не изменяется. Примеры возможных значений переменной:
#
#
# experience = 'Work experience 202 months'
# experience = 'Work experience 60 months'
# experience = 'Work experience 3 months'
# Ваша задача — разделить информацию об опыте работы на составляющие: количество полных лет опыта работы и количество месяцев опыта работы.
#
# Напишите программу, которая выполняет следующие действия:
#
# разделяет строку experience на части (символ, по которому стоит производить разбиение выберите самостоятельно);
# сохраняет в переменную experience_year информацию о количестве полных лет опыта работы;
# сохраняет в переменную experience_month информацию о количестве месяцев работы (в неполном году).
# Например, если переменная experience задана следующим образом: experience = 'Work experience 202 months', то в переменных experience_year и experience_month должны содержаться целые числа 16 и 10 (из расчёта 16 * 12 + 10 = 202).
#
# Примеры работы программы:
#
#
# # Входные данные
# experience = 'Work experience 202 months'
#
# # Значения переменных:
# # experience_year = 16
# # experience_month = 10
#
# # Входные данные
# experience = 'Work experience 60 months'
#
# # Значения переменных:
# # experience_year = 5
# # experience_month = 0
# При решении обратите внимание на имена переменных и их типы данных: они должны соответствовать условию задачи, чтобы тестирование кода произошло корректным образом. Прежде чем отправить решение на проверку, самостоятельно проверьте работу вашей программы, сравнив результат с ожидаемым для приведённого в задании примера. Протестируйте программу при других значениях переменной experience, приведённых в описании задания.

# %%
experience = 'Work experience 60 months' 
experience_split = experience.split()

experience_year = int(experience_split[2]) // 12
experience_month = int(experience_split[2]) % 12

print(f'experience_year = {experience_year}\nexperience_month = {experience_month}')

# %% [markdown]
# В каждом резюме обязательно заполняется графа «пол, возраст». Пусть информация о поле и возрасте хранится в переменной description и строится по такому шаблону (обратите внимание на пробелы слева и справа от запятой): '<Пол> , <возраст> year old , born on <дата рождения> , <год рождения>.'
#
# Гарантируется, что структура текста не изменяется. Примеры возможных значений переменной:
#
# description = 'Male , 39 years old , born on November 27 , 1979'
# description = 'Woman , 36 years old , born on August 12 , 1982'
# description = 'Male , 38 years old , born on June 25 , 1980'
# Ваша задача — разделить информацию о поле и возрасте соискателя на компоненты. Напишите программу, которая выполняет следующие действия:
#
# Разделяет строку description на части по символу ' , ' и сохраняет результат в переменную description_split; (Обратите внимание: пробелы перед и после запятой обязательны)
# Сохраняет в переменную gender информацию о поле соискателя (приведённое к нижнему регистру);
# Сохраняет в переменную age информацию о том, сколько полных лет соискателю;
# Сохраняет в переменную year_of_birth информацию о годе рождения соискателя.
# Например, если переменная example задана следующим образом: example = 'Male , 39 years old , born on November 27 , 1979', то в переменных gender, age и year_of_birth должны содержаться строки 'male', '39' и '1979' соответственно.
#
# Примеры работы программы:
#
#
# # Входные данные
# description = 'Male , 39 years old , born on November 27 , 1979'
#
# # Значения переменных:
# # gender = 'male'
# # age = '39'
# # year_of_birth = '1979'
#
# # Входные данные
# description = 'Woman , 36 years old , born on August 12 , 1982'
#
# # Значения переменных:
# # gender = 'woman'
# # age = '36'
# # year_of_birth = '1982'
# При решении обратите внимание на имена переменных и их типы данных: они должны соответствовать условию задачи, чтобы тестирование кода произошло корректным образом. Прежде чем отправить решение на проверку, самостоятельно проверьте работу вашей программы, сравнив результат с ожидаемым для приведённого в задании примера. Протестируйте программу при других значениях переменной description, приведённых в описании задания.

# %%
description = 'Male , 39 years old , born on November 27 , 1979' 
description_split = description.split(' , ') 

test = description_split[2]
 
print(test.split()[3])

# %%
description = 'Male , 39 years old , born on November 27 , 1979' 
description_split = description.split(' , ') 

test = description_split[2]


print(f'gender = {description_split[0]}\nage = {test.split()[3]}\nyear_of_birth = {description_split[3]}')

# %%
description_split = description.split(' , ') 

test = description_split[1]

gender = description_split[0].lower()
age = test.split()[0]
year_of_birth = description_split[3]

# %%
test = list()

print(test)

# %%
test = list(range(1, 10, 2))

# %%
print(test)

# %%
my_list = []

# %%
empty_list = list()

print(empty_list)

# %%
another_empty_list = []

# %%
print(another_empty_list)

# %%
a = range(-10, 100)

# %%
print(a)

# %%
li

# %%
a = list(range(-10, 100))

# %%
b = list(range(50, 20, -2))

print(list(b))

# %%
a = ["a", "b", "c"] 


a[0]

a[::-1]


a[0:2]

a[2]

# %%
a = list(range(-5, 5))

a[4:9]

# %%
b = list(range(-3, 6))
print(b[::-1])

# %%
a = list(range(-3,7))
# OR a = [-3, -2, -1, 0, 1, 2|, 3, 4, 5, 6]
print(a[::-1])

# %%
word = 'hello kitty' 

x = word.split()

x[-2:]

# %% [markdown]
# Задание 2.12
# 1 point possible (ungraded)
# Старайтесь выполнить задание самостоятельно. Но также у вас есть возможность увидеть решение, введя в поле ниже «хочу увидеть ответ» (без кавычек). В этом случае задание будет зачтено как выполненное некорректно.
#
# Создайте три переменные: a, b, c.
# Положите в них следующие строковые значения: 'order1', 'order2', 'order3'.
# Создайте пустой список orders, используя квадратные скобки.
# Последовательно положите все три созданные переменные в список.
# Выведите значение получившегося списка на экран с помощью фукнции print(). В качестве ответа запишите результат вывода.

# %%
a, b, c = 'order1', 'order2', 'order3'

order = []

order.append(a)
order.append(b)
order.append(c)

print(order)

# %% [markdown]
# Задание 2.13
# 1 point possible (ungraded)
# Старайтесь выполнить задание самостоятельно. Но также у вас есть возможность увидеть решение, введя в поле ниже «хочу увидеть ответ» (без кавычек). В этом случае задание будет зачтено как выполненное некорректно.
#
# Создайте две переменные: book1, book2.
# Положите в них следующие строковые значения: 'my book', 'your book'.
# Создайте список books, используя квадратные скобки. В нём уже должно лежать значение 'all_books'.
# Последовательно положите две созданные переменные в список.

# %%
book1, book2 = 'my book', 'your book'

books = ['all_books']

books.append(book1)
books.append(book2)

print(books)

# %%
letters = ['a','b','c','d','e']

letters.clear()

print(letters)

# %%
numbers = [5, 1, 7, 5, 3, 9, 1, 4, 5, 8]

print(numbers.count(5))

# %% [markdown]
# Создайте список my_books из пяти элементов: 'book1', 'book2', 'book3', 'book4', 'book5'. Затем используйте метод .copy() для копирования содержимого вашего списка в список tom_books. Выведите два полученных списка. В качестве ответа запишите результат вывода.

# %%
my_books = ['book1', 'book2', 'book3', 'book4', 'book5']

tom_books = my_books.copy()

# %%
print(tom_books)

# %%
my_books = ['book1', 'book2', 'book3', 'book4', 'book5'] 

tom_books = my_books[:]

# %%
print(tom_books)

# %%
my_orders = ['order1', 'order2', 'order3', 'order4', 'order5']
anne_orders = my_orders[:]
print(my_orders, anne_orders)

# %%
all_things = ['order1', 'order2', 'order3']
only_books = ['book1', 'book2']

all_things.extend(only_books)

# %%
print(all_things)

# %%
nums = list(range(1, 11))
test = nums[::-1]
print(test)

# %% [markdown]
# .append()
# .clear()
# .copy() тоже через срез [:] и просто
# .extend()
# .reverse() два варика обычный и через срез
# .sort()

# %%
random_values = [3, 5, 0, -1, 2, 10, 15, -5]

random_values.sort()

print(random_values)

# %%
list1 = []

list1.append(5)
list1.append(0.2)
list1.append('hello there')
list1.append([1,2,3,4])
list1.append('bye')

# %%
print(list1)

# %%
s1 = {}

type(s1)

# %%
s2 = {5, 10, 3, 2, 11}

print(

# %%
s3 = set('wow thats cool')

# %%
s3

# %% [markdown]
# Создайте множество s1 из первых пяти строчных букв английского языка. Затем с помощью метода .add() добавьте новый элемент со значением 'hello'. Выведите результат.
# В качестве ответа запишите результат вывод

# %%
s1 = {'a','b','c','d','e'}
s1.add('hello')

s1

# %%
s = {1, 2}
s.update([3, 4], {5, 6}, (7, 8))
print(s)

# %% [markdown]
# Создайте множество s1 из первых пяти строчных букв английского языка. Затем с помощью метода .remove() удалите элемент 'd'. Выведите s1.
# В качестве ответа запишите результат вывода.

# %%
s1 = {'a','b','c','d','e','f'} 

s1.remove('f')

s1

# %% [markdown]
# Создайте множество alpha_set из первых пяти строчных букв английского алфавита. Затем создайте множество name из строки 'bad boy' (преобразуйте строку в множество с помощью функции set()). Примените метод .union() к созданным множествам. Выведите результат.
# В качестве ответа запишите результат вывода.

# %%
alpha_set = {'a', 'b', 'c', 'd', 'e'}
name = set('bad boy')

# %%
print(alpha_set)
print(name)

# %%
alpha_set.union(name)

# %% [markdown]
# Создайте множество num_set из чисел от 0 до 10 (включительно). Затем создайте множество date_num из списка [1,9,4,8]. Примените метод .union() к созданным множествам. Выведите результат. В качестве ответа запишите результат вывода.

# %%
num_set = set(range(11))
date_num = set([1,9,4,8])


num_set.union(date_num)

# %% [markdown]
# Создайте множество alpha_set из первых пяти букв английского алфавита. Затем создайте множество name из строки 'bad boy'. Примените метод .intersection() к созданным множествам. Выведите результат.
# В качестве ответа запишите результат вывода.

# %%
alpha_set = set('abcde')

name = set('bad boy')

alpha_set.intersection(name)

# %% [markdown]
# Создайте множество num_set из чисел от 0 до 10 (включительно). Затем создайте множество date_num из списка [1,9,4,8]. Примените метод .intersection() к созданным множествам. Выведите результат. В качестве ответа запишите результат вывода.
# 1

# %%
num_set = set(range(11))
date_num = set([1,9,4,8])

# %%
num_set

# %%
date_num

# %%
num_set.intersection(date_num)

# %% [markdown]
# Создайте множество alpha_set из первых пяти букв английского алфавита. Затем создайте множество name из строки 'bad boy'. Примените метод .difference() к созданным множествам. В качестве базового множества используйте alpha_set. Выведите результат.
# В качестве ответа запишите результат вывода.

# %%
alpha_set = set('abcde')
name = set('bad boy')

alpha_set.difference(name)

# %%
num_set = set(range(11))
date_num = set([1,9,4,8])  

num_set.difference(date_num)

# %%
a = 3
b = float(a)

# %%
num1 = 3
num2 = 3.5 
sum1 = num1 + num2 
float(num1)
sum2 = num1 + num2 
print(sum1, sum2)

# %%
int_one = 1 
str_one = str(int_one)
print(str_one)

# %%
str_age_begin = 'my age is '
int_age = 18 
result_string = str_age_begin + str(int_age)
print(result_string)

# %% [markdown]
# Создайте список list1 из цифр от 1 до 5 (включительно). Преобразуйте список в кортеж tpl1 с помощью конструктора типов tuple(). Выведите результат. В качестве ответа запишите результат вывода.

# %%
list1 = list(range(1, 6)) 

tpl1 = tuple(list1)
tpl1

# %%
tpl1

# %% [markdown]
# Создайте кортеж tpl1 из первых пяти букв английского языка. Преобразуйте кортеж в список list2 с помощью конструктора типов list(). Выведите результат. В качестве ответа запишите результат вывода.

# %%
tpl_set = set('abcde') 

list_set = list(tpl_set)

list_set.sort()

x = tuple(list_set)

list2 = list(x)


print(list2)

# %%
list1 = list()

list1.append(1)
list1.append(2)
list1.append(3)

# %%
list1

# %%
list2 = list(range(-5, 15, 2))
list3 = list(range(1, 5))

list3.extend(list2)

# %%
list3

# %%
list6 = [3, 1, -10, 5, 11, 20, 1, -10]
list7 = [3, 1, -10, 5, 11, 20, 1, -10]

list6.sort()

list_result = list6

# %%
print(list7, list_result)

# %% [markdown]
# Создайте список list1. Положите в него два значения: 10, 15.
# Преобразуйте список в кортеж и сохраните результат в tpl1.
# Создайте словарь dict1.
# По ключу, который соответствует кортежу tpl1, положите значение 'hello'.
# Выведите полученный словарь dict1.
# В качестве ответа запишите результат вывода.

# %%
list1 = (10, 15)
tpl1 = tuple(list1)

dict1 = {}

dict1[tpl1] = 'hello' 

dict1

# %% [markdown]
# Создайте два словаря: dict1 и dict2. Положите в первый словарь по ключу 'name' значение 'unknown', а во второй по ключу 'name' положите значение 'Tom'.
# Выведите dict1 и dict2.
# Выведите ключи и значения из dict1. Для этого используйте методы dict.keys() и dict.values().

# %%
dict1 = {}
dict2 = {}

dict1['name'] = 'unknown'
dict2['name'] = 'Tom'
print(dict1.keys(), dict1.values())

# %%
dict1 = {'name': 'unknown'} 
# or dict1 = dict(name='unknown')
dict2 = {'name': 'Tom'} 
# or dict2 = dict(name='Tom')
print(dict1, dict2, dict1.keys(), dict1.values())

# %%
s1 = set('hello')
s2 = set(['w', 'o', 'w'])

print(s1.union(s2), s1.intersection(s2), s1.difference(s2))

# %% [markdown]
# Выведите переменную result, которая является сложением строки 'age is ' (в конце строки есть пробел) и числа 15. Воспользуйтесь преобразованием типов. В качестве ответа запишите результат вывода.

# %%
result = 'age is ' + str(15)
print(result)

# %%
s = 'A string with white space' 

''.join(s.split())

# %%
s = 'A string with white space'  

s.replace(' ', '')

# %%
# Создаём 3 переменные, в которых содержится прибыль за 3 года
income_2019 = 15
income_2020 = 16.5
income_2021 = 16.5

# %%
print(income_2019 == income_2020)
print(income_2020 == income_2021)

# %%
ord('а')

# %% [markdown]
# Напишите условие, которое проверяет, является ли строка палиндромом.
#
# Палиндром читается одинаково слева направо и справа налево. Например: "шалаш", "казак", "мадам", "коту тащат уток".
#
# Строка, которую мы хотим проверить, находится в переменной target_string.
#
# Важно: Обратите внимание, что результат работы программы не должен зависеть от пробелов, а также регистра символов, поэтому алгоритм решения задачи будет следующим:
#
# привести строку к нижнему (или верхнему) регистру (это можно сделать с помощью методов lower() и upper())
#
# убрать из нее все пробелы (это можно сделать с помощью метода replace(), передав в него первым аргументом символ пробела ' ', а вторым аргументом символ пустой строки — '')
#
# проверить равенство полученной строки с её развернутым аналогом (развернуть строку можно с помощью срезов с отрицательным шагом — target_string[::-1])
#
# Результатом работы условия должно стать булево значение — True или False, в зависимости от того, является ли строка палиндромом. Занесите этот результат в переменную result.
#
# Примеры работы программы:
#
#
# target_string = 'коту тащат уток'
# # result = True
#
# target_string = 'Шалаш'
# # result = True
#
# target_string = 'кота тащат в шалаш'
# # result = False

# %%
target_string = "Казак" 

x = target_string.replace(' ', '') 

y = x.lower()

z = x[::-1].lower()

print(x == z)

# %%
print (y)

# %%
target_string = "Казак"  

result = target_string.replace(' ', '').lower() == target_string[::-1].lower()

print(result)

# %%
diagnosis_1 = 'no'
diagnosis_2 = 'no'
diagnosis_3 = 'no'

result = 'yes' in [diagnosis_1, diagnosis_2, diagnosis_3] 
print(result)

# %% [markdown]
# Задача №1
#
# Условие задачи:
#
# Пусть задан словарь покупок за период с 10 по 12 октября 2022 года. Ключами этого словаря являются даты, а значениями — списки с идентификаторами заказов, поступивших в этот день:
#
# orders = {
#     '2022-10-10': ['F124', 'D89D', '142L'],
#     '2022-10-11': ['H241', 'OR24', 'BE14', '348F'],
#     '2022-10-12': ['H429', 'JAS2']
# }
# Необходимо узнать, поступал ли за указанный период заказ с идентификатором 'BE14'.

# %%
orders = {
    '2022-10-10': ['F124', 'D89D', '142L'],
    '2022-10-11': ['H241', 'OR24', 'BE14', '348F'],
    '2022-10-12': ['H429', 'JAS2']
} 


result = 'BE14' in orders['2022-10-10'] or 'BE14' in orders['2022-10-11'] or 'BE14' in orders['2022-10-12']

print(result)

# %% [markdown]
# Задача №2
#
# Условие задачи:
#
# Окунёмся в мир криптографии и шифрования.
#
# Представим, что мы обмениваемся секретными сообщениями, составленными только из определённых слов. Каждое из ключевых слов в сообщении кодируется одним или несколькими числами.
#
# В результате шифрования сообщения получается одно большое число, которое мы и передаём через специальные средства связи. На этапе приёма сообщения число попадает в переменную message. Пример сообщения:
#
# message = 14093530013530593
# Чтобы усилить систему шифрования, мы, помимо сообщений, которые несут полезную информацию, обмениваемся и случайно сгенерированными сообщениями.
#
# Известно, что «шумовое» сообщение отличается от обычного тем, что в нём в первых шести цифрах обязательно должна содержаться цифра 5.
#
# Реализуем условие, которое проверит, несёт ли полезную информацию присланное сообщение.

# %%
message = 14093530013530593 

print('5' in str(message)[:5])

# %% [markdown]
# Шахматная фигура передвигается по доске 8x8 клеток. Нумерация клеток по горизонтальной ведётся с помощью первых 8 латинских букв, а по вертикальной — с помощью цифр от 1 до 8.
#
#
#
# Координатам по горизонтальной и вертикальной осям шахматной доски, в которые должна переместиться фигура, соответствуют переменные x и y:
#
#
# x, y = 'F', 7
# Напишите условие проверки корректности хода. Ход считается корректным, если новые координаты фигуры не выходят за пределы шахматной доски.
#
# Результат работы условия присвойте переменной move_is_correct, в которой должно содержаться значение True или False в зависимости от того, является ли ход корректным.
#
# Примеры работы программы:
#
#
# x, y = 'F', 7
# # move_is_correct = True
#
# x, y = 'K', 1
# # move_is_correct = False

# %%
x, y = 'K', 7 

move_is_correct = x in 'ABCDEFGH' and str(y) in '12345678'

print(move_is_correct)

# %% [markdown]
# Задача №3
#
# Условие задачи:
#
# В одной упаковке карандашей содержится 13 карандашей. Количество упаковок в наличии на складе хранится в переменной available_packages. Количество произведённых карандашей хранится в переменной total_count.
#
# Необходимо реализовать условие, которое проверяет, удастся ли распределить все карандаши по упаковкам без остатка и хватит ли упаковок вообще.
#
# Пример значений переменных:
#
# available_packages = 105
# total_count = 1677

# %%
available_packages = 105
total_count = 1677

# %%
105 * 13

# %% [markdown]
# Дано n-значное целое число N. Реализуйте условие для проверки того, начинается ли число N с четной цифры.
#
# Результатом работы условия должно стать булево значение True или False. Занесите этот результат в переменную first_is_even.
#
# *Примеры работы программы:
#
#
# N = 782
# # first_is_even = False
# N = 45901
# # first_is_even = True
# Подсказка: Преобразуйте число N в тип данных str, извлеките первый символ, а затем преобразуйте его в целое число int. Проверьте, что полученное число делится на 2 без остатка.

# %%
N = 882
first_is_even = int(str(N)[:1]) % 2 == 0
print(first_is_even)

# %% [markdown]
# Напишите условие, которое проверяет, что год является високосным.
#
# Известно, что год является високосным при выполнении хотя бы одного из следующих условий:
#
# Номер года делится (без остатка) на 400.
# Номер года делится (без остатка) на 4 и не делится на 100 одновременно.
# Номер года находится в переменной year.
#
# Результат выполнения условия занесите в переменную year_is_leap. Её значение должно быть равно True или False, в зависимости от того, является ли заданный год високосным.
#
# Примеры работы программы:
#
#
# year = 2000
# # year_is_leap = True
#
# year = 1900
# # year_is_leap = False
#
# year = 2015
# # year_is_leap = False

# %%
year = 2000


year_is_leap = year % 400 == 0 or (year % 4 == 0 and year % 100 != 0 )

print(year_is_leap)

# %%
2000 % 100

# %% [markdown]
# Задача №1
#
# Условие задачи:
#
# Пусть задан словарь покупок за период с 10 по 12 октября 2022 года. Ключами этого словаря являются даты, а значениями — списки с идентификаторами заказов, поступивших в этот день:
#
# orders = {
#     '2022-10-10': ['F124', 'D89D', '142L'],
#     '2022-10-11': ['H241', 'OR24', 'BE14', '348F'],
#     '2022-10-12': ['H429', 'JAS2']
# }
# Необходимо узнать, поступал ли за указанный период заказ с идентификатором 'BE14'.

# %%
orders = {
    '2022-10-10': ['F124', 'D89D', '142L'],
    '2022-10-11': ['H241', 'OR24', 'BE14', '348F'],
    '2022-10-12': ['H429', 'JAS2']
}

print('BE14' in orders['2022-10-11'])

# %% [markdown]
# Задача №2
#
# Условие задачи:
#
# Окунёмся в мир криптографии и шифрования.
#
# Представим, что мы обмениваемся секретными сообщениями, составленными только из определённых слов. Каждое из ключевых слов в сообщении кодируется одним или несколькими числами.
#
# В результате шифрования сообщения получается одно большое число, которое мы и передаём через специальные средства связи. На этапе приёма сообщения число попадает в переменную message. Пример сообщения:
#
# message = 14093530013530593
# Чтобы усилить систему шифрования, мы, помимо сообщений, которые несут полезную информацию, обмениваемся и случайно сгенерированными сообщениями.
#
# Известно, что «шумовое» сообщение отличается от обычного тем, что в нём в первых шести цифрах обязательно должна содержаться цифра 5.
#
# Реализуем условие, которое проверит, несёт ли полезную информацию присланное сообщение.

# %%
message = 14093530013530593 

'5' in str(message)[:6]

# %% [markdown]
# Дано n-значное целое число N. Напишите условие для проверки того, входят ли в заданное число цифры 3 и 7.
#
# Результатом выполнения условия должно стать значение True или False. Занесите этот результат в переменную contains.
#
# Примеры работы программы:
#
#
# N = 12043879584
# # contains = True
#
# N = 59005085801
# # contains = False
# Примечание: Для отправки кода на проверку переменную N объявлять не нужно. Не забудьте удалить строку кода с ее объявлением перед отправкой на тестирование.

# %%
N = 12043879584

contains = (('3' in str(N)) and ('7' in str(N)))

print(contains)

# %% [markdown]
#  Шахматная фигура передвигается по доске 8x8 клеток. Нумерация клеток по горизонтальной ведётся с помощью первых 8 латинских букв, а по вертикальной — с помощью цифр от 1 до 8.
#
#
#
# Координатам по горизонтальной и вертикальной осям шахматной доски, в которые должна переместиться фигура, соответствуют переменные x и y:
#
#
# x, y = 'F', 7
# Напишите условие проверки корректности хода. Ход считается корректным, если новые координаты фигуры не выходят за пределы шахматной доски.
#
# Результат работы условия присвойте переменной move_is_correct, в которой должно содержаться значение True или False в зависимости от того, является ли ход корректным.
#
# Примеры работы программы:
#
#
# x, y = 'F', 7
# # move_is_correct = True
#
# x, y = 'K', 1
# # move_is_correct = False

# %%
x, y = 'F', 9 

move_is_correct = x in 'ABCDEFGH' and str(y) in '12345678'

# %%
print(move_is_correct)

# %%
x_step = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

x, y = 'F', 8

y_step = list(range(1, 9))

move_is_correct = x in x_step and y in y_step

print(move_is_correct)

# %% [markdown]
# Задача №3
#
# Условие задачи:
#
# В одной упаковке карандашей содержится 13 карандашей. Количество упаковок в наличии на складе хранится в переменной available_packages. Количество произведённых карандашей хранится в переменной total_count.
#
# Необходимо реализовать условие, которое проверяет, удастся ли распределить все карандаши по упаковкам без остатка и хватит ли упаковок вообще.
#
# Пример значений переменных:
#
# available_packages = 105
# total_count = 1677

# %%
available_packages = 105
total_count = 1677 
result = total_count % 13 == 0 and total_count // 13 <= available_packages

print(result)

# %% [markdown]
# Дано n-значное целое число N. Реализуйте условие для проверки того, начинается ли число N с четной цифры.
#
# Результатом работы условия должно стать булево значение True или False. Занесите этот результат в переменную first_is_even.
#
# *Примеры работы программы:
#
#
# N = 782
# # first_is_even = False
# N = 45901
# # first_is_even = True
# Подсказка: Преобразуйте число N в тип данных str, извлеките первый символ, а затем преобразуйте его в целое число int. Проверьте, что полученное число делится на 2 без остатка.

# %%
N = 782

first_is_even = int(str(N)[:1]) % 2 == 0
print(first_is_even)

# %% [markdown]
# Напишите условие, которое проверяет, что год является високосным.
#
# Известно, что год является високосным при выполнении хотя бы одного из следующих условий:
#
# Номер года делится (без остатка) на 400.
# Номер года делится (без остатка) на 4 и не делится на 100 одновременно.
# Номер года находится в переменной year.
#
# Результат выполнения условия занесите в переменную year_is_leap. Её значение должно быть равно True или False, в зависимости от того, является ли заданный год високосным.
#
# Примеры работы программы:
#
#
# year = 2000
# # year_is_leap = True
#
# year = 1900
# # year_is_leap = False
#
# year = 2015
# # year_is_leap = False

# %%
year = 2015


year_is_leap = year % 400 == 0 or (year % 4 == 0 and year % 100 != 0)

print(year_is_leap)

# %% [markdown]
# Шоколадка имеет вид прямоугольника размером n * m долек. Шоколадку можно один раз разломить по прямой на две части.
#
# Необходимо реализовать условие, проверяющее, можно ли таким образом отломить от шоколадки часть, состоящую ровно из k долек. Два примера таких разделений — по горизонтали и вертикали — приведены на рисунке.
#
# Пример
#
# Информация о количестве долек в ширину и длину шоколадки, а также количество долек, которое должно получиться после разделения, содержится в переменных n, m и k соответственно.
#
# Не забудьте также учесть, что количество долек, получаемое в остатке, должно быть строго меньше, чем общее количество долек, из которых состоит шоколадка.
#
# Результат работы условия занесите в переменную result, значение которой равно True или False в зависимости от выполнения условия.
#
# Примеры работы программы:
#
#
# n, m, k = 5, 4, 8
# # result = True
#
# n, m, k = 5, 4, 3
# # result = False
#
# n, m, k = 5, 4, 25
# # result = False

# %%
n, m, k = 5, 4, 8

# %% [markdown]
# Ну тут очевидно по идеи
# k должно быть меньше n * m
# k не должно быть меньше (min(n,m))
# остаток от деления от n или m должны быть == 0

# %%
n, m, k = 5, 4, 8 
result_1 = k < n*m 
result_2 = k > min(n,m)
result_3 = k % n == 0 or k % m == 0

result = result_1 and result_2 and result_3

# %%
result

# %% [markdown]
# Представьте, что вы обрабатываете заполненные пользователями онлайн-заявки. Переменная phone в виде строки хранит указанный пользователем номер телефона и None, если соответствующее поле в анкете заполнено не было.
#
# Реализуйте условие, которое проверит, оставил ли пользователь номер телефона. Результатом работы условия должно стать булево значение True или False в зависимости от того, заполнено ли поле с номером телефона.
#
# Результат занесите в переменную phone_is_defined.
#
# Примеры работы программы:
#
#
# phone = '+7 927 124 42 12'
# # phone_is_defined = True
#
# phone = None
# # phone_is_defined = False

# %%
phone = None

phone_is_defined = not(phone is None)

print(phone_is_defined)

# %% [markdown]
# В словаре arrival_of_goods хранится информация о приходах товара на склад интернет-магазина. Ключами этого словаря являются номера накладных, а значениями — словари, в которых содержится информация о товаре и его количестве в каждой из накладной.
#
#
# arrival_of_goods = {
#     '148902': {
#         'Футболка с принтом': 180,
#         'Свитшот черный': 245,
#         'Джинсы серые': 252
#     },
#     '893516': {
#         'Футболка с принтом': 43,
#         'Свитшот черный': 64,
#         'Джинсы черные': 102
#     },
#     '893481': {
#         'Кружка керамическая': 35,
#         'Свитшот черный': 10,
#         'Джинсы сервые': 14
#     }
# }
# Мы проводим аналитику прихода товара на склад. В переменной invoice_number содержится номер накладной, который мы хотим найти.
#
# С помощью метода словарей get() и проверки на None реализуйте условие, которое проверяет, есть ли в истории прихода накладная с указанным в переменной invoice_number номером.
#
# Результатом работы условия должна стать булева переменная со значением True или False в зависимости от того, существует ли в системе указанная накладная.
#
# Результат занесите в переменную invoice_exists.
#
# Примеры работы программы:
#
#
# invoice_number = '148902'
# # invoice_exists = True
#
# invoice_number = '892421'
# # invoice_exists = False

# %%
arrival_of_goods = {
    '148902': {
        'Футболка с принтом': 180,
        'Свитшот черный': 245,
        'Джинсы серые': 252
    },
    '893516': {
        'Футболка с принтом': 43,
        'Свитшот черный': 64,
        'Джинсы черные': 102
    },
    '893481': {
        'Кружка керамическая': 35,
        'Свитшот черный': 10,
        'Джинсы сервые': 14
    }
}


invoice_number = '14890112' 

invoice_exists = arrival_of_goods.get(invoice_number) is not None

print(invoice_exists)

# %% [markdown]
# Начинающий программист торопился и допустил в своей программе несколько синтаксических ошибок. Ваша задача — исправить код так, чтобы он отработал без синтаксических ошибок
#
#
# mx = 0
# s = 0
#
#     x = -5
#     if x < 0
#         s = x
#
# if x > mx
#     mx = x
#
# print(s)
# print(mx)

# %%
mx, s, x = 0, 0, -5 

if x < 0:
    s = x 

if x > mx:
    mx = x 

print(s, mx, sep = '\n')

# %% [markdown]
# Вам необходимо запрограммировать сенсор в общественном помещении, который определяет количество человек.
#
# Если людей в помещении меньше 10, то на табло должно гореть сообщение «Добро пожаловать!», а в противном случае — «Всё занято. Подождите!».
#
# Количество человек в помещении хранится в переменной people_count. Организуйте вывод на табло с помощью функции print().
#
# Примеры работы программы:
#
#
# people_count = 5
# # Добро пожаловать!
#
# people_count = 10
# # Всё занято. Подождите!
# Примечание: Для отправки кода на проверку переменную people_count объявлять не нужно. Не забудьте удалить строку кода с её объявлением перед тестированием.

# %%
people_count = 5 

if people_count >= 10:
    print('Всё занято. Подождите!')
else:
    print('Добро пожаловать!')

# %% [markdown]
# Пользователь вводит своё имя и возраст, их значения хранятся в переменных name и age соответственно.
#
# Если возраст пользователя больше либо равен 18, то программа должна вывести строку "Добрый вечер, <name>!", меньше — "Привет, <name>! Приносим свои извинения, но вы не можете гулять после 22:00".
#
# Примеры работы программы:
#
#
# name = 'Андрей'
# age = 21
# # "Добрый вечер, Андрей!"
#
# name = 'Павел'
# age = 17
# # Привет, Павел! Приносим свои извинения

# %%
name = 'Андрей'
age = 17

if age >= 18:
    print(f"Добрый вечер, {name}!")
else:
    print(f"Привет, {name}! Приносим свои извинения, но вы не можете гулять после 22:00")

# %%
is_rainy = True

if is_rainy:
    print('взять зонт')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
is_rainy = False # дождь будет
heavy_rain = False  # не сильный дождь 

if is_rainy:
    if heavy_rain:
        print('Зонт')
    else:
        print('Дождевик')
else:
    print('Не брать зонт')

# %%
is_rainy = False  # дождь будет
heavy_rain = False  # не сильный дождь

if is_rainy:
    # в данный блок дописали ещё один условный оператор
    if heavy_rain:
        #брать зонт
        print("Take an umbrella")  
    else:
        #надеть дождевик
        print("Put on a raincoat") 
else:
    #не брать зонт
    print("Don't take an umbrella") 

## Put on a raincoat

# %%
credit_history = 'good' #кредитная история
deposit = True # есть ли залог
guarantors = False # есть ли поручители
credit = 500.0 #сумма долга  

if credit_history == 'good':
    if credit <= 1000:
        print('Выдать')
    else:
        print('Не выдавать')
else:
    if deposit:
        if guarantors:
            print('Выдать')
        else:
            print('Не выдавать')
    else:
        print('Не выдавать')

# %%
if credit_history == 'bad':
    if deposit:
        if guarantors:
            print('Issue a loan')
        else:
            print('Not to issue a loan')
    else:
        print('Not to issue a loan')
else:
    if credit < 1000:
        print('Issue a loan')
    else:
        print('Not to issue a loan')

# %% [markdown]
# Используя вложенный условный оператор, напишите программу, которая проверяет, что число number делится на 2 и на 5 без остатка.
#
# Если число делится на 2 и на 5, программа должна выводить на экран фразу "<число> делится на 2 и на 5".
#
# Если число делится на 2, но не делится на 5 — программа должна выводить на экран фразу "<число> делится на 2, но не делится на 5".
#
# Если число не делится на 2, но делится на 5 — программа должна выводить на экран фразу "<число> не делится на 2, но делится на 5".
#
# Если число не делится ни на 2, ни на 5 — программа должна выводить на экран фразу "<число> не делится ни на 2, ни на 5".
#
# Примеры работы программы:
#
#
# number = 200
# # 200 делится на 2 и на 5
#
# number = 8
# # 8 делится на 2, но не делится на 5
#
# number = 15
# # 15 не делится на 2, но делится на 5
#
# number = 27
# # 27 не делится ни на 2, ни на 5

# %%
number = 200 

if number % 2 == 0 and number % 5 == 0:
    print(f'{number} делится на 2 и на 5')

# %%
number = 27

if number % 2 == 0:
    if number % 5 == 0:
        print(f'{number} делится на 2 и на 5')
    else:
        print(f'{number} делится на 2, но не делится на 5')
else:
    if number % 5 == 0:
        print(f'{number} не делится на 2, но делится на 5')
    else:
        print(f'{number} не делится ни на 2, ни на 5')

# %% [markdown]
# Рассмотрим пример для сравнения двух чисел и получения большего из них:

# %%
a = 50
b = 30 


result = a if a > b else b

# %%
print(result)

# %%
result = x if cond1 else y if cond2 else z

# %% [markdown]
# Напиши выражение, которое в переменную result запишет большее из двух чисел a и b через тернарный оператор.

# %%
a = 10
b = 9 
result = b if a < b else a 
print(result)

# %% [markdown]
# Есть число n. Запиши в переменную answer строку "even", если число чётное, иначе "odd".

# %%
n = 11
answer = 'even' if n % 2 == 0 else 'odd' 
print(answer)

# %% [markdown]
# Есть три числа: a, b, c.
# Запиши в result:
# a, если a > 0
# иначе b, если b > 0
# иначе c

# %%
a = 10
b = 15 
c = 30 

result = a if a > 0 else b if b > 0 else c 

print (result)

# %% [markdown]
# Рассмотрим ещё один пример для закрепления. Мы реализуем систему скидок по возрасту в приложении для бронирования мероприятий. Клиент может рассчитывать на скидку, если его возраст выше 60 лет.
#
# В переменной cust_age содержится значение возраста клиента. Программа должна выводить на экран фразу "Eligible for discount", если у клиента есть право на скидку и "Not eligible for discount", если такого права нет.
#
# Без использования тернарного оператора наша программа выглядела бы следующим образом:

# %%
cust_age = 59

discount = 'Даем скидон' if cust_age >= 60 else 'Нахуй с пляжа'

print(discount)

# %% [markdown]
# Пусть задан список lst:
#
# lst = ['a', 'b', 'c']
#
# Запишите следующую условную конструкцию, используя тернарный оператор:
#
# if'f'in lst:
#     x = 5
# else:
#     x = None

# %%
lst = ['a', 'b', 'c']  


x = 5 if 'f' in lst else None

# %%
print(x)

# %% [markdown]
# Нам нужно установить конкретную ставку скидки в зависимости от того, соответствует ли клиент критериям. По умолчанию наше приложение для бронирования мероприятий предоставляет всем клиентам скидку 10%; однако клиенты в возрасте 60 лет и старше имеют право на скидку 20%.
#
# С помощью тернарного оператора напишите программу, которая определяет скидку клиента. Возраст клиента хранится в переменной cust_age.
#
# Значение скидки занесите в переменную cust_discount.
#
# Примеры работы программы:
#
#
# cust_age = 40
# # cust_discount  = 10
#
# cust_age = 68
# # cust_discount  = 20

# %%
cust_age = 60 

cust_discount = 10 if cust_age < 60 else 20

# %% [markdown]
# Задача №1
#
# Условие задачи:
#
# Написать программу, определяющую, является ли данное время суток утром, и вывести соответствующее сообщение. Утром считается временной промежуток с 6 (включительно) и до 12 часов (невключительно).
#
# Текущее время (в часах) находится в переменной now и представлено в формате 'hour:minute:second'. Например:
#
# now = '11:24:39'

# %%
now = '11:24:39' 


result = 'Утро' if 6 <= int(now[:2]) < 12 else None 

print(result)

# %%
hour, minute, second = now.split(':')
hour, minute, second = int(hour), int(minute), int(second)

if 6 <= hour < 12:
    print("Morning!") # Утро!

# %% [markdown]
# Нам необходимо написать программу, которая определяет, к какой четверти принадлежит точка. Координаты точки хранятся в переменных x и y. Так, точка со следующими координатами:
#
# x, y = (6.3, -5.3)

# %%
x, y = (6.0, -5.3) 


print('1-ая четверть')
print('4-ая четверть')
print('3-ая четверть')
print('2-ая четверть')
print('точка лежит на оси ординат')
print('точка находится в начале координат')
print('точка лежит на оси абсцисс')

# %%
x, y = (1, 0) 


if x:
    if y == 0:
        print('точка лежит на оси абсцисс')
    else:
        if y > 0:
            if x > 0:
                print('1-ая четверть')
            else:
                print('2-ая четверть')
        else:
            if x > 0:
                print('4-ая четверть')
            else:
                print('3-ая четверть')
else:
    if y:
        print('точка лежит на оси ординат')
    else:
        print('точка находится в начале координат')

# %% [markdown]
# Пользователь вводит целое число — текущее время в часах, значение которого хранится в переменной time. Если количество часов находится между 7 и 10 (включая обе границы), то программа должна вывести строку «Пора вставать!», иначе выведется строка «Ты проспал!».
#
# Примечание: В рамках данной задачи условимся, что пользователь считается проспавшим в любое время, отличное от указанного интервала.
#
# Примеры:
#
#
# time = 8
# # Пора вставать!
#
# time = 12
# # Ты проспал!

# %%
letters = ['q', 'z', 'Q', 'Z'] 

target_word = "uantity" 


if target_word in target_word:
    print('хуй')

# %% [markdown]
# Считается, что буквы q и z встречается в английском языке реже остальных букв. Вы решили написать программу, которая позволяет пользователям вводить слова и проверяет, можно считать это слово редким или нет. Интересующее вас слово содержится в переменной target_word.
#
# Пусть эта программа выводит на экран одну из двух фраз: «Ух ты! Вы ввели редкое слово!», если в слове есть буква q или букву z, или «Это не очень редкое слово...», если в нём этих букв нет.
#
# Примеры:
#
#
# target_word = "quantity"
# # Ух ты! Вы ввели редкое слово!
#
# target_word = "apply"
# # Это не очень редкое слово...
# Примечание: Для отправки кода на проверку переменную target_word объявлять не нужно. Не забудьте удалить строку кода с её объявлением перед тестированием.

# %%
target_word = "quantity" 

if 'q' in target_word or 'z' in target_word:
    print('Ух ты! Вы ввели редкое слово!')
else:
    print('Это не очень редкое слово...')

# %% [markdown]
# Вы работаете в агентстве знакомств. К вам обратилась некая Алла, которая ищет мужчину ростом строго выше 180 см, весом строго менее 80 кг. Также Алла верит в гороскопы и согласно гороскопу ей подходят только весы, дева, овен и козерог.
#
# Напишите условие, которое позволит определить, подходит ли Алле тот или иной кандидат. В результате работы программы на экран должно быть введено:
#
# «Ваша половинка нашлась!» — если кандидат подходит Алле по параметрам.
#
# «Попробуем поискать еще!» — если кандидат не подходит Алле по параметрам.
#
# Примеры работы программы:
#
#
# height = 183
# weight = 78
# zodiac_sign = 'козерог'
# # "Ваша половинка нашлась!"
#
# height = 171
# weight = 75
# zodiac_sign = 'весы'
# # "Попробуем поискать еще!"

# %%
height = 183
weight = 81
zodiac_sign = 'лев'


lst = ['весы', 'дева', 'овен', 'козерог']

if height > 180 and weight < 80:
    if zodiac_sign in lst:
        print('Ваша половинка нашлась!')
    else:
        print('Попробуем поискать еще!')
else:
        print('Попробуем поискать еще!')

# %% [markdown]
# Рассмотрим простейший пример: необходимо сравнить значение переменной a с числом 10. Всего есть 3 исхода: число a равно 10, меньше 10 и больше него.

# %%
a = 5


if a == 10:
    print ('а = 10')
elif a > 10:
    print('а > 10')
else:
    print('меньше')

# %% [markdown]
# В переменной month находится номер месяца. Необходимо определить сезон в зависимости от номера месяца и вывести сообщение:
#
# "Spring" для 3, 4, 5 месяцев;
# "Summer" для 6, 7, 8 месяцев;
# "Autumn" для 9, 10, 11 месяцев;
# "Winter" для 12, 1, 2 месяцев;
# "Incorrect month number" для всех остальных значений.

# %%
month = 1


if month in [3, 4, 5]:
    print('Spring')
elif month in [6, 7, 8]:
    print('Summer')
elif month in [9, 10, 11]:
    print('Autumn')
elif month in [12, 1, 2]:
    print('Winter')
else:
    print('Incorrect month number')

# %% [markdown]
# Необходимо реализовать условный оператор, который печатает на экран характеристику ветра и его класс (от 1 до 4) в зависимости от его характера:
#
# "weak [1]" — от 1 до 4 м/с
#
# "moderate [2]" — от 5 до 10 м/c
#
# "strong [3]" — от 11 до 18 м/c
#
# "hurricane [4]" — от 19 м/c
#
# Скорость ветра хранится в переменной speed.
#
# Примеры работы программы:
#
#
# speed = 4
# # "weak [1]"

# %%
speed = 12

if 0 < speed < 5:
    print('weak [1]')
elif 4 < speed < 11:
    print('moderate [2]')
elif 10 < speed < 19:
    print('strong [3]')
else:
    print('hurricane [4]')

# %% [markdown]
# Друг, зная, что вы отличный программист, попросил вас запрограммировать игру «Камень, ножницы, бумага» для своего младшего брата. Правила игры всем известны: камень побеждает ножницы; ножницы — бумагу; бумага — камень.
#
# Жесты, выполняемые первым и вторым игроками находятся в переменных player_1 и player_2 соответственно. Обратите внимание, что названия жестов должны быть написаны строчными буквами.
#
# Напишите программу, которая определяет победителя. Если побеждает первый игрок, то выводится сообщение «Первый игрок — победитель!». Если второй — «Второй игрок — победитель!». Если ничья — выводится «Ничья!».

# %%
player_1 = 'ножницы'
player_2 = 'бумага'


if player_1 == 'ножницы':
    if player_2 == 'бумага':
        print('Первый игрок — победитель!')
    elif player_2 =='камень':
        print('Второй игрок — победитель!')
    else:
        print('Ничья!')
elif player_1 == 'камень':
    if player_2 == 'бумага':
        print('Второй игрок — победитель!')
    elif player_2 =='ножницы':
        print('Первый игрок — победитель!')
    else:
        print('Ничья!')
elif player_1 == 'бумага':
    if player_2 == 'ножницы':
        print('Второй игрок — победитель!')
    elif player_2 =='камень':
        print('Первый игрок — победитель!')
    else:
        print('Ничь!')

# %%
condition_1 = player_1 == 'камень' and player_2 == 'ножницы'
condition_2 = player_1 == 'ножницы' and player_2 == 'бумага'
condition_3 = player_1 == 'бумага' and player_2 == 'камень'

if player_1 == player_2:
    print("Ничья!")
elif condition_1 or condition_2 or condition_3:
    print("Первый игрок — победитель!")
else:
    print("Второй игрок — победитель!")

# %%
dish, street = 'Рамен с говядиной', 'Заводской'


dish_time_dict = {
    'Рамен с говядиной': 15,
    'Суши': 18,
    'Лагман с курицей': 20,
    'Лагман с говядиной': 24,
    'Плов с курицей': 28
} 

street_time_dict  = {
    'Дзержинский': 39,
    'Солнечный': 40,
    'Заводской': 27,
    'Гагаринский': 43,
    'Кировский': 37,
    'Октябрьский': 34
} 

if street not in street_time_dict:
    print('В ваш район доставку не осуществляем!')
else:
    if dish not in dish_time_dict:
        print('Блюдо отсутствует в наличии')
    else:
        if dish_time_dict[dish] + street_time_dict[street] >= 60:
            print('К сожалению мы не можем осуществить доставку, она больше 60 минут')
        else:
            print(f'Доставка приедет через: {dish_time_dict[dish] + street_time_dict[street]} минут')

# %% [markdown]
# Представим ситуацию. В последний месяц удача перестала вам улыбаться. У вас 3 раза взломали пароль от вашего профиля в соцсетях. Вы задумались над тем, что неправильно подходите к вопросу безопасности. И решаете написать программу на Python, которая будет проверять ваш пароль на надёжность. Немного погуглив, вы смогли составить список рекомендаций к паролю:
#
# Длина – 8 символов (если меньше – то проще взломать, а если длиннее – то сложно запомнить).
# Пароль не должен состоять только из цифр.
# Пароль не должен состоять только из букв.
# В пароле должны быть заглавные буквы.
# В пароле должны быть строчные символы.
# В пароле должен быть хотя бы один из специальных символов ('*', '-', '#'), но каждый из символов должен входить в пароль не более 1 раза.
# Другие спецсимволы недопустимы, так как вы их не можете запомнить. Вот список «плохих» символов: '!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~'.
# В случае надёжного пароля программа должна выводить фразу «Пароль идеален!», а в остальных случаях будут перечислены все ошибки, которые вы допустили.

# %%
special_bad = ['!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~']

special_good = ['*', '-', '#']

print(set(special_bad))

# %%
errors_dict = {
    'length': 'Длина пароля не равна 8 символам',
    'digits': 'Пароль состоит только из цифр',
    'letters': 'Пароль состоит только из букв',
    'upper': 'Отсутствуют заглавные буквы',
    'lower': 'Отсутствуют строчные буквы',
    'spec': 'Отсутствуют спецсимволы в пароле',
    'bad_symbols': 'В пароле использованы непредусмотренные символы'
}

password = 'Aafaf*al'

special_bad = ['!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~']



if len(password) != 8: 
    errors_dict.pop('length')

if not password.isdigit():
    errors_dict.pop('digits')
    
if not password.isalpha():
    errors_dict.pop('letters')

if not password.upper() == password:
    errors_dict.pop('lower')

if not password.lower() == password:
    errors_dict.pop('upper')

if (password in '*' or password in '-' or password in '#'):
    errors_dict.pop('spec')
    if (password.count('*') > 1 or password.count('-') > 1 or password.count('#') > 1):
        errors_dict['spec_count'] = 'Какой-то из спецсимволов в пароле использован более одного раза'

if not (set(password)).intersection(set(special_bad)):
    errors_dict.pop('bad_symbols')

if len(errors_dict) > 0:
    print(list(errors_dict.values()))
else:
    print('Пароль идеален!')

# %%
if not set_password.intersection(set_special_bad):
    errors_dict.pop('bad_symbols')

# %%
errors_dict = {
    'length': 'Длина пароля не равна 8 символам',
    'digits': 'Пароль состоит только из цифр',
    'letters': 'Пароль состоит только из букв',
    'upper': 'Отсутствуют заглавные буквы',
    'lower': 'Отсутствуют строчные буквы',
    'spec': 'Отсутствуют спецсимволы в пароле',
    'bad_symbols': 'В пароле использованы непредусмотренные символы'
} 

password = 'Aafaf*al'

bad_symbols = ['!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~']

# Проверяем длину пароля
if len(password) == 8:
    errors_dict.pop('length')

# Проверяем, что пароль НЕ состоит только из цифр
if not password.isdigit():
    errors_dict.pop('digits')

# Проверяем, что пароль НЕ состоит только из букв
if not password.isalpha():
    errors_dict.pop('letters')

# Проверяем, есть ли в пароле заглавные буквы
if password.lower() != password:
    errors_dict.pop('upper')

# Проверяем, есть ли в пароле строчные буквы
if password.upper() != password:
    errors_dict.pop('lower')

# Проверяем, есть ли в пароле специальные символы
if '*' in password or '-' in password or '#' in password:
    errors_dict.pop('spec')
    # Проверяем, встречаются ли спец символы в пароле несколько раз
    if password.count('*') > 1 or password.count('-') > 1 or password.count('#') > 1:
        errors_dict['spec_count'] = 'Какой-то из спецсимволов в пароле использован более одного раза'

# Проверяем, есть ли в пароле запрещенные символы
if len(set(password).intersection(set(bad_symbols))) == 0:
    errors_dict.pop('bad_symbols')

# Проверяем результирующую длину чек-листа
if len(errors_dict) > 0:
    print(list(errors_dict.values()))
else:
    print('Пароль идеален!')

# %% [markdown]
# Представим ситуацию. В последний месяц удача перестала вам улыбаться. У вас 3 раза взломали пароль от вашего профиля в соцсетях. Вы задумались над тем, что неправильно подходите к вопросу безопасности. И решаете написать программу на Python, которая будет проверять ваш пароль на надёжность. Немного погуглив, вы смогли составить список рекомендаций к паролю:
#
# Длина – 8 символов (если меньше – то проще взломать, а если длиннее – то сложно запомнить).
# Пароль не должен состоять только из цифр.
# Пароль не должен состоять только из букв.
# В пароле должны быть заглавные буквы.
# В пароле должны быть строчные символы.
# В пароле должен быть хотя бы один из специальных символов ('*', '-', '#'), но каждый из символов должен входить в пароль не более 1 раза.
# Другие спецсимволы недопустимы, так как вы их не можете запомнить. Вот список «плохих» символов: '!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~'.
# В случае надёжного пароля программа должна выводить фразу «Пароль идеален!», а в остальных случаях будут перечислены все ошибки, которые вы допустили

# %%
rules = {
    '1': 'Длина должна быть 8 символов',
    '2': 'Пароль не должен состоять только из цифр',
    '3': 'Пароль не должен состоять только из букв',
    '4': 'В пароле должны быть заглавные буквы',
    '5': 'В пароле должны быть строчные символы',
    '6': "В пароле должен быть хотя бы один из специальных символов ('*', '-', '#')",
    '7': 'Другие спецсимволы недопустимы'
}

password = 'Aafaf*al'

# %%
rules = {
    '1': 'Длина должна быть 8 символов',
    '2': 'Пароль не должен состоять только из цифр',
    '3': 'Пароль не должен состоять только из букв',
    '4': 'В пароле должны быть заглавные буквы',
    '5': 'В пароле должны быть строчные символы',
    '6': "В пароле должен быть хотя бы один из специальных символов ('*', '-', '#')",
    '7': 'Другие спецсимволы недопустимы'
}

forbidden_special = {'!', '@', '$', '%', '^', '`', '&', '(', ')', '+', '=', '_', '~'}

password = 'Aafaf*al'

if len(password) == 8:
    rules.pop('1')

if not password.isdigit():
    rules.pop('2')

if not password.isalpha():
    rules.pop('3')

if password.upper() != password:
    rules.pop('5') 

if password.lower() != password:
    rules.pop('4') 

if '*' in password or '-' in password or '#' in password:
    rules.pop('6')
    if password.count('*') > 1 or password.count('-') > 1 or password.count('#') > 1:
        rules['6'] = "Каждый из специальных символов ('*', '-', '#'), должен входить в пароль не более 1 раза"

if not set(password) & (forbidden_special):
    rules.pop('7')

if not rules:
    print('Пароль идеален')
else:
    print(rules.values())

# %% [markdown]
# Обдумывая акцию для распродажи, владелец компании пришёл к выводу, что продавать все кроссовки по акции на сайте компании невыгодно. Поэтому была придумана новая схема: если клиент покупает одновременно кроссовки двух разных брендов, то его общая скидка составит 5 %, если две пары от одного бренда — то 10 %.
#
# Для упрощения задачи будем считать, что покупатель в любом случае купит не более двух пар кроссовок. Список товаров в корзине хранится в переменной purchases и может быть пустым.
#
# Также будем считать, что для всех товаров бренда действует одна и та же цена. Расценки товаров хранятся в словаре prices:
#
#
# prices = {'Adidas': 4298, 'Nike': 6550, 'Puma': 4490, 'Asics': 3879}
# Напишите программу, которая:
#
# Выводит на экран информацию об ошибке, если список покупок пуст в виде строки: Ваша корзина пуста
#
# Выводит на экран информацию об общей стоимости товара, если куплен только один товар Стоимость заказа составила: <стоимость заказа>
#
# Выводит на экран информацию о полученной скидке, сумме оплаты без скидки и сумму со скидкой в следующем формате:
#
#
# Стоимость заказа составила: <стоимость заказа без скидки>. С учетом скидки в <размер скидки>% — <стоимость заказа со скидкой>
# Примечание: Для отправки кода на проверку переменную purchases объявлять не нужно. Не забудьте удалить строку кода с её объявлением перед тестированием.
#
# Примеры работы программы:
#
#
# purchases = ["Adidas", "Nike"]
# # Стоимость заказа составила: 10848. С учетом скидки в 5% — 10305.6
#
# purchases = ["Nike", "Nike"]
# # Стоимость заказа составила: 13100. С учетом скидки в 10% — 11790.0
#
# purchases = []
# # Ваша корзина пуста

# %%
prices = {'Adidas': 4298, 'Nike': 6550, 'Puma': 4490, 'Asics': 3879} 
 
purchases = ["Adidas", "Nike"] 

if purchases:
    if purchases[0] == purchases[1]:
        print(f'Стоимость заказа составила: {prices[purchases[0]] + prices[purchases[1]]}.  С учетом скидки в 10% — {(prices[purchases[0]] + prices[purchases[1]]) * 0.9}')
    else:
        print(f'Стоимость заказа составила: {prices[purchases[0]] + prices[purchases[1]]}.  С учетом скидки в 5% — {(prices[purchases[0]] + prices[purchases[1]]) * 0.95}')
elif set(purchases) == 1:
    print()
else:
    print('Ваша корзина пуста')

# %% [markdown]
# При составлении резюме на платформе поиска работы автоматически указывается дата обновления этого резюме. Дата содержится в поле date.
#
# Примеры:
#
#
# date = '16.04.2019 15:59'
# date = '12.05.2019 08:42'
# date = '05.07.2018 20:15'
# Мы распределяем резюме по категориям:
#
# Категория 1 — резюме, обновленные в мае 2019
#
# Категория 2 — резюме, обновленные в период с января по май (не включая май) 2019 года
#
# Категория 3 — резюме, составленные раньше, чем 1 января 2019 года
#
# Напишите программу, которая определяет категорию резюме. Категорию занесите целым числом в переменную category.
#
# Известно, что в базе нет резюме, обновлённых после 1 июня 2019 года. Формат строки date одинаков для всех записей из базы данных, вы можете воспользоваться им.
#
# Примеры работы программы:
#
#
# date = '16.04.2019 15:59'
# # category = 2
#
# date = '12.05.2019 08:42'
# # category = 1
#
# date = '05.07.2018 20:15'
# # category = 3

# %%
date = '30.05.2019 18:20'

if 2019 > int(date[6:10]):
    category = 3
elif date[3:5] == '05':
    category = 1
else:
    category = 2

print(category)

# %%
date[3:5]

# %%
date = '30.05.2019 18:20'
day_month_year = date.split(' ')[0]
print(day_month_year)
# Разделяем строку по символу '.' и создаем соответствующие переменные
day, month, year = day_month_year.split('.')

# %% [markdown]
# Мы занимаемся обработкой и анализом базы данных, содержащей резюме соискателей. Напишем скрипт для автоматического извлечение информации о городе, в котором проживает соискатель.
#
# В поле city_info содержится информация о городе, а также о готовности соискателя к переезду и командировкам.
#
# Примеры переменной city_info:
#
# city_info = "Москва , не готов к переезду , готов к командировкам"
# city_info = "Москва , м. Беломорская , не готов к переезду, не готов к командировкам"
# city_info = "Санкт-Петербург , готов к переезду (Сочи, Москва) , готов к командировкам"
# city_info = "Новосибирск , готов к переезду, не готов к командировкам"
# Нас интересует только город. Причём мы не хотим учитывать все города. Разделим их на 4 категории:
#
# "Москва"
#
# "Санкт-Петербург"
#
# "Город миллионник"
#
# "Другое"
#
# Напишите программу, которая в переменную city записывает одну из четырёх категорий городов, приведённых выше (в точности как указано в задании) на основе информации, содержащейся в переменной city_info.
#
# Чтобы отделить город от ненужной информации обратите внимание на структуру строки: город, готовность к командировкам и переезду разделены последовательностью символов ' , '.
#
# Также вам понадобится список городов-миллионников:
#
# million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград']
# Примеры работы программы:
#
#
# city_info = "Москва , не готов к переезду , готов к командировкам"
# # 'Москва'
#
# city_info = "Иваново , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам"
# # 'Другое'
#
# city_info = "Санкт-Петербург , готов к переезду (Сочи, Москва) , готов к командировкам"
# # 'Санкт-Петербург'
#
# city_info = "Новосибирск , готов к переезду, не готов к командировкам"
# # 'Город миллионник'

# %%
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград'] 

city_info = "Новосибирск , готов к переезду, не готов к командировкам"

city_final = city_info.split(' , ')[0]

if city_final == 'Москва':
    city = 'Москва'
elif city_final == 'Санкт-Петербург':
    city = 'Санкт-Петербург'
elif city_final in million_cities:
    city = 'Город миллионник'
else:
    city = 'Другое'

print(city)

# %%
print("Before exception")

I = 1 / 0 # Здесь что-то не так….

print("After exception")

# %%
print("Before exception")
# Теперь пользователь сам вводит числа для деления
a = int(input("a: "))
b = int(input("b: "))
# Здесь может возникнуть исключение деления на ноль
c = a / b 
# Печатаем c = a / b если всё хорошо   
print(c)  
 
print("After exception")

# %%
try:
    print('Введите числа:')
    a = int(input("a: "))
    print(a)
    b = int(input("b: "))
    print(b)
    с = a/b 
    print(f'{a} / {b} = {c}')
except ZeroDivisionError:
    print('Нельзя делить на ноль')

# %% [markdown]
# Пусть у нас есть некоторый список images_db, в нём хранятся идентификаторы изображений, которые мы отдаём пользователю. Пользователь вводит номер (индекс) элемента, который он хочет получить, а мы выводим на экран сам элемент. Индекс, который ввёл пользователь, находится в переменной index.
#
# Часть с обращением по индексу сейчас выглядит следующим образом:
#
# images_db = [101252, 521929, 215251]
# img_id = images_db[index]
# print(f'Image id: {img_id}')
# Есть вероятность, что в переменной index содержится такое число, что при обращении к списку возникнет ошибка выхода за его пределы. Например, если значение переменной index будет равно 10, а длина списка будет равна 3, мы увидим на экране следующее:
#
# IndexError: list index out of range
# Необходимо организовать обработку этого исключения, чтобы программа не завершала свою работу.

# %%
images_db = [101252, 521929, 215251] 
index = int(input())

try:
    img_id = images_db[index]
    print(f'Номер id {img_id}')
except IndexError:
    print('Нету фото с данным id')

# %%
index = 10
images_db = [101252, 521929, 215251]
try:
    img_id = images_db[index]
except:
    img_id = images_db[-1]
print(f'Image id: {img_id}')

# %% [markdown]
# my_dict = {'a': 10, 'b': '5.214', 'c': 'simple_string'}
#
# value_1 = my_dict[key_1]
# value_2 = my_dict[key_2]
# value_1, value_2 = float(value_1), float(value_2)
# new_value = value_1 + value_2
# Подумайте, какие ошибки могут в нём возникнуть.
#
# При этом переменные key_1 и key_2 приходит каким-то образом извне, например задаются пользователем.

# %%
my_dict = {'a': 10, 'b': '5.214', 'c': 'simple_string'}
key_1, key_2 = input(), input()
value_1 = my_dict[key_1]
value_2 = my_dict[key_2]
value_1, value_2 = float(value_1), float(value_2)
new_value = value_1 + value_2

print(new_value)

# %% [markdown]
# ValueError у нас да отбивается ошибка в том случае если очевидно в нашем словаре мы пытаемчя преобразовать строку в число
#
# KeyError при изначальном вводе ввели отсутствующее значение ключа
#
# ну давай начнем сначала try для инпута потом пропишем try для преобразования

# %%
my_dict = {'a': 10, 'b': '5.214', 'c': 'simple_string'} 

try:
    key_1, key_2 = input(), input()
    value_1 = my_dict[key_1]
    value_2 = my_dict[key_2]
except KeyError:
    print('Данный ключ отсутствует в словаре')
else:
    try:
        value_1, value_2 = float(value_1), float(value_2)
        new_value = value_1 + value_2
        print(new_value)
    except ValueError:
        print('Под одним из ключей находится строка которую невозможно преобразовать в число, введите пожалуйста другой ключ')

# %%
try:
    value_1 = my_dict[key_1]
    value_2 = my_dict[key_2]
    value_1, value_2 = float(value_1), float(value_2)
    new_value = value_1 + value_2
except Exception as e:
    print('Код завершился с ошибкой: {}'.format(e))

# %% [markdown]
# Задан словарь medicines с ценами на лекарства в онлайн-аптеке и строка name.
#
# С помощью конструкции try-except реализуйте программу, которая печатает на экран значение, хранящееся по ключу из переменной name. Если строка name не является ключом словаря, то на экран через print выводится сообщение «Такого ключа в словаре нет».
#
# Примеры работы программы:
#
#
# medicines = {'Ибупрофен': 99, 'Эспумизан': 279, 'Пенталгин': 119}
# name = 'Визин'
# # Такого ключа в словаре нет
#
# medicines = {'Ибупрофен': 99, 'Эспумизан': 279, 'Пенталгин': 119}
# name = 'Ибупрофен'
# # 99

# %%
medicines = {'Ибупрофен': 99, 'Эспумизан': 279, 'Пенталгин': 119} 
name = 'Визин'

try:
    print(medicines[name])
except Exception:
    print('Такого ключа в словаре нет')

# %%
age = int(input("How old are you?"))

# Проверяем, что возраст пользователя корректный
if age > 100 or age <= 0:
    # Намеренно вызываем ошибку, в скобках указываем текст ошибки
    raise ValueError("You are too old or don't exist") 
# Возраст выводится только в том случае, если пользователь ввёл правильный возраст. 
print("You are {} years old!".format(age))

# %%
# Добавляем конструкцию try-except для отлова нашей ошибки
try:
    age = int(input("How old are you?"))
    # Проверяем, что возраст пользователя корректный
    if age > 100 or age <= 0:
        # Намеренно вызываем ошибку, в скобках указываем текст ошибки
        raise ValueError("You are too old or don't exist") 
# Ловим исключение ValueError
except ValueError:
    # В случае возникновения исключения выводим сообщение
    print("Wrong age")
# В блоке else прописываем часть, которая выполняется, если блок try отработал без ошибок
else:
    # Возраст выводится только в том случае, если пользователь ввёл правильный возраст. 
    print("You are {} years old!".format(age))

# %% [markdown]
# Напишите программу со следующим условием: если число number не ноль, то программа делит 10 на введённое число и записывает результат, округлённый до трёх знаков после запятой, в переменную result. Если же в переменной number хранится ноль, то программа должна выбросить исключение ZeroDivisionError с фразой "Вы собираетесь делить на 0" с помощью ключевого слова raise.
#
# Примеры работы программы:
#
#
# number = 20
# # result = 0.5
#
# number = 7
# # result = 1.429
#
# number = 0

# %%
number = 0

if number:
    result = round(10 / number, 3)
else:
    raise ZeroDivisionError('Вы собираетесь делить на 0')

# %%
my_list = [5, 9, 19]   


for i in my_list:
    print(f'Element:{i}')

# %%
incomes = [120, 38.5, 40.5, 80] 
x = 0 

for i in incomes:
    x += i

print(int(x))

# %%
print(sum(incomes))

# %% [markdown]
# Напишите программу, которая находит произведение элементов списка num_list. В качестве начального значения произведения задайте 1. Далее в цикле перебирайте элементы списка num_list и умножайте значение произведения на элемент списка.
#
# Результирующее произведение занесите в переменную p.
#
# Примеры работы программы:
#
#
# num_list = [98, 24, 23, 12, 3]
# ## p = 1947456
#
# num_list = [1, 10, 0.5, 21, 0.13]
# ## p = 13.65

# %%
num_list = [98, 24, 23, 12, 3] 

p = 1 

for i in num_list:
    p *= i

print(p)

# %%
n = 10
summm = 0

for i in range(1, n + 1):
    summm += i

print(summm)

# %% [markdown]
# В математике факториал числа n — это произведение чисел от 1 до n включительно. Это записывается как:
#
# n! = 1 · 2 · 3 · ... · (n-1) · n
#
# Например:
#
# 3! = 1 · 2 · 3 = 6
#
# 5! = 1 · 2 · 3 · 4 · 5 = 120
#
# Факториал часто применяется в высшей математике, например в комбинаторике, теории вероятностей и дифференциальном исчислении.
#
# В переменной n хранится натуральное число. Напишите программу для вычисления факториала числа n. Результат запишите в переменную p.
#
# Пример работы программы:
#
#
# n = 3
# ## p = 6
# n = 5
# ## p = 120
# n = 10
# ## p = 3628800

# %%
p = 1 
n = 10 
for i in range(1, n + 1):
    p *= i


print(x)

# %% [markdown]
# Представим, что мы пишем программу для компании, занимающейся грузоперевозками.
#
# В нашем распоряжении есть список масс товаров, предназначенных для перевозки (в килограммах).
#
# Согласно нашим данным, товары, которые весят больше 100 килограммов, необходимо перевозить на грузовой машине, а товары меньшей массы можно перевезти на легковой.
#
# → Необходимо написать алгоритм, который распределял бы товары по типам машин.
#
# Пример списка товаров (грузов):
#
# weight_of_products= [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15]

# %%
weight_of_products= [10, 42.4, 240.1, 101.5, 98, 0.4, 0.3, 15] 
big_car = []
small_car = []

for i in range(len(weight_of_products)):
    if weight_of_products[i] > 100:
        big_car.append(weight_of_products[i])
    else:
        small_car.append(weight_of_products[i])

print(f'грузовые: {big_car}, маленькие грузы: {small_car}')

# %% [markdown]
# Условие задачи. Мы разрабатываем новый функционал приложения для туристического агентства «Ковёр-самолёт». В нашем распоряжении есть список мест places, которые пользователь хотел бы посетить.
#
# places = [
#     'Red Square',
#     'Swallow Nest',
#     'Niagara Falls',
#     'Grand Canyon',
#     'Louvre',
#     'Hermitage'
# ]
# Также есть словарь location, ключи которого — места, которые пользователь хочет посетить, а значения — названия стран, где находятся эти места.
#
# location = {
#     'Red Square': 'Russia',
#     'Swallow Nest': 'Russia',
#     'Niagara Falls': 'USA',
#     'Grand Canyon': 'USA',
#     'Louvre': 'France',
#     'Hermitage': 'Russia'
# }
# По эпидемиологическим причинам пользователь не может посетить места, которые находятся вне территории России. Наша задача — заменить заграничные места в списке places на значение 'Unavailable'.

# %%
places = [
    'Red Square',
    'Swallow Nest',
    'Niagara Falls',
    'Grand Canyon',
    'Louvre',
    'Hermitage'
]

location = {
    'Red Square': 'Russia',
    'Swallow Nest': 'Russia',
    'Niagara Falls': 'USA',
    'Grand Canyon': 'USA',
    'Louvre': 'France',
    'Hermitage': 'Russia'
}

index = 0 
for i in places:
    if location[i] != 'Russia':
        places[index] = 'Unavailable'
    index += 1

print(places)

# %%
for i in places:
    if location[i] == 'Russia':
        location[i] = 'Unavailable'

print(location)

# %%
my_list = [1]
for i in range(10):
    my_list.append(my_list[i] * 2)
    print(my_list)

# %% [markdown]
# Вам задан список num_list, состоящий из чисел (int и float) например:
#
#
# num_list = [1, 10, 3, -5].
# Отсортируйте его с помощью метода sort() для списков, а затем последовательно выведите на экран элементы этого списка с помощью цикла for в следующем формате: "element {i}: {elem}", где i - индекс элемента в списке, elem - элемент.
#
# Пример работы программы:
#
#
# num_list = [1, 10, 3, -5]
# ## element 0: -5
# ## element 1: 1
# ## element 2: 3
# ## element 3: 10

# %%
num_list = [1, 10, 3, -5] 

sort_list = sorted(num_list)

score = 0

for i in sort_list:
    print(f'element {score}: {i}')
    score += 1

# %%
num_list = [1, 10, 3, -5] 

score = 0

num_list.sort()

for i in num_list:
    print(f'element {score}: {i}')
    score += 1

# %%
num_list = [10, 4, 4, 21, 2, 0, -10]

count_even = 0 

for i in num_list:
    if i % 2 == 0:
        count_even += 1 
 
print(count_even)

# %% [markdown]
# Дан список mixture_list, элементами которого могут являться любые типы данных Python. Например:
#
#
# mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']
# С помощью цикла for посчитайте количество элементов типа str в списке. Результат запишите в переменную count_str.
#
# Примеры работы программы:
#
#
# mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another']
# ## count_str = 3
#
# mixture_list = ['My', 'Simple', -10, True, 'False', 'string_1', False, 2.5, [1, 2], 'True']
# ## count_str = 5

# %%
mixture_list = [True, 1, -10, 'hello', False, 'string_1', 123, 2.5, [1, 2], 'another'] 
count_str = 0 
for i in mixture_list:
    if type(i) == str:
        count_str +=1

# %%
print(count_str)

# %% [markdown]
# Мы генерируем текст с помощью нейронной сети. В списке word_list в виде строк задана сгенерированная нейронной сетью последовательность слов. Например:
#
#
# word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]
# Напишите программу для объединения строк из списка word_list в предложения.
#
# Гарантируется, что конец каждого предложения обозначается специальной последовательностью символов — "EOS" (End Of Sentence). Вместо этого символа в предложении ставится точка — ".". Для простоты условимся, что другие знаки препинания (запятые, восклицательные знаки и т. д.) нейронная сеть генерировать не умеет.
#
# Для решения задачи воспользуйтесь циклом for. Результирующий текст запишите в переменную text.
#
# Примеры работы программы:
#
#
# word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]
# ## text = "My name is Sergei. I'm from Moscow."
#
# word_list = ["Человек", "он", "умный", "EOS", "Но", "чтоб", "умно", "поступать", "одного", "ума", "мало", "EOS"]
# ## "Человек он умный. Но чтоб умно поступать одного ума мало."
# Примечание: При составлении строки

# %%
word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]


string = ""

for i in range(len(word_list)):
    if word_list[i] == "EOS":
        word_list[i] = "."
        string += word_list[i] + ' '
        
    else:
        string += word_list[i] + ' '

    
string = string.replace(' . ', '. ')

# %%
word_list = ["My", "name", "is", "Sergei", "EOS", "I'm", "from", "Moscow", "EOS"]

res = " ".join(word_list)
res = res.replace(" EOS", ".")
res = res.strip()

print(res)

# %%
lst = ['a', 'b', 'c', 'd', 'e'] 

while len(lst) > 2:
    lst.pop(0)

# %%
lst

# %% [markdown]
# Условие задачи. Пассажирский лифт имеет ограничение на перевозку — не более 400 кг единовременно. Пусть входящие в лифт люди имеют одинаковый вес (weight).
#
# Необходимо написать программу, которая должна следить за изменением нагрузки на лифт, сравнивать её с грузоподъёмностью и в случае перевеса выдавать предупреждение 'Overweight N kg'). Например, при перевесе в 15 кг должно быть выведено сообщение 'Overweight 15 kg').
#
# Для данного примера вес заходящих людей зададим как weight = 67).

# %%
score = 0 
weight = 55

while score < 400:
    score += weight

print(f'Перевес: {score - 400}')

# %% [markdown]
# Сосуд вмещает в себя ровно volume литров жидкости. Каждый раз в него вливается 0.0033 кубических метра жидкости. Понятно, что в какой-то момент сосуд наполнится до краёв, и жидкость начнёт выливаться из него. В тот момент, когда жидкость начинает выливаться (заполненный объём становится больше, чем вместимость сосуда), наполнение сосуда прекращается.
#
# С помощью цикла while опишите данный процесс и найдите, сколько литров жидкости выльется из сосуда. Результат запишите в переменную cost.
#
# Учтите, что 1 кубический метр равен 1 000 литрам (0.0033 * 1000 = 3.3).
#
# Примеры работы программы:
#
#
# volume = 10
# ## cost = 3.1999999999999993
#
# volume = 15
# ## cost = 1.5

# %%
volume = 10 
score = 0

while volume > (x := ((0.0033 * 1000) * score)):
    score += 1 

cost = x - volume 
print(cost)

# %% [markdown]
# Условие задачи. Написать цикл, который будет складывать натуральные числа, пока их сумма не превысит 500.
#
# Натуральные числа — это числа 1, 2, 3, 4 и т. д.

# %%
s = 0 
x = 0 
while s < 500:
    x += 1
    s += x

# %% [markdown]
# Напишите цикл while, который находит минимальное натуральное число number, квадрат которого больше некоторого заданного value.
#
# Результирующий ответ запишите в переменную number.
#
# Примеры работы программы:
#
#
# value = 10
# ## number = 4
#
# value = 159
# ## number = 13
#
# value = 1000
# ## number = 32

# %%
value = 1000
x = 0 
while value > x ** 2:
    x += 1


print(x)

# %%
n = 1 

while True:
    print('Новый клиент!')
    n += 1 
    if n > 10:
        break

# %% [markdown]
# Условие задачи. Представьте себя администратором тайного интернет-сообщества «Три Слепые Мыши» с ограниченным членством. У каждого участника сообщества есть свой позывной и пароль. Позывные и пароли представлены в словаре secret_passwords. Ключи данного словаря — позывные, а значения — пароли.
#
# secret_passwords = {
#     'Enot': 'ulybaka',
#     'Agent12': '1password1',
#     'MouseLulu': 'myshkanaruhka'
# }
# Необходимо создать бесконечный цикл, который будет проверять, что пользователь, посетивший интернет-сообщество, является его членом. Пользователь вводит свои позывной и пароль с клавиатуры.

# %%
secret_passwords = {
    'Enot': 'ulybaka',
    'Agent12': '1password1',
    'MouseLulu': 'myshkanaruhka'
}  


x_login = input() 
y_pass = input() 

while True:
    if x_login not in secret_passwords:
        print("Такой пользователь не найден")
        x_login = input()
    else:
        if y_pass in secret_passwords[x_login]:
            print('Добро пожаловать в тайной общество!')
            break 
        else:
            print('Неверный пароль!')
            break

# %%
secret_passwords = {
    'Enot': 'ulybaka',
    'Agent12': '1password1',
    'MouseLulu': 'myshkanaruhka'
}   


while True:
    x_log = input("Введите логин")
    if x_log in secret_passwords:
        y_pass = input("Введите пароль")
        if y_pass == secret_passwords[x_log]:
            print('Добро пожаловать!')
            break
        else:
            print('Неверный пароль')
    else:
        print('Неверный логин')

# %% [markdown]
# Напишите бесконечный цикл while с условием выхода внутри цикла, который находит минимальное натуральное число, квадрат которого больше value.
#
# Запишите результат в переменную number.
#
# Примеры работы программы:
#
#
# value = 10
# ## number = 4
#
# value = 159
# ## number = 13
#
# value = 1000
# ## number = 32

# %%
value = 10 
number = 0
while True:
    number += 1
    if value < number ** 2:
        break 


print(number)

# %%
i = 0
n = 3
while True:
    i += 1 
    print("Hello")
    if i == n:
        break

# %%
n = 156
x = 1 

while (x ** 2) % n != 0:
    x += 1

# %%
print(x)

# %%
p = 1 
n = 1
while True:
    n += 1
    p *= n 
    if p > value:
        break

# %%
print(p)

# %% [markdown]
# Олег положил money рублей в банк под 8 % годовых с ежегодной капитализацией процентов. Через сколько лет у него на счету будет не менее target_money рублей?
#
# Запишите ответ в переменную year_count.
#
# Для моделирования процесса увеличения денежной суммы на счёте воспользуйтесь циклом while. В случае, когда значение target_money < money, в переменной year_count должен содержаться 0.
#
# Примеры работы программы:
#
#
# money = 1000
# target_money = 3000
# ## year_count = 15
#
# money = 8000
# target_money = 15000
# ## year_count = 9
#
# money = 1500
# target_money = 300
# ## year_count = 0

# %%
money = 1000
target_money = 3000 
year_count = 0

while money < target_money:
    year_count += 1
    money = money * 1

# %%
print(year_count)

# %% [markdown]
# Вы играете в компьютерную игру, дошли до схватки с финальным боссом, но вот незадача: ваш компьютер «заглючил», и вы не можете управлять вашим персонажем. Босс атакует и каждую секунду наносит один удар, который отнимает у персонажа damage единиц здоровья. На схватку с боссом ваш персонаж вышел с health единиц здоровья.
#
# Создайте цикл, позволяющий понять, через сколько секунд босс убьёт вашего персонажа. В результате работы вашей программы в переменной seconds_num должно быть сохранено количество секунд, в течение которых будет длиться схватка.
#
# Примеры работы программы:
#
#
# health = 500
# damage = 80
# ## seconds_num = 7
#
# health = 3014
# damage = 174
# ## seconds_num = 18

# %%
health = 500
damage = 80 
seconds_num = 0

while health - damage * seconds_num > 0:
    seconds_num += 1

# %%
print(seconds_num)

# %% [markdown]
# Числа Фибоначчи — это бесконечная последовательность чисел, которую можно получить рекурсивно. Каждое число из последовательности является суммой двух предыдущих.
#
#
#
# Последовательность Фибоначчи активно применяется в комбинаторике и аналитике. О значении и вариантах применения чисел Фибоначчи вы можете прочитать в блоге Skillfactory.
#
# Напишите программу, которая выводит первые n чисел Фибоначчи, начиная с 1. Значение n может быть любым.
#
# Для решения можно воспользоваться следующим алгоритмом:
#
# Инициализируем начальные значения последовательности: a = 1, b = 1. В переменную i запишем текущую длину нашей последовательности: i = 2.
# Пока i < n:
# Вычислить новые значения b и a: новым значением b станет сумма старых значений a и b, новым значением a - старое значение b.
# Добавить элемент b в последовательность.
# Увеличить i на 1.
# Результирующую последовательность чисел сохраните в списке fibonacci_list.
#
# Примеры работы программы:
#
#
# n = 3
# ## fibonacci_list = [1, 1, 2]
#
# n = 5
# ## fibonacci_list = [1, 1, 2, 3, 5]

# %%
a, b = 1, 1 

fibonacci_list = []
i = 2 

if n == 1:
    fibonacci_list.append(a)
    print(fibonacci_list)
elif n == 2:
    fibonacci_list.append(a)
    fibonacci_list.append(b)
    print(fibonacci_list)
else:
    fibonacci_list.append(a)
    fibonacci_list.append(b)
    while i < n:
       
        i += 1 
        fibonacci_list.append(b)
    print(fibonacci_list)


     a, b = b, a + b

# %%
temperature = [
    [13, 15, 10],
    [14, 13, 9],
    [8, 9, 6]
]


print(temperature[0][2])
print(temperature[1][1])
print(temperature[2][0])

# %%
a, b, n, i = 1, 1, 5, 2 


fibonacci_list = []

if n == 1:
    fibonacci_list.append(a)
elif n == 2:
    fibonacci_list.append(a)
    fibonacci_list.append(b)
else:
    fibonacci_list.extend([a,b])
    while i < n:
        i += 1
        old_a = a
        a = b 
        b = old_a + b
        fibonacci_list.append(b)

# %%
print(fibonacci_list)

# %%
matrix = [
    [1, 2], 
    [3, 4], 
    [5, 6]
] 

for i in matrix:
    print(f'строка {i}')
    for j in i:
        print(f'{j}')

# %%
matrix = [
    [1, 2], 
    [3, 4], 
    [5, 6]
] 



for i in range(len(matrix)):
    print(matrix[i])
    for j in range(len(matrix[i])):
        print(matrix[i][j])

# %%
hours = list(range(10, 24, 5))
minutes = list(range(0,60, 30))


for i in hours:
    for j in minutes:
        if j:
            print(f'Будильник прозвенит в {i}:{j}')
        else:
            print(f'Будильник прозвенит в {i}:{j}0')

# %% [markdown]
# Задание 4.2 (на самопроверку)
#
# Пусть пользователь заводит будильники на каждые два часа, начиная с 9 часов утра. Причём будильники должны звонить четырежды в указанный час (интервал 15 минут), например в 11:00, 11:15, 11:30 и 11:45.
#
# Напишите вложенный цикл, который будет выводить на экран время, в которое прозвенят будильники.

# %%
hours = list(range(9,24,2))
minutes = list(range(0,60,15))

for i in hours:
    for j in minutes:
        print(f'Время будильников {i:02d}:{j:02d}')

# %% [markdown]
# Условие задачи. Дан список строк str_list = ['text', 'morning', 'notepad', 'television', 'ornament']. Необходимо подсчитать, сколько всего раз во всех строках списка встречается буква 'e'.

# %%
score = 0 

str_list = ['text', 'morning', 'notepad', 'television', 'ornament'] 

for i in str_list:
    for j in i:
        if 'e' in j:
            score +=1 


print(score)

# %% [markdown]
# Задание 4.3 (на самопроверку)
#
# Дан список строк text_list. Посчитайте, сколько раз во всех строках списка встречается буква 'a'.
#
# text_list = [
#     'afbaad',
#     'faaf',
#     'afaga',
#     'agag'
# ]
# В работе кода используйте вложенные списки: внешний список — по элементам списка text_list, внутренний — по символам в строках.

# %%
text_list = [
    'afbaad',
    'faaf',
    'afaga',
    'agag'
] 

count = 0

for i in text_list:
    for j in i:
        if j == 'a':
            count += 1

print(count)

# %%
text_list = [
    'afbaad',
    'faaf',
    'afaga',
    'agag'
] 

count = 0

for i in text_list:
    count += i.count('a')

print(count)

# %%
random_matrix = [
    [9, 2, 1],
    [2, 5, 3],
    [4, 8, 5]
] 

min = 999 

for i in random_matrix:
    for j in i:
        if min > j:
            min = j
    print(min)
    min = 999

# %%
random_matrix = [
    [9, 2, 1],
    [2, 5, 3],
    [4, 8, 5]
] 


min_value_raw = []

for i in random_matrix:
    min_value = i[0]
    for j in i:
        if min_value > j:
            min_value = j
    min_value_raw.append(min_value)


print(min_value_raw)

# %%
random_matrix = [
    [9, 121, 1, 10, 42],
    [91, 5, 3, 34, -1],
    [-8, 98, 5, 24, -420]
]


max_value_raws = []

for i in random_matrix:
    max_value = i[0]
    for j in i: 
        if j > max_value:
            max_value = j
    max_value_raws.append(max_value)

max_value_raws

# %% [markdown]
# Условие задачи. Нам предоставлены данные о баллах пяти студентов по трём экзаменам. Данные находятся во вложенном списке student_scores.
#
# student_scores = [
#     [56, 90, 80],
#     [80, 86, 92],
#     [91, 76, 89],
#     [91, 42, 60],
#     [65, 30, 90]
# ]
# Каждая строка таблицы соответствует номеру студента, а каждый из трёх столбцов соответствует номеру экзамена (первый — математика, второй — информатика, третий — русский язык).
#
# Необходимо найти средний балл студентов по каждому из экзаменов и общий средний балл по всем экзаменам.

# %%
student_scores = [
    [56, 90, 80],
    [80, 86, 92],
    [91, 76, 89],
    [91, 42, 60],
    [65, 30, 90]
] 


rus, math, info = 0, 0, 0
score_i, score_all = 0, 0
average_score = 0 

for i in student_scores:
    score_i += 1
    for j in range(len(i)):
        score_all += 1
        average_score += i[j]
        if j == 0:
            math += i[j]
        elif j ==1:
            info += i[j]
        else:
            rus += i[j]


print(f'Средный балл по всем экзамена:{average_score / score_all}')
print(f'Средный балл по математике:{math / score_i}')
print(f'Средный балл по информатике:{info / score_i}')
print(f'Средный балл по русскому:{rus / score_i}')

# %%
student_scores = [
    [56, 90, 80],
    [80, 86, 92],
    [91, 76, 89],
    [91, 42, 60],
    [65, 30, 90]
]

rus, math, info = 0, 0, 0
score_i, score_all = 0, 0
average_score = 0

for i in student_scores:
    score_i += 1

    for j in range(len(i)):
        score_all += 1
        average_score += i[j]
        if j == 0:
            math += i[j]
        elif j == 1:
            info += i[j]
        else:
            rus += i[j]

print(f'Средний балл по всем экзаменам: {average_score / (score_i * len(student_scores[0]))}')
print(f'Средний балл по математике: {math / score_i}')
print(f'Средний балл по информатике: {info / score_i}')
print(f'Средний балл по русскому: {rus / score_i}')

# %%
student_scores = [
    [56, 90, 80],
    [80, 86, 92],
    [91, 76, 89],
    [91, 42, 60],
    [65, 30, 90]
]  



students = len(student_scores)
subjects = len(student_scores[0])
russia, pcs, math = 0, 0, 0
total_score = 0

for i in range(students):
    math += student_scores[i][0]
    pcs += student_scores[i][1]
    russia += student_scores[i][2]
    for j in range(subjects):
        total_score += student_scores[i][j]

print(f'Average Math: {math/students} Russian: {russia/students} Pcs: {pcs/students}')
print(f'Overall average score: {total_score / (students * subjects)}')

# %% [markdown]
# Напишите код, который определяет, является ли вложенный список test_matrix квадратной матрицей (то есть матрицей, у которой количество строк равно количеству столбцов).
#
# Примеры квадратной и неквадратной (прямоугольной) матрицы: слева — квадратная, справа — неквадратная.
#
#
#
# В результате работы программы в переменной is_square должно лежать булево значение — True или False — в зависимости от заданного вложенного списка.
#
# Примеры работы программы:
#
#
# test_matrix = [
#     [1, 2, 3],
#     [7, -1, 2],
#     [123, 2, -1]
# ]
# ## is_square = True
#
# test_matrix = [
#     [1, 2, 3],
#     [7, -1, 2],
#     [123, 2, -1],
#     [123, 5, 1]
# ]
# ## is_square = False
#
# test_matrix = [
#     [1, 2, 3,  4],
#     [7, -1, 2, 5],
#     [123, 2, -1, 3],
#     [123, 5, 1]
# ]
# ## is_square = False

# %%
test_matrix = [
    [1, 2, 3],
    [7, -1, 2],
    [123, 2, -1],
    [123, 5, 1]
]

count_lines = len(test_matrix)

for i in test_matrix:
    if len(i) != count_lines:
        is_sqaure = False
        break

# %% [markdown]
# При формировании данных о температуре за три летних месяца допустили ошибку: некоторые значения оказались отрицательными. Вам необходимо заменить все отрицательные значения на положительные.
#
# Список со значениями температуры задан в переменной temp. Необходимо перезаписать значения этого списка.
#
# Пример работы программы:
#
#
# temp = [[25, 27, 28, 26, 27, -26, -25, -2, 26], [21, 22, 28, 27, 28, 26, 25, 19, 26], [-19, 21, 25, -27, 28, 25, 21, 20, 26]]
#
# # После обработки
# ## temp = [[25, 27, 28, 26, 27, 26, 25, 2, 26], [21, 22, 28, 27, 28, 26, 25, 19, 26], [19, 21, 25, 27, 28, 25, 21, 20, 26]]

# %%
temp = [[25, 27, 28, 26, 27, -26, -25, -2, 26], [21, 22, 28, 27, 28, 26, 25, 19, 26], [-19, 21, 25, -27, 28, 25, 21, 20, 26]] 



for i in temp:
    for j in range(len(i)):
        if i[j] < 0:
            i[j] *= -1
        

temp

# %% [markdown]
# Дан список customer_satisfaction, состоящий из вложенных списков с показателями удовлетворённости клиентов компании по месяцам. Удовлетворённость измеряется от 0 до 1.
#
# Пример такого списка:
#
#
# customer_satisfaction = [
#     [0.87, 0.56, 0.77],
#     [0.22, 0.46, 0.56, 0.89, 0.95],
#     [0.45, 0.44, 0.68],
#     [0.73, 0.88, 0.95, 0.49]
# ]
#
# Напишите программу, которая вычисляет средние значения удовлетворённости клиентов за каждый месяц (среднее значение в каждом из вложенных списков), округлённые до двух знаков после точки-разделителя, а также максимальное из этих средних значений.
#
# Средняя удовлетворённость по месяцам должна быть представлена в виде списка month_satisfaction. Максимальная удовлетворённость должна быть представлена в виде float-числа и записана в переменную max_satisfaction.
# Пример работы программы:
#
#
# customer_satisfaction = [
#     [0.87, 0.56, 0.77],
#     [0.22, 0.46, 0.56, 0.89, 0.95],
#     [0.45, 0.44, 0.68],
#     [0.73, 0.88, 0.95, 0.49]
# ]
#
# ## month_satisfaction = [0.73, 0.62, 0.52, 0.76]
# ## max_satisfaction = 0.76
#
# При решении задачи постарайтесь обойтись без использования встроенных функций для вычисления суммы списка (sum), длины списка (len), а также максимального значения в списке (max). Решите задачу, используя вложенные циклы, и опишите весь алгоритм самостоятельно.

# %%
customer_satisfaction = [
    [0.87, 0.56, 0.77],
    [0.22, 0.46, 0.56, 0.89, 0.95],
    [0.45, 0.44, 0.68],
    [0.73, 0.88, 0.95, 0.49]
] 

month_satisfaction = []

for i in customer_satisfaction:
    count = len(i)
    count_j = 0
    for j in i:
        count_j += j
    month_satisfaction.append(round(count_j/count,2))

max_satisfaction = month_satisfaction[0]
for i in month_satisfaction:
    if max_satisfaction < i:
        max_satisfaction = i

# %% [markdown]
# Напишите программу, которая вычисляет средние значения удовлетворённости клиентов за каждый месяц (среднее значение в каждом из вложенных списков), округлённые до двух знаков после точки-разделителя, а также максимальное из этих средних значений.
#
# Средняя удовлетворённость по месяцам должна быть представлена в виде списка month_satisfaction. Максимальная удовлетворённость должна быть представлена в виде float-числа и записана в переменную max_satisfaction.

# %%
# Инициализируем пустой список month_satisfaction
month_satisfaction = []
# Создаём цикл по внешнему списку
for row in customer_satisfaction:
    # Инициализируем сумму и количество
    summa = 0
    count = 0
    # Создаём цикл по внутреннему списку
    for value in row:
        # Обновляем сумму и количество
        summa += value
        count += 1
    # Вычисляем среднее
    mean_s = round(summa / count, 2)
    # Добавляем результат в новый список
    month_satisfaction.append(mean_s)

# Инициализируем значение максимальной удовлетворённости
max_satisfaction = 0
# Создаём цикл по элементам списка со значениями удовлетворённости по месяцам
for s in month_satisfaction:
    # Проверяем, что текущее значение удовлетворённости выше
    if s > max_satisfaction:
        # Обновляем максимальную удовлетворенность
        max_satisfaction = s

# %% [markdown]
# user_dynamics = [-5, 2, 4, 8, 12, -7, 5]
# Мы бы хотели вывести этот список на экран поэлементно в виде {номер дня}: {динамика}. Например, для первого дня вывод должен быть "Day 1: -5".

# %%
user_dynamics = [-5, 2, 4, 8, 12, -7, 5] 

for i, x in enumerate(user_dynamics):
    print(f'Day {i+1}: {x}')

# %%
user_dynamics = [-5, 2, 4, 8, 12, -7, 5]
number_negative = None #объявляем переменную, в которой будем хранить номер последнего дня оттока, изначально она пустая (None)
N = len(user_dynamics) #вычисляем длину списка
#создаём цикл по элементам последовательности от 0 до N (не включая N)
for i in range(N): # i — индекс текущего элемента
    #проверяем условие оттока — текущий элемент отрицательный
    if user_dynamics[i] < 0: #если условие истинно,
        number_negative = i+1  #перезаписываем значение номера дня
        print("Churn value: ", user_dynamics[i]) # выводим количество ушедших в этот день пользователей
        print("Number day: ", number_negative) # выводим номер дня

# %%
user_dynamics = [-5, 2, 4, 8, 12, -7, 5] 

for i, x in enumerate(user_dynamics):
    if x < 0:
        print(f"Churn value: {x}") 
        print(f"Number day: {i+1}")

# %% [markdown]
# Дан список, состоящий из строк. Список хранится в переменной str_list. Создайте новый список cut_str_list.
#
# В цикле добавляйте в список cut_str_list списки, состоящие из порядкового номера строки из списка str_list (номер в рамках данной задачи начинается с 0) и трёх первых символов из каждой строки. Если длина строки меньше трёх символов, то добавляется вся строка целиком.
#
# Пример работы программы:
#
#
# str_list = ['Hello', 'my', 'name', 'is', 'Ezeikel', 'I', 'like', 'knitting']
#
# ## cut_str_list = [[0, 'Hel'], [1, 'my'], [2, 'nam'], [3, 'is'], [4, 'Eze'], [5, 'I'], [6, 'lik'], [7, 'kni']]
# При решении задачи воспользуйтесь

# %%
str_list = ['Hello', 'my', 'name', 'is', 'Ezeikel', 'I', 'like', 'knitting'] 

cut_str_list = []


for i, x in enumerate(str_list):
    cut_str_list.append([i, x[:3]])

cut_str_list

# %%
to_inventory = ['Blood Moon Sword', 'Sunset-colored sword', 'Bow of Stars', 'Gain Stone']

score = 0 
inventory = []

for i in to_inventory:
    score += 1
    inventory.append(i)
    if score == 3:
        break

# %%
to_inventory = ['Blood Moon Sword', 'Sunset-colored sword', 'Bow of Stars', 'Gain Stone']


inventory = []

for i in to_inventory:
    if len(inventory) == 3:
        break
    inventory.append(i)

# %%
inventory

# %% [markdown]
# Условие задачи. В теории шифрования очень активно используются степени числа. Берётся число и несколько раз возводится в некоторую степень. Для дешифрации нужно определить, какое число было задано изначально.
#
# Например, изначально задано простое число 3, его возвели в степень 4 и получили число 81.
#
# Необходимо написать программу, которая проверяет, что число n является степенью числа 3.

# %%
x = 0
n = int(input())
for i in range(100):
    x = 3 ** i
    if x == n:
        print(f'3^{i} = {n}')
        break
else:
    print('Ничего не найдено!')

# %%
# Задаём число
n = 27 
# Создаём бесконечный цикл
while True:
    # Проверяем условие, что остаток от деления на 3 равен 0.
    if n % 3 == 0:
        # Если условие выполняется, новое число — результат целочисленного деления на 3.
        n = n // 3 
        # Проверяем условие, что в результате деления получили 1.
        if n == 1: 
            # Выводим утвердительное сообщение
            print('n - is the power of the number 3!')
            # Выходим из цикла
            break 
    else: 
        # В противном случае выводим сообщение-опровержение
        print('n - is not the power of the number 3!') 
        # Выходим из цикла
        break 
## Будет выведено:
## n - is the power of the number 3!

# %%
n = 82

while True:
    if n % 3 == 0:
        n //= 3
        if n == 1:
            print("Заебись")
            break
    else:
        print('Плохо')
        break

# %% [markdown]
# Допишите программу, которая проверяет гипотезу Сиракуз.
#
# Гипотеза Сиракуз заключается в том, что любое натуральное число n можно свести к 1, если повторять над ним следующие действия:
#
# если число чётное, разделить его нацело пополам, т. е. n = n // 2;
# если нечётное — умножить на 3, прибавить 1 и результат нацело разделить на 2, т. е. n = (n * 3 + 1) // 2.
# Мы тестируем только целые числа!
#
# Пример работы программы:
#
#
# n = 19
# ## Syracuse hypothesis holds for number 19
#
# n = 25921
# ## Syracuse hypothesis holds for number 25921

# %% [markdown]
# origin = n
# # Создаём бесконечный цикл
# while True:
#     if origin % 2 == 0:
#
#     # Ваш код здесь
#
#     # Проверяем, что результат равен 1
#     if n == 1:
#         # Если условие выполняется, выводим утвердительное сообщение.
#         print(f'Syracuse hypothesis holds for number {origin}')
#
#         # Ваш код здесь

# %%
origin = n

# Создаём бесконечный цикл
while True: 

    if n % 2:
        n = (n * 3 + 1) // 2
    else:
        n //= 2

    if n == 1: 
        print(f'Syracuse hypothesis holds for number {origin}') 
        break

# %%
origin = n

while True:
    print(n)

    if n % 2:
        n = (n * 3 + 1) // 2
    else:
        n //= 2

    if n == 1:
        print(1)
        print(f'Syracuse hypothesis holds for number {origin}')
        break

# %% [markdown]
# Условие задачи. Дан словарь клиентов и статус их программы скидок. Ключами словаря являются идентификаторы клиентов, а значениями — статусы программы скидок ('yes' — активен, 'no' — неактивен).
#
# client_status = {
#     103303: 'yes',
#     103044: 'no',
#     100423: 'yes',
#     103032: 'no',
#     103902: 'no'
# }
# В честь Нового года магазин хочет отправить подарочные сертификаты всем, у кого активен статус программы скидок.
#
# Необходимо написать программу, которая выводит идентификаторы клиентов, которым полагается подарочный сертификат.

# %%
client_status = {
    103303: 'yes', 
    103044: 'no',
    100423: 'yes',
    103032: 'no',
    103902: 'no'
} 

for i in client_status:
    if client_status[i] == 'no':
        continue
    print(i)

# %% [markdown]
# Дан словарь mixture_dict. Значения в нём могут быть трёх типов: строки (str) или числа (int и float).
#
# Посчитайте, сколько значений в словаре mixture_dict являются числами. Результат занесите в переменную count_numbers. Используйте в своём коде оператор continue.
#
# Примеры работы программы:
#
#
# mixture_dict = {'a': 15, 'b': 10.5, 'c': '15', 'd': 50, 'e': 15, 'f': '15'}
# ## count_numbers = 4
#
# mixture_dict = {'key1': 24, 'key2': '1.4', 'key3': 14, 'key4': 16.24, 'key6': 124.2414, 'key7': 12.2}
# ## count_numbers = 5
# П

# %%
mixture_dict = {'a': 15, 'b': 10.5, 'c': '15', 'd': 50, 'e': 15, 'f': '15'} 

count_numbers = 0

for i in mixture_dict:
    if isinstance(mixture_dict[i], str):
        continue
    else:
        count_numbers += 1

print(count_numbers)

# %%
text = """
The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling down a very deep well.

Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next. First, she tried to look down and make out what she was coming to, but it was too dark to see anything; then she looked at the sides of the well, and noticed that they were filled with cupboards and book-shelves; here and there she saw maps and pictures hung upon pegs. She took down a jar from one of the shelves as she passed; it was labelled `ORANGE MARMALADE', but to her great disappointment it was empty: she did not like to drop the jar for fear of killing somebody, so managed to put it into one of the cupboards as she fell past it.

`Well!' thought Alice to herself, `after such a fall as this, I shall think nothing of tumbling down stairs! How brave they'll all think me at home! Why, I wouldn't say anything about it, even if I fell off the top of the house!' (Which was very likely true.)
"""

# %%
text = text.lower()

# %%
text = text.replace(' ', '')

# %%
text = text.replace('\n','')

# %%
count_dict = {}

# %%
for i in text:
    if i not in count_dict:
        count_dict[i] = 1
    else:
        count_dict[i] += 1

print(count_dict)

# %% [markdown]
# Дана переменная text, в которой содержится некоторый текст. В этом тексте могут присутствовать знаки препинания: точки ('.'), запятые(','), точки с запятой (';'), вопросительные ('?') и восклицательные знаки ('!'), а также тире ('—').
#
# Напишите программу, формирующую словарь count_punctuation, ключами которого являются знаки препинания, а значениями — их количество в тексте.

# %%
text = """
She sells sea shells on the sea shore;
The shells that she sells are sea shells I am sure.
So if she sells sea shells on the sea shore,
I am sure that the shells are sea shore shells.
"""

# %%
text = text.lower()

text = text.replace(' ','')

text = text.replace('\n','')

count_punctuation = {
    ".": 0,
    ",": 0,
    ";": 0,
    "?": 0,
    "!": 0,
    "—": 0
}

for i in text: 
    if i in count_punctuation:
        count_punctuation[i] += 1

# %%
print(count_punctuation)

# %%
punctuation = [".", ",", ";", "?", "!", "—"]

text = """
She sells sea shells on the sea shore;
The shells that she sells are sea shells I am sure.
So if she sells sea shells on the sea shore,
I am sure that the shells are sea shore shells.
"""
text = text.lower()

text = text.replace(' ','')

text = text.replace('\n','')

count_punctuation = {}


for i in text:
    if i in punctuation:
        if i not in count_punctuation:
            count_punctuation[i] = 1
        else:
            count_punctuation[i] += 1

# %%
print(count_punctuation)

# %%
text = """
She sells sea shells on the sea shore;
The shells that she sells are sea shells I am sure.
So if she sells sea shells on the sea shore,
I am sure that the shells are sea shore shells.
""" 

text = text.lower()

symbols = ['\n', '.', ',', ';']

for i in symbols:
    text = text.replace(i, '')

text = text.split()
count = len(text)
    

word_dict = {}

for i in text:
    if i not in word_dict:
        word_dict[i] = 1
    else:
        word_dict[i] += 1

word_dict

# %% [markdown]
# Дано предложение, хранящееся в переменной sentence.
#
# Выполните следующие действия:
#
# Приведите все символы в предложении к нижнему регистру.
# Исключите знаки препинания (запятые и точки).
# Разделите строку по пробелам и создайте список слов, которые входят в предложение.
# Подсчитайте количество повторений каждого слова.
# Для подсчёта слов используйте словарь. Ключами словаря будут слова, а значениями — число вхождений этих слов в предложение. В результате работы вашей программы в переменной word_dict должен храниться результирующий словарь.
#
# Примеры работы программы:
#
#
# sentence = 'A roboT MAY Not injure a humAn BEING or, tHROugh INACtion, allow a human BEING to come to harm.'
# ## word_dict = {'a': 3, 'robot': 1, 'may': 1, 'not': 1, 'injure': 1, 'human': 2, 'being': 2, 'or': 1, 'through': 1, 'inaction': 1, 'allow': 1, 'to': 2, 'come': 1, 'harm': 1}
#
# sentence = "СчастьЕ нЕ в тоМ, чтобы делать всегда, что хочешь, а в Том, чтОБЫ всегдА хотеть того, ЧТО дЕлаешь."
# ## word_dict = {'счастье': 1, 'не': 1, 'в': 2, 'том': 2, 'чтобы': 2, 'делать': 1, 'всегда': 2, 'что': 2, 'хочешь': 1, 'а': 1, 'хотеть': 1, 'того': 1, 'делаешь': 1}
# П

# %%
sentence = 'A roboT MAY Not injure a humAn BEING or, tHROugh INACtion, allow a human BEING to come to harm.' 

sentence = sentence.lower()

sentence = sentence.replace('.', '').replace(',', '')

sentence = sentence.split(' ')

word_dict = {} 

for i in sentence:
    if i not in word_dict:
        word_dict[i] = 1
    else:
        word_dict[i] += 1

# %% [markdown]
# Дан список из строк str_list. Например:
#
#
# str_list = ["text", "morning", "notepad", "television", "ornament"]
# Напишите программу для подсчёта количества вхождений заданного символа в каждую из строк этого списка. Искомый символ хранится в переменной symbol_to_check.
#
# Для подсчёта используйте словарь: в качестве ключа запишите в него строку, в качестве значения — число вхождений искомого символа в эту строку. Для хранения словаря используйте переменную с именем word_dict.
#
# Примеры работы программы:
#
#
# str_list = ["text", "morning", "notepad", "television", "ornament"]
# symbol_to_check = 't'
# ## word_dict = {'text': 2, 'morning': 0, 'notepad': 1, 'television': 1, 'ornament': 1}
#
# str_list = ["text", "morning", "notepad", "television", "ornament"]
# symbol_to_check = 'n'
# ## word_dict = {'text': 0, 'morning': 2, 'notepad': 1, 'television': 1, 'ornament': 2}

# %%
str_list = ["text", "morning", "notepad", "television", "ornament"] 

symbol_to_check = 't' 

word_dict = {}

for i in str_list:
    if i not in word_dict:
        word_dict[i] = 0


for i in word_dict:
    for x in i:
        if x == symbol_to_check:
            word_dict[i] += 1

# %%
str_list = ["text", "morning", "notepad", "television", "ornament"] 

symbol_to_check = 't' 

word_dict = {}

# %%
for i in str_list:
    word_dict[i] = 0
    for x in i:
        if x == symbol_to_check:
            word_dict[i] += 1

# %%
word_dict

# %%
def my_first_function():
    print("Моя первая функция")

# %%
my_first_function()

# %%
my_first_function()

# %%
def print_hours(minutes):
    hours = minutes // 60
    left_minutes = minutes % 60 
    print(f'{hours:02d}:{left_minutes:02d}')


print_hours(1335)

# %%
def get_time(distance, speed):
    result = distance / speed 
    return result

# %%
time = get_time(1000, 60)
time

# %%
def get_time_tuple(distance, speed):
    hours = distance // speed
    distance_left = distance % speed
    kms_per_minute = speed / 60
    minutes = round(distance_left / kms_per_minute)
    return hours, minutes

# %%
result = get_time_tuple(120,100)

# %%
print(result[0], result[1])

# %%
hours, minutes = get_time_tuple(120, 100)

# %%
print(hours, minutes)

# %%
def in_list(list_in, obj):
    for i in list_in:
        if obj == i:
            print('Элемент найден')
            return True
            print('Это не будет напечатано')
    print('Элемент не найден')
    return False
    print('Это тоже не будет напечатано')

# %%
list_test = list(range(1, 10))
obj_test = 5

# %%
in_list(list_test, obj_test)

# %%
# Функция открытия дверей
def open_doors():
    pass

# Функция закрытия дверей
def close_doors():
    pass

# Функция перемещения на этаж с номером number
def move_to_floor(number): 
    pass

# %% [markdown]
# Напишите функцию get_total(units, price), которая принимает на вход число единиц товара и стоимость каждой единицы. Функция возвращает одно число — общую стоимость данного числа товаров.
#
# Пример: print(get_total(15, 50))

# %%
def get_total(units, price):
    return(units*price)

# %%
print(get_total(15, 50))

# %%
def get_time(distance, speed):
    if distan

# %% [markdown]
# Попробуйте добавить в функцию get_time проверку скорости на равенство нулю. Если скорость равна нулю, верните ValueError с сообщением "Speed cannot be equal to 0!".
#
#
# def get_time(distance, speed):
#     if distance < 0 or speed < 0:
#         raise ValueError("Distance or speed cannot be below 0!")
#     result = distance / speed
#     return result
# Пример:
#
#
# get_time(100, 0)
# # ValueError: Speed cannot be equal

# %%
def get_time(distance, speed):

    if any(i < 0 for i in (distance, speed)):
        raise ValueError('Speed or Distance cannot be equal')
    
    if speed:
        pass
    else:
        raise ZeroDivisionError("Speed cannot be equal to 0!")
    
    result = distance / speed
    return result


get_time(120,10)

# %%
def get_cola(ice = True):
    if ice:
        return "Кола со льдом"
    return "Кола без льда"

# %%
get_cola()

# %%
def get__cola(ice = True):
    if ice:
        print('Кола со льдом')
    else:
        print('Кола без льда')

# %%
get__cola()

# %% [markdown]
# Теперь напишем более серьёзную функцию: она будет извлекать корень n-ой степени из заданного числа. Назовём функцию root. Она будет принимать на вход value (число, из которого необходимо извлечь корень) и n (степень корня).

# %%
def root(value, n):
    return(int(value ** (1/n)))

# %%
root(36, 3)

# %% [markdown]
# Модифицируйте функцию root так, чтобы передавать степень корня было необязательно. Если степень корня не передана, функция должна возвращать значение квадратного корня.
#
# Проверьте своё решение, вызвав функцию root:

# %%
def root(value, n = 2):
    return(int(value ** (1/n)))

# %%
root(81, 3)

# %%
def add_mark(name, mark, journal={}):
    # Присваиваем имени в журнале переданную оценку
    journal[name] = mark
    return journal

# %%
group1 = {}

# %%
group1 = add_mark('Ivanov', 5, group1)

# %%
group2 = {}

# %%
group2 = add_mark('Хуйлопан', 5, group2)

# %%
group2

# %%
group1

# %%
group1 = add_mark('Xуйлопан 2', 4)

# %%
group1

# %%
group2

# %%
group1

# %%
group2 = add_mark("Пупкин залупкин", 5)

# %%
group2

# %%
def add_mark(name, mark, journal=None):
    if journal is None:
        journal = {}
        
    journal[name] = mark
    return journal

# %%
group1 = add_mark('A', 4)

# %%
group1 = add_mark('B', 6)

# %%
group1

# %%
def add_mark(name, mark, journal=None):
   # Добавьте здесь проверку аргумента mark
   if journal is None:
       journal = {}
   journal[name] = mark
   return journal

# %% [markdown]
# Дополните её код таким образом, чтобы возникала ошибка ValueError с текстом "Invalid Mark!" при попытке поставить оценку не из списка: 2, 3, 4 или 5.

# %%
def add_mark(name, mark, journal=None):
   if mark not in range(2,6):
        raise ValueError("Invalid Mark!")
   # Добавьте здесь проверку аргумента mark
   if journal is None:
       journal = {}
   journal[name] = mark
   return journal

# %%
def add_mark(name, mark, journal=None):
   if not any(mark == i  for i in range(2,6)):
       raise ValueError("Invalid Mark!")
   # Добавьте здесь проверку аргумента mark
   if journal is None:
       journal = {}
   journal[name] = mark
   return journal

# %%
add_mark('хуй', 11)

# %%
def add_mark(name, mark, journal=None):
   if not mark in [2,3,4,5]:
       raise ValueError("Invalid Mark!")
   # Добавьте здесь проверку аргумента mark
   if journal is None:
       journal = {}
   journal[name] = mark
   return journal

# %%
add_mark('хуй', 11)

# %%
def add_product(name, price, cart = None):

    if price <= 0:
        raise ValueError('Передайте корректную сумму товара!')
    
    if cart is None:
        cart = {}

    cart[name] = price 

    return cart

# %%
cart1 = add_product("apple", 50)

# %%
cart1

# %%
cart1 = add_product("banana", 70, cart1)
print(cart1)

# %%
add_product("milk", 0)

# %% [markdown]
# Напиши функцию add_score, которая добавляет результат игрока в словарь.

# %%
def add_score(player, score, results = None):

    if results is None:
        results = {}
    
    if score < 0:
        raise ValueError('Score cannot be negative')
    
    result[player] = score

    return result

# %%
def root(value, n=2, xyu = False):
    result = value ** (1/n)
    if xyu:
        # Аргументы в функции print,
        # перечисленные через запятую,
        # печатаются через пробел
        print('Root of power', n, 'from',
            value, 'equals', result)
        
    return result

# %%
root(81, xyu = True)

# %%
print("Shopping list:", end = ' ')
print("bread", "butter", "eggs", sep = ', ')
# Будет напечатано:
# Shopping list:
# bread butter eggs

# %%
def mean(*args):
    result = sum(args) / len(args)
    return result

mean(2,4,5,6,10)

# %%
result = 1 

def mult(*numbers):
    for i in numbers:
        result *= i
    return result

# %%
mult(1,2,3)

# %%
print(mult(3,5,10))
# Должно быть напечатано:
# 150

# %%
langs = ['Python', 'SQL', 'Machine Learning', 'Statistics']

# %%
print(*langs, sep = ', ')

# %%
marks = [4,5,5,5,5,3,4,4,5,4,5]

# %%
def mean_mark(name, *marks):
    result = sum(marks) / len(marks)
    # Не возвращаем результат, а печатаем его
    print(name+':', result)

# %%
mean_mark('Константин', *marks)

# %% [markdown]
# Задание 1
#
# def show_args(*args):
#     print(args)
#
# show_args(1, 2, 3)
# show_args([1, 2, 3])
# show_args(*[1, 2, 3])
#
#
# так как я сейчас только что проходил эту тему я понял что функция * возращает кортеж и соотвественно когда мы передает туда
#
# show_args(1, 2, 3) наша функция может принимать множество значение из-за * поэтому выводится кортеж (1,2,3)
# show_args([1, 2, 3]) тут мы передаем список и не распаковываем то-есть получается одним числом цельным и поэтому функция создает кортеж (этот список, )
# show_args(*[1, 2, 3]) а тут мы передаем в нашу функция и еще распаковывает и аналогично первому варианту кортеж но уже с 3 числами а не с одним как во втором случае
#
#
# Задание 2
#
# def total(*numbers):
#     return sum(numbers)
#
# print(total(1, 2, 3))      # 6
# print(total(10, 20))       # 30
# print(total(*[5, 5, 5]))   # 15
#
# ну написал да тоже самое вывелось в целом пока тут тоже понял просто передаем числа возвращает сум с помощью функции встроенной питон и в целом так как распаковка все меня на tuple то-есть кортеж поэтому sum прекрасно работает
#
#
# Задание 3
#
# def mult(*numbers):
#     result = 1
#
#     for num in numbers:
#         result *= num
#
#     return result
#
# так ладно тут чисто на внимательность если result = 0 То при умножение возвращает всегда 0 очевидно
#
#
# Задача 4
#
# marks = [4, 5, 5, 3]
#
# def mean_mark(name, *marks):
#     result = sum(marks) / len(marks)
#     print(name + ':', result)
#
# mean_mark('Анна', *marks)
#
# ну все тут я уже понял что в нашей функции это не означает распаковку это означает что она может принять много аргументов и если мы передаем уже сами список то надо его распаковывать в функцию
#
# Задание 5
# так ну я пока не дошел но я предположил но вроде да все правилньо сделал чисто на индукции
#
# def print_profile(name, age, city):
#     print(f'Имя : {name}')
#     print(f'Возраст : {age}')
#     print(f'Город : {city}')
#
# data = {
#     "name": "Анна",
#     "age": 20,
#     "city": "Москва"
# }
#
# print_profile(**data)
#
# Задача 6
#
# def f(*args):
#     print(args)
#
# numbers = [1, 2, 3]
#
# f(numbers)
# f(*numbers)
#
# а ну я уже в целом объяснял но тоже самое я уже понял что в функции создается кортеж tuple и  если передавать не распакоывая то он создал (x, )
#
# а если распкоаывая в данном слуучае (1,2,3)

# %%
def f(*args):
    print(args)

numbers = [1, 2, 3]
    
f(numbers)
f(*numbers)

# %%
def schedule(**kwargs):
    # kwargs — это словарь, проверим это с помощью isinstance:
    print(isinstance(kwargs, dict))
    # Напечатаем объект kwargs
    print(kwargs) 

schedule(monday='Python', tuesday='SQL', friday='ML')

# %%
def shedule(**kwargs):
    print('Расписание на неделю:')
    for i in kwargs:
        print(i, kwargs[i], sep = '  - ')

# %%
shedule(monday='Python', tuesday='SQL', friday='ML')

# %%
lessons = {
    'Wednesday': 'Maths',
    'Thursday': 'SQL',
    'Friday': 'Statistics'
}

# %%
shedule(**lessons)

# %%
def print_arg(*args, **kwargs):
    print(args)
    print(kwargs)

# %%
print_arg(1,4,5,7, name='Ivanov', age=19, city='Moscow')

# %%
list1 = [1,4,6,8]
list2 = [12, 45, 56, 190, 111]
list3 = ['Python', 'Functions']
 
# Один раз запишем в словарь параметры для печати
# через print: разделитель — запятая,
# окончание строки — точка с запятой
how = {'sep': ', ', 'end': '; '}
 
# Распаковываем и список, и словарь how
print(*list1, **how)
print(*list2, **how)
print(*list3, **how)

# %%
print(*list1)

# %% [markdown]
# Задание 1:
#
# def print_args(*args):
#     print(args)
#     print(type(args))
#     for i in args:
#         print(i)
#
#
# Задание 2:
#
# def print_schedule(**kwargs):
#     for i in kwargs:
#         print(f'{i}: {kwargs[i]}')
#
# ну тут еще можно было через sep = ": " сделать но зачем
#
#
# Задание 3:
#
# def student_info(name, *subjects, **grades):
#     print(f'Student: {name}')
#     print(f'Subjects: {", ".join(subjects)}')
#     print(f'Grades:')
#     for i in grades:
#         print(f'{i}: {grades[i]}')
#
#
# student_info('Alice', 'Python', 'SQL', Python=5, SQL=4)

# %%
def print_args(*args):
    print(args)
    print(type(args))
    for i in args:
        print(i)

# %%
print_args('Python', 'SQL', 'ML')

# %%
def print_schedule(**kwargs):
    for i in kwargs:
        print(f'{i}: {kwargs[i]}')

# %%
print_schedule(monday='Python', tuesday='SQL', friday='ML')

# %%
d = {'x': 10, 'y': 20}

# %%
for k, v in d.items(): 
    print(v)

# %%
def student_info(name, *subjects, **grades):
    print(f'Student: {name}')
    print(f'Subjects: {', '.join(subjects)}')
    print(f'Grades:')
    for i in grades:
        print(f'{i}: {grades[i]}')


student_info('Alice', 'Python', 'SQL', Python=5, SQL=4)

# %%
def root(num):
    return num ** (1/2)

# %%
root1 = lambda num: num ** (1/2)

# %%
root2 = lambda num, n: num ** (1/n)

# %%
root2(25, 2)

# %%
is_even = lambda num: 'even' if num % 2 == 0 else 'odd'

# %%
func_args = lambda *args: print(args)

func_args(1,2,3,4)

# %%
full_func = lambda *args, **kwargs: (args, kwargs)
 
print(full_func(1,5,6,7,name='Ivan', age=25))
# Будет напечатано:
# ((1, 5, 6, 7), {'name': 'Ivan', 'age': 25})

# %%
names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon']

# %%
names.sort()

# %%
names.sort(key = lambda name: len(name))
print(names)

# %%
new_list = ['bbb', 'ababa','aaa', 'aaaaa',  'cc']
new_list.sort(key=get_length)
print(new_list)
# Должно быть напечатано:
# ['cc', 'bbb', 'aaa', 'ababa', 'aaaaa']

# %% [markdown]
# В качестве упражнения попробуйте переписать использованную lambda-функцию в классический вид (с def). Назовите её get_length.
#
# Затем воспользуйтесь полученной функцией для сортировки списка:

# %%
new_list = ['bbb', 'ababa','aaa', 'aaaaa',  'cc']

def get_length(new_list):
    new_list.sort(key = len)
    return new_list

get_length(new_list)

# %%
def get_length_two(new_list):
    return(len(new_list))

# %%
new_list = ['bbb', 'ababa','aaa', 'aaaaa',  'cc']
new_list.sort(key=get_length_two)
print(new_list)

# %%
x = lambda y: 'even' if y % 2 == 0 else 'odd'

# %% [markdown]
# А теперь представим, что мы хотим отсортировать слова в списке не по алфавиту, а по их длине. Для этого как раз будет удобно воспользоваться короткой lambda-функцией, которую мы передадим в качестве параметра key. Теперь функция сортировки уже будет сравнивать не слова в алфавитном порядке, а их длины:

# %%
names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon'] 


sorted = lambda names: len(names)

names.sort(key = sorted)

# %%
names

# %%
names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon'] 


names.sort(key = lambda names: len(names))

# %%
names

# %%
names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon'] 
def get_lenght(names):
    return len(names)

# %%
names.sort(key = get_lenght)

# %%
names

# %%
new_list = ['bbb', 'ababa','aaa', 'aaaaa',  'cc']

# %%
new_list.sort(key = lambda x: (len(x)))

# %%
new_list.sort(key = lambda x: (len(x), x))

# %%
new_list

# %% [markdown]
# Напишите lambda-функцию для расчёта гипотенузы прямоугольного треугольника: она принимает на вход длины двух катетов и возвращает длину гипотенузы (третьей, самой длинной стороны прямоугольного треугольника).
#
# Формула: c = (a**2 + b**2) ** (1/2), где a и b — длины катетов, — длина гипотенузы. Сохраните эту функцию в переменную hyp.
#
# Пример работы функции
#
#
# print(hyp(3,4))
# print(hyp(1,9))
# # 5.0
# # 9.055385138137417

# %%
hyp = lambda a, b: (a**2 + b**2) ** (1/2)

# %%
hyp(3,4)
hyp(1,9)

# %% [markdown]
# Напишите функцию sort_sides(l_in), которая сортирует переданный в неё список l_in.
#
# Входной список состоит из кортежей с парами чисел — длинами катетов прямоугольных треугольников.
#
# Функция должна возвращать список, отсортированный по возрастанию длин гипотенуз треугольников.
#
# Примечание. Вам пригодится lambda-функция из предыдущего задания. При этом вам потребуется заменить lambda от двух аргументов на lambda от одного аргумента и обращаться к элементам кортежа уже при вычислении гипотенузы.
#
# Пример работы функции
#
#
# print(sort_sides([(3,4), (1,2), (10,10)]))
# # [(1, 2), (3, 4), (10, 10)]

# %%
## Задание 1 
double = lambda x: x*2 
print(double(5))

## Задание 2 
get_length = lambda word: len(word) 

def get_length(word):
    return(len(word))

## Задание 3 вот тут подробно я не выкупаю как сортировка происходит ну типо окей когда len понятно он количество слов высчитывакт и сортирует а в этом случае он просто сравнивает или что он вообще делает хз 

words = ['python', 'go', 'javascript', 'java', 'c']

words.sort(key = lambda x: x)

## Задание 4 

is_even = lambda x: 'even' if x % 2 == 0 else 'odd'

## Задание 5. тут тоже не выкупаю сортировку и почему у меня код без скобок не работал тоже не понял 

words = ['bbb', 'ababa', 'aaa', 'aaaaa', 'cc']

words.sort(key = lambda x: (len(x), x))

  Cell In[30], line 5
    words.sort(key = lambda x: x, len(x))
                                        ^
SyntaxError: positional argument follows keyword argument

# %%
## Задание 5. тут тоже не выкупаю сортировку и почему у меня код без скобок не работал тоже не понял 

words = ['bbb', 'ababa', 'aaa', 'aaaaa', 'cc']

words.sort(key = lambda x: (len(x), x))

  Cell In[30], line 5
    words.sort(key = lambda x: x, len(x))
                                        ^
SyntaxError: positional argument follows keyword argument

# %%
## Задние 6 

students = [
    ('Ivan', 22),
    ('Anna', 19),
    ('Petr', 22),
    ('Oleg', 18),
    ('Maria', 19)
]


students.sort(key = lambda x: (x[1], x[0]))

# %%
students

# %%
## Задание 7 

products = [
    ('apple', 120),
    ('banana', 80),
    ('orange', 120),
    ('kiwi', 150),
    ('melon', 80)
] 


products.sort(key = lambda x: (x[1], x[0]))

# %%
products = [
    ('apple', 120),
    ('banana', 80),
    ('orange', 120),
    ('kiwi', 150),
    ('melon', 80)
]  

products.sort(key = lambda x: (-x[1], x[0]))

# %%
products

# %%
discount = lambda x: x * 0.9 

discount(100)

# %%
discount = lambda price, percent: price - (price * (percent/100))

# %%
discount(100,10)
final_price(100, 10)
final_price(200, 25)

# %%
discount = lambda age: 'adult' if age >= 18 else 'minor'

# %%
number_status = lambda number: 'positive' if number > 0 else 'not positive'

# %%
result = 1 

def multiply_all(*args):
    for i in args:
        result *= i 
    return result


get_kwargs = lambda **kwargs: kwargs 


names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon']


new_names = sorted(names, key = lambda x: len(x))

# %%
get_kwargs(name='Anna', age=20)

# %%
names = ['Ivan', 'Kim', 'German', 'Margarita', 'Simon']


new_names = sorted(names, key = lambda x: len(x)) 



def sum_positive(*args):
    result = 0
    for i in range(len(args)):
        if args[i] > 0:
            result += i

print(sum_positive(1, -2, 3, -4, 5)) 

хз почему у меня nonе 



people = [
    {'name': 'Ivan', 'age': 22},
    {'name': 'Anna', 'age': 19},
    {'name': 'Petr', 'age': 22},
    {'name': 'Oleg', 'age': 18}
]

people.sort(key = lambda x, x['age'], x['name'])  

и тут тоже хз хотя по идеи вот мы обращаемсчя к ключу к значению хз что он не хочет

# %%
def sum_positive(*args):
    result = 0
    for i in range(len(args)):
        if args[i] > 0:
            result += i

print(sum_positive(1, -2, 3, -4, 5))

# %%
print(sum_positive(1, -2, 3, -4, 5))

# %%
people = [
    {'name': 'Ivan', 'age': 22},
    {'name': 'Anna', 'age': 19},
    {'name': 'Petr', 'age': 22},
    {'name': 'Oleg', 'age': 18}
]

people.sort(key = lambda x, x['age'], x['name'])

# %%
def sum_positive(*args):
    result = 0 

    for i in args:
        result += i

    return result


books = [
    {'title': 'Python', 'pages': 300},
    {'title': 'AI', 'pages': 150},
    {'title': 'Data', 'pages': 300},
    {'title': 'Math', 'pages': 200}
] 

books.sort(key = lambda x: (x['pages'], x['title']))

# %%
employees = [
    {'name': 'Ivan', 'salary': 1000, 'age': 25},
    {'name': 'Anna', 'salary': 1500, 'age': 22},
    {'name': 'Petr', 'salary': 1000, 'age': 30},
    {'name': 'Oleg', 'salary': 1500, 'age': 20},
    {'name': 'Maria', 'salary': 1000, 'age': 25}
] 


employees.sort(key = lambda x: (-x['salary'], x['age'], x['name']))

# %% [markdown]
# Напишите lambda-функцию для расчёта гипотенузы прямоугольного треугольника: она принимает на вход длины двух катетов и возвращает длину гипотенузы (третьей, самой длинной стороны прямоугольного треугольника).
#
# Формула: c = (a**2 + b**2) ** (1/2), где a и b — длины катетов, — длина гипотенузы. Сохраните эту функцию в переменную hyp.
#
# Пример работы функции
#
#
# print(hyp(3,4))
# print(hyp(1,9))
# # 5.0
# # 9.055385138137417

# %%
hyp = lambda a, b: (a**2 + b**2) ** (1/2)

# %%
hyp(3,4)

# %% [markdown]
# Напишите функцию sort_sides(l_in), которая сортирует переданный в неё список l_in.
#
# Входной список состоит из кортежей с парами чисел — длинами катетов прямоугольных треугольников.
#
# Функция должна возвращать список, отсортированный по возрастанию длин гипотенуз треугольников.
#
# Примечание. Вам пригодится lambda-функция из предыдущего задания. При этом вам потребуется заменить lambda от двух аргументов на lambda от одного аргумента и обращаться к элементам кортежа уже при вычислении гипотенузы.
#
# Пример работы функции
#
#
# print(sort_sides([(3,4), (1,2), (10,10)]))
# # [(1, 2), (3, 4), (10, 10)]

# %%
sort_sides.sort(key = lambda x: x)

print(sort_sides([(3,4), (1,2), (10,10)]))

# %%
def sort_sides(l_in):
    l_in.sort(key = lambda x: (int(x[0])**2 + int(x[1])**2) ** (1/2))
    return l_in

print(sort_sides([(3,4), (1,2), (10,10)]))

# %% [markdown]
# Напишите функцию get_less(list_in, num), которая принимает на вход список list_in, состоящий из чисел, и ещё одно число num.
#
# Функция должна вернуть первое найденное число из списка, которое меньше переданного во втором аргументе. Если такого числа нет, необходимо вернуть None.
#
# Пример:
#
#
# print(get_less([1, 5, 8,  10], 8))
# # 1
#
# print(get_less([1, 5, 8,  10], 0))
# # None
# Вместо pass напишите тело функции
#
#
# def get_less(list_in, num):
#
#     pass

# %%
def get_less(list_in, num):
    for i in list_in:
        if i < num:
            return i
        
print(get_less([1, 5, 8,  10], 0))

# %%
print(get_less([1, 5, 8,  10], 0))

# %% [markdown]
# Напишите функцию split_date(date), которая принимает на вход строку, задающую дату, в формате ддммгггг без разделителей. Функция должна вернуть кортеж из чисел (int): день, месяц, год.
#
# Примечание. Здесь вам пригодятся срезы строк.
#
# Пример
#
#
# print(split_date("31012019"))
# # (31, 1, 2019)

# %%
def split_date(date):
    return (int(date[:2]), int(date[2:4]),int(date[4:]))

print(split_date("31012019"))

# %%
print(split_date("31012019"))

# %% [markdown]
# Напишите функцию is_prime(num), которая проверяет, является ли число простым.
#
# Функция должна вернуть True, если число простое, иначе — False.
#
# Примечание. Простым называют число, которое делится только на 1 или на само себя. Число 1 простым не является.
#
# Пример:
#
# print(is_prime(1))
# print(is_prime(10))
# print(is_prime(13))
# # False
# # False
# # True

# %%
def is_prime(num):
    if num == 1:
        return 'False'
    
    for i in range(num - 1, 1, -1):
        if num % i == 0:
            return 'False'
            
    return 'True'

print(is_prime(3))

# %%
Напишите функцию between_min_max(...), которая принимает на вход числа через запятую.

Функция возвращает среднее арифметическое между максимальным и минимальным значением этих чисел, то есть (max + min)/2.

Пример:

print(between_min_max(10))
print(between_min_max(1,2,3,4,5))
# 10.0
# 3.0

# %%
def between_min_max(*args):
    maxx = max(args)
    minn = min(args)
    return (maxx + minn) / 2

# %%
print(between_min_max(1,2,3,4,5))

# %% [markdown]
# Напишите функцию best_student(...), которая принимает на вход в виде именованных аргументов имена студентов и их номера в рейтинге (нагляднее в примере).
#
# Необходимо вернуть имя студента с минимальным номером по рейтингу.
#
# Пример:
#
# print(best_student(Tom=12, Mike=3))
# print(best_student(Tom=12))
# print(best_student(Tom=12, Jerry=1, Jane=2))
# # Mike
# # Tom
# # Jerry

# %%
def best_student(**kwargs):
    min = 999
    best_student = None 
    for i in kwargs:
        if kwargs[i] < min:
            min = kwargs[i]
            best_student = i 
    
    return best_student

# %%
print(best_student(Tom=12, Jerry=1, Jane=2))

# %%
12 < 999
min = 12 


1 < 12:
min = 1 

2 < 1 
pass

# %% [markdown]
# напишите lambda-функцию is_palindrom(str), которая принимает на вход одну строку str (имя параметра - x) и проверяет, является ли она палиндромом, то есть читается ли она слева-направо и справа-налево одинаково.
#
# Функция возвращает yes, если строка является палиндромом, иначе — no.
#
# Примечание. Не пытайтесь схитрить — в тест включена проверка на то, что функция действительно является lambda.
#
# Пример:
#
# print(is_palindrom('1234'))
# print(is_palindrom('12321'))
# # no
# # yes

# %%
is_palindrom = lambda str: 'yes' if str == str[::-1] else 'no'

# %%
area = lambda a,b: a * b

# %%
print(area(12,5))

# %% [markdown]
# Перепишите функцию between_min_max из задания 7.12 в lambda-функцию. Функция принимает на вход числа через запятую и возвращает одно число — среднее между максимумом и минимумом этих чисел.
#
# Пример:
#
# print(between_min_max(1,2,3,4,5))
# # 3.0

# %%
between_min_max = lambda *args: (max(args) + min(args)) / 2

# %%
print(between_min_max(1,2,3,4,5))

# %% [markdown]
# Напишите функцию sort_ignore_case(ls), которая принимает на вход список ls и сортирует его без учёта регистра по алфавиту.
#
# Функция возвращает отсортированный список.
#
# Пример:
#
#
# print(sort_ignore_case(['Acc', 'abc']))
# # ['abc', 'Acc']

# %%
def sort_ignore_case(ls):
    return sorted(ls, key = str.lower)

# %%
print(sort_ignore_case(['Acc', 'abc']))

# %% [markdown]
# Напишите функцию exchange(usd, rub, rate), которая может принимать на вход сумму в долларах (usd), сумму в рублях (rub) и обменный курс (rate). Обменный курс показывает, сколько стоит один доллар. Например, курс 85.46 означает, что один доллар стоит 85 рублей и 46 копеек.
#
# В функцию должно одновременно передавать два аргумента. Если передано менее двух аргументов, должна возникнуть ошибка ValueError('Not enough arguments'). Если же передано три аргумента, должна возникнуть ошибка: ValueError('Too many arguments').
#
# Функция должна находить третий аргумент по двум переданным. Например, если переданы суммы в разных валютах, должен возвращаться обменный курс. Если известны сумма в рублях и курс, должна быть получена эквивалентная сумма в долларах, аналогично — если передана сумма в долларах и обменный курс.
#
# Пример:
#
# print(exchange(usd=100, rub=8500))
# # 85.0
#
# print(exchange(usd=100, rate=85))
# # 8500
#
# print(exchange(rub=1000, rate=85))
# # 11.764705882352942
#
# print(exchange(rub=1000, rate=85, usd=90))
# # ValueError: Too many arguments
#
# print(exchange(rub=1000))
# # ValueError: Not enough arguments

# %%
def exchange(usd = None, rub = None, rate = None):
    if usd is not None:
        if rub is not None:
            if rate is not None:
                raise ValueError('Too many arguments')
            else:
                return rub / usd 
        else:
            if rate is not None:
                return rate * usd 
    else:
        if rub is not None:
            if rate is not None:
                return rub / rate
    
    raise ValueError('Not enough arguments')

# %%
print(exchange(usd=100, rate=85))

# %%
def print_root(value, n = 2):

    def root(value, n = 2):
        result = value ** (1/n)
        return result
    
    res = root(81, 4)

    
    print(f'Root of power {n} from {value} equals {res}')

# %%
print_root(81, 4)

# %%
root(81,4)

# %% [markdown]
# Мы решили написать программу, которая будет определять, на каком из языков лучше всего написать одну и ту же фразу. Определять, какой вариант «лучше» или «хуже», будем по количеству уникальных букв во фразе. При этом регистр не имеет значения.

# %% [markdown]
# На первом этапе напишите функцию get_count_unique_symbols(), которая:
#
# принимает на вход строку s,
#
# приводит её к нижнему регистру,
#
# убирает из неё все пробелы,
#
# возвращает количество уникальных символов в строке.
#
# Примеры вызова функции:
#
#
#     get_count_unique_symbols('Это простая строка')
#     ## 9
#     get_count_unique_symbols('This is a simple string')
#     ## 12

# %%
def get_count_unique_symbols(s):
    s = s.lower()
    s = s.replace(' ','')
    s_lst = []
    for i in s:
        if i not in s_lst:
            s_lst.append(i)
    return len(s_lst)

# %% [markdown]
# На втором этапе напишите функцию get_min_string(), которая:
#
# принимает на вход две строки s1 и s2,
#
# возвращает ту, в которой количество уникальных символов меньше.
#
# Чтобы определить количество уникальных символов, воспользуйтесь функцией get_count_unique_symbols(), которую вы написали в предыдущем задании. Поместите ее определение и вызов внутрь функции get_min_string().
#
# У вас должна получиться такая конструкция:
#
#
#     def get_min_string(s1, s2):
#         def get_count_unique_symbols(s):
#             # Код внутренней функции
#         # Применяем вложенную функцию к каждой из строк
#         s1_len = get_count_unique_symbols(s1)
#         s2_len = get_count_unique_symbols(s2)
#         # код внешней функции
# Функция get_min_string() должна возвращать:
#
# строку s1, если количество уникальных символов в ней меньше, чем в s2;
#
# строку s2, если количество уникальных символов в ней меньше, чем в s1;
#
# кортеж из строк s1 и s2 при равенстве количества уникальных символов.
#
# Примеры вызова функций:
#
#
#     print(get_min_string(s1='Это простая строка', s2='This is a simple string'))
#     ## Это простая строка
#     print(get_min_string(s1='Отличная фраза', s2='Great phrase'))
#     ## Great phrase
#     print(get_min_string(s1='школа', s2='school'))
#     ## ('школа', 'school')

# %%
def get_min_string(s1, s2):

    def get_count_unique_symbols(s):
        s = s.lower()
        s = s.replace(' ','')
        s_lst = []
        for i in s:
            if i not in s_lst:
                s_lst.append(i)

        return len(s_lst)
    
    s1_len = get_count_unique_symbols(s1)
    s2_len = get_count_unique_symbols(s2)

    if s1_len == s2_len:
        return (s1,s2)
    elif s1_len < s2_len:
        return s1   
    else:
        return s2

# %%
    print(get_min_string(s1='Это простая строка', s2='This is a simple string'))
    ## Это простая строка
    print(get_min_string(s1='Отличная фраза', s2='Great phrase'))
    ## Great phrase
    print(get_min_string(s1='школа', s2='school'))
    ## ('школа', 'school')

# %%
def register_employee(name, surname):
    def create_full_name():
        sep = ' '
        result = name + sep + surname
        return result
    
    full_name = create_full_name()
    print(f'Employee {full_name} is registered with the company {company_name}')


company_name = 'TheBlindMice' # Название компании
register_employee('John','Doe') # Вызов функции

# %%
print(dir(__builtins__))

# %%
# Объявляем внешнюю функцию для регистрации сотрудников
def register_employee(name, surname):
    # Объявляем функцию для промежуточных вычислений
    def create_full_name():
        # Функция использует внешние переменные name и surname
        sep = ' ' # Разделитель между именем и фамилией
        result = name + sep + surname # Вычисляем полное имя
        return result
    # Вызываем внутреннюю функцию
    full_name = create_full_name()
    # Выводим результат на экран, используя внешнюю переменную company_name
    print('Employee {} is registered with the company {}'.format(full_name, company_name))
    
company_name = 'TheBlindMice' # Название компании
register_employee('John','Doe') # Вызов функции

## Будет выведено
## Employee John Doe is registered with the company TheBlindMice

# %% [markdown]
# Мы пишем приложение для рисования графических фигур. Пока мы можем рисовать только окружности и эллипсы.
#
# Чтобы закрашивать фигуры, которые мы рисуем, необходимо рассчитывать площадь этих фигур. Для расчета площади воспользуемся простейшими формулами.
#
# Площадь круга вычисляется по формуле:
#
# S = πr², где r — радиус окружности.
#
#
#
# Площадь эллипса вычисляется по формуле:
#
# S = πab, где a и b — длины полуосей эллипса.
#
# При разработке приложения мы принимаем, что π = 3,1416.
#
# Обратите внимание! Это число является константой — его значение не меняется на всём протяжении выполнения программы.
#
# Напишите функции calculate_area_circle() и calculate_area_ellipse().
#
# Первая функция должна принимать один аргумент r — радиус окружности, вторая функция должна принимать два аргумента a и b — длины полуосей эллипса.
#
# Каждая из функций должна возвращать площадь соответствующей фигуры, округленную до третьего знака после запятой.
#
# Обе функции должны использовать внутри себя локальные переменные с одним и тем же именем area (площади фигур) и глобальную переменную pi, объявленную вне этих функций.
#
# Примеры вызова функций:
#
#
# pi = 3.1416
# print(calculate_area_circle(r=5))
# ## 78.54
# print(calculate_area_ellipse(a=3, b=2.5))
# ## 23.562
#
# pi = 3.14
# print(calculate_area_circle(r=5))
# ## 78.5
# print(calculate_area_ellipse(a=3, b=2.5))
# ## 23.55

# %%
def calculate_area_circle(r):
    area = round(pi * (r ** 2), 2)
    return area 

def calculate_area_ellipse(a, b):
    area = round(pi * a * b, 3)
    return area

# %%
pi = 3.1416
print(calculate_area_circle(r=5))
## 78.54
print(calculate_area_ellipse(a=3, b=2.5))
## 23.562

pi = 3.14
print(calculate_area_circle(r=5))
## 78.5
print(calculate_area_ellipse(a=3, b=2.5))
## 23.55

# %%
-5 ** 2

# %%
word = 'global'

def outer():
    word = 'outer'

    def inner():
        word = 'inner'
        print(word)

    inner()
    print(word)

outer()
print(word)

# %% [markdown]
# Вам необходимо написать программу, которая будет вычислять сумму, оставшуюся на счёте у пользователя банковской карты. Посмотрите на код ниже и внесите в него исправление так, чтобы он работал верно.
#
#
#     def cash(less_money):
#         money -= less_money
#         return money
#     money = 200000
#     print(cash(1000))
# Не добавляйте аргументы в функцию cash, помимо less_money.
#
# Примеры вызова функции:
#
#
#     money = 200000
#     print(cash(1000))
#     ## 199000
#
#     money = 30240
#     print(cash(240))
#     ## 30000

# %%
def cash(less_money):
    global money
    money -= less_money
    return money

money = 200000
print(cash(1000))

# %% [markdown]
# Вы написали программу, которая позволяет конвертировать рубли в выбранную валюту. При написании программы вы использовали global, но позже узнали, что не стоит так часто его использовать. Перепишите следующий код, не используя global.
#
#
# # Словарь с курсами валют (по отношению к рублю)
#
# currencies = {'USD': 74, 'EUR': 88, 'GBP': 98 , 'CHF': 82}
#
#
# # Общее количество денег на счету, которое нужно конвертировать
#
# money = 100000
#
#
# # Функция для конвертации валюты, аргумент - наименование валюты
# def convert(currency):
#     # Объявляем, что money - глобальная переменная
#     global money
#     # Производим конвертацию - делим количество денег на счету на соответствующий курс
#     money = money / currencies[currency]
#
#
# # Вызываем функцию для конвертации валюты
# print(convert('USD'))
#
# Перепишите функцию convert() так, чтобы словарь с курсами валют и количество денег на счету были её первым и вторым аргументом, а валюта, в которую необходимо произвести конвертацию, — третьим.
#
#
# Примеры вызова функции:
#
#
# currencies = {'USD': 74, 'EUR': 88, 'GBP': 98 , 'CHF': 82}
#
# money = 100000
#
# convert_money = convert(currencies, money, 'USD')
# print(convert_money)
#
# ## 1351.3513513513512
#
# convert_money = convert(currencies, money, 'EUR')
# print(convert_money)
#
# ## 1136.3636363636363

# %%
currencies = {'USD': 74, 'EUR': 88, 'GBP': 98 , 'CHF': 82}

money = 100000


def convert(currencies, money, currency):
    money = money / currencies[currency]
    return money

# %%
convert_money = convert(currencies, money, 'USD')  
print(convert_money)  

## 1351.3513513513512

# %% [markdown]
# Примечание. В качестве практики мы предлагаем вам самостоятельно добавить в код внутренней функции preprocessing_sale() следующее условие: если скидка не задана как строка (str), целое (int) или дробное число (float), функция должна выбрасывать исключение ValueError("Некорректный формат скидки").
#
# Напомним, что для выброса исключений используется ключевое слово raise.

# %% [markdown]
# Представим, что у нас есть функция calculate_cost(), которая вычисляет стоимость товара с учётом скидки. Есть два параметра:
#
# cost — стоимость товара, которая всегда является числом;
# sale — скидка на товар, которая задаётся в виде дробного числа (например, 0.15 — скидка в 15 %).
# # Функция для вычисления стоимости
# # Аргументы — cost (стоимость), sale (размер скидки)
# def calculate_cost(cost, sale):
#     # Считаем итоговую стоимость и возвращаем её
#     # (стоимость — стоимость * скидка)
#     return cost - cost * sale
# Мы хотим модифицировать функцию так, чтобы параметр sale можно было задавать не только дробным числом, но и в процентах в виде целого числа или строки.
#
# Следующие вызовы функции должны отрабатывать одинаково:
#
# print(calculate_cost(1330, '15%'))
# print(calculate_cost(1330, 15))
# print(calculate_cost(1330, 0.15))
# Во всех случаях функция должна возвращать число 1130.5 независимо от того, как задаётся скидка.
#
# В данном случае будет удобно написать внутреннюю вспомогательную функцию preprocessing_sale(), которая будет изменять значения аргумента sale следующим образом:
#
# если аргумент — строка, мы будем удалять из неё символ %, приводить к типу данных float и делить на 100;
# если аргумент — целое число, мы будем делить его на 100.
# Аргумент функции также является локальной переменной по отношению к ней и нелокальной переменной по отношению ко внутренней функции. Поэтому для изменения аргумента нам необходимо будет объявить во внутренней функции, что мы используем нелокальную переменную sale.

# %%
def calculate_cost(cost, sale):

    def preprocessing_sale():
        nonlocal sale
        if not isinstance(sale, (int, str, float)):
            raise ValueError("Некорректный формат скидки")
        elif isinstance(sale , str):
            sale = float(sale.replace('%',''))/100
        elif isinstance(sale, int):
            sale = sale / 100 

    
    if preprocessing_sale():
        return cost - (cost * sale)
    else:
        raise ValueError("Некорректный формат скидки")

# %% [markdown]
# Примечание. В качестве практики мы предлагаем вам самостоятельно добавить в код внутренней функции preprocessing_sale() следующее условие: если скидка не задана как строка (str), целое (int) или дробное число (float), функция должна выбрасывать исключение ValueError("Некорректный формат скидки").
#
# Напомним, что для выброса исключений используется ключевое слово raise.

# %%
print(calculate_cost(1330, '15qwfqwfq%'))

# %%
def calculate_cost(cost, sale):

    def preprocessing_sale():
        nonlocal sale
        if isinstance(sale , str):
            sale = float(sale.replace('%',''))/100
        elif isinstance(sale, int):
            sale = sale / 100 

    
    preprocessing_sale() 

    return cost - (cost * sale)

# %%
print(calculate_cost(1330, '15qwfqwfq%'))

# %%
def calculate_cost(cost, sale):

    def preprocessing_sale():
        nonlocal sale
        
        if not isinstance(sale, (int, str, float)):
            raise ValueError("Некорректный формат скидки")
        elif isinstance(sale , str):
            sale = float(sale.replace('%',''))/100
        elif isinstance(sale, int):
            sale = sale / 100 

    
    preprocessing_sale()

    return cost - (cost * sale)

# %%
calculate_cost(1000, [15])

# %%
def total_multiplier(n):

    total = 0

    def multiplier():
        nonlocal total
        product = 10 * n
        total += product
        return total
    
    return multiplier()

# %%
total_multiplier(10)

# %% [markdown]
# Мы реализуем функцию count_occurrences(), у которой есть два параметра s — строка и symbols — список из символов. Функция вычисляет, сколько раз символ symbol встречается в строке s.
#
# Перед подсчётом количества символов строка s проходит предобработку: из неё удаляются пробелы, а символы приводятся к нижнему регистру.
#
#
# # Функция для вычисления количества символов (symbol) в строке s
# def count_occurrences(s, symbol):
#     # Внутренняя функция для предобработки строки s
#     def preprocessing_s():
#         # Удаляем пробелы из строки
#         s = s.replace(' ', '')
#         # Приводим строку к нижнему регистру
#         s = s.lower()
#     # Вызываем функцию для предобработки аргумента s
#     preprocessing_s()
#     # Считаем количество символов symbol в строке s и возвращаем результат
#     return s.count(symbol)
# Сейчас при попытке вызвать функцию: count_occurrences('This is simple string', symbol='t') вызывается исключение UnboundLocalError.
#
# Исправьте код таким образом, чтобы он отрабатывал без ошибки.
#
# Пример вызова функции:
#
#
# count_occurrences('This is simple string', symbol='t')
# ## 2

# %%
def count_occurrences(s, symbol):
    # Внутренняя функция для предобработки строки s
    def preprocessing_s():
        nonlocal s 
        # Удаляем пробелы из строки
        s = s.replace(' ', '')
        # Приводим строку к нижнему регистру
        s = s.lower()
    # Вызываем функцию для предобработки аргумента s
    preprocessing_s()
    # Считаем количество символов symbol в строке s и возвращаем результат
    return s.count(symbol)

# %%
count_occurrences('This is simple string', symbol='t')
## 2

# %%
dir(__builtins__)

# %%
dir('hello')

# %%
dir(list(range(1,10)))

# %%
import math

# %%
dir(math)

# %% [markdown]
# Нам необходимо проанализировать, какая из рекламных кампаний оказалась наиболее успешной. Данные хранятся в словаре advertising_campaigns, где ключ — это рекламный канал, а значение — список, в котором задано суммарное количество вновь нажавших на кнопку рекламного баннера в 2021 и 2022 годах.
#
#
# advertising_campaigns = {'ютуб': [212, 248], 'вк': [514, 342], 'радио': [339, 125]}
# Для каждого рекламного канала нужно получить максимальное количество откликнувшихся за 2021 и 2022 годы.
#
# Для этого мы создали пустой словарь advertising_campaigns_max и написали цикл for, в котором:
#
# проходимся по ключам исходного словаря;
#
# вычисляем максимумы в списках, соответствующих этим ключам;
#
# добавляем эти значения в новый словарь.
#
#
# # Создаём новый пустой словарь
# advertising_campaigns_max = {}
# # Создаём цикл по ключам исходного словаря
# for key in advertising_campaigns:
#     # Вычисляем максимум в списке, лежащем по ключу key
#     max = max(advertising_campaigns[key])
#     # Добавляем максимум в новый словарь
#     advertising_campaigns_max[key] = max
# Но что-то пошло не так, и код падает с ошибкой:
#
#
# TypeError: 'int' object is not callable
# Выясните, в чём дело, и исправьте код. В результате выполнения кода у вас должен получиться словарь advertising_campaigns_max следующего вида:
#
#
# ## {'ютуб': 248, 'вк': 514, 'радио': 339}
# П

# %%
advertising_campaigns = {'ютуб': [212, 248], 'вк': [514, 342], 'радио': [339, 125]}

# %%
advertising_campaigns_max = {}

for i in advertising_campaigns: 
    advertising_campaigns_max[i] = max(advertising_campaigns[i])``

# %%
print(advertising_campaigns_max)

# %%
# Внешняя функция для обработки списка из строк
# defprocessing_list(answers):
    # Внутренняя функция для выполнения обработки одного элемента спискаdefpreprocessing_answer(answer):
        # Приводим к нижнему регистру
        answer = answer.lower()
        # Удаляем стоп-символы 
        stop_symbols = '"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~!'
        # Создаём цикл по символам в строке
        for sym in stop_symbols:
            # Если стоп-символ есть в строке answer
            if sym in answer:
                # Заменяем стоп-символы в строке на пустые строки
                answer = answer.replace(sym, '')
        return answer
    # Создаём пустой список, куда будем добавлять результаты
    result = []
    # Создаеё цикл по всем элементам списка
    for answer in answers:
         # Добавляем предобработанную строку в лог-список
        result.append(preprocessing_answer(answer))  
    return result

# %% [markdown]
# Задача №1
#
# Условие задачи
#
# Мы создаём некоторое приложение, предусматривающее регистрацию пользователей.
#
# Пока мы реализуем небольшой функционал для регистрации. Для этого нам необходимо написать функцию register(surname, name, date, middle_name, registry).
#
# Она будет иметь следующие аргументы:
#
# surname — фамилия пользователя;
# name —  имя пользователя;
# date —  дата рождения пользователя в виде строки формата "DD.MM.YYYY" (например, "13.01.2001");
# middle_name — отчество пользователя;
# registry — список, в который необходимо добавить полученные аргументы в виде кортежа. Порядок следующий: фамилия, имя, отчество, день, месяц, год рождения.
# Регистрацию будем имитировать добавлением данных о пользователях в список в виде кортежа. Функция должна возвращать список, в который добавила запись.
#
# Примеры вызовов функции:
#
# reg = register('Petrova', 'Maria', '13.03.2003', 'Ivanovna')
#
# reg = register('Ivanov', 'Sergej', '24.09.1995', registry=reg)
#
# reg = register('Smith', 'John', '13.02.2003', registry=reg)
# print(reg)
#
# ## [('Petrova', 'Maria', 'Ivanovna', 13, 3, 2003), ('Ivanov', 'Sergej', None, 24, 9, 1995), ('Smith', 'John', None, 13, 2, 2003)]
# Примечание. Значение отчества по умолчанию должно быть None, так как отчество может быть не у всех регистрирующихся.
#
# Значения дня, месяца и года рождения должны быть представлены в виде целых чисел.
#
# Также нужно сделать так, чтобы пустой список создавался в том случае, если он не был передан извне. То есть по умолчанию registry имеет значение None, и если при вызове функции список так и не был передан, то он создаётся в теле функции.

# %%
list_reg = []


def register(surname, name, date, middle_name = None, registry = False):

    def parse_date():
        day,month,year = int(date[:2]), int(date[3:5]), date[6:10]
        return day, month, year

    if registry:
        day, month, year = parse_date()
        list_reg.append((surname, name, middle_name, day, month, year))
        return list_reg 


        

register('Smith', 'John', '13.02.2003', registry = True)

# %%
def register(surname, name, date, middle_name = None, registry = None):


    def preprocessing_date(date):

        day,month,year = int(date[:2]), int(date[3:5]), int(date[6:10])

        return day, month, year
    

    
    if registry is None:

        registry = list()
    
    day, month, year = preprocessing_date(date)


    def check_day(day, month, year):

        if not all(isinstance(i, int) for i in (day, month, year)):
            return False
        
        if not 1900 <= year <= 2022:
            return False 
        
        if not 1 <= month <= 12:
            return False 
        
        if not 1 <= day <= 31:
            return False 
        
        if month in (9,4,6,11):
            if day > 30:
                return False
            
        if month == 2:
            if day != 28:
                return False
            
        return True 
        
    check_day(day, month, year)
    
    

    registry.append((surname, name, middle_name, day, month, year))

    return registry
    

print(check_date(18, 9, 1999))

# %%
reg = register('Petrova', 'Maria', '13.03.2003', 'Ivanovna')
reg = register('Ivanov', 'Sergej', '24.09.1995', registry=reg)
reg = register('Smith', 'John', '13.02.2003', registry=reg)
print(reg)

# %%
print(check_date(18, 9, 1999))

# %%
def check_date(day, month, year):

    if not all(isinstance(i, int) for i in (day, month, year)):
        return False
        
    if not 1900 <= year <= 2022:
        return False 
        
    if not 1 <= month <= 12:
        return False 
        
    if not 1 <= day <= 31:
        return False 
        
    if month in (9,4,6,11):
        if day > 30:
            return False
            
    if month == 2:
        if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
            if day > 29:
                return False
        else:
            if day > 28:
                return False
            
    return True

# %%
print(check_date(29,2,2020))

# %% [markdown]
# Нам остался финальный штрих — добавить проверку даты на корректность в функцию для регистрации!
#
# Модифицируйте функцию register() так, чтобы она выбрасывала исключение ValueError("Invalid Date!"), если введённая пользователем дата является некорректной. Для этого вам пригодится функция check_date() из предыдущего задания — вы можете добавить её в функцию register() или сделать независимой, на ваш вкус.
#
# Главное — не забудьте добавить её объявление при отправке кода на проверку.
#
# Пример вызова функции:
#
#
# reg = register('Petrova', 'Maria', '13.03.2003', 'Ivanovna')
# reg = register('Ivanov', 'Sergej', '24.09.1995', registry=reg)
# reg = register('Smith', 'John', '13.02.2003', registry=reg)
# print(reg)
# ## [('Petrova', 'Maria', 'Ivanovna', 13, 3, 2003), ('Ivanov', 'Sergej', None, 24, 9, 1995), ('Smith', 'John', None, 13, 2, 2003)]
#
# reg = register('Ivanov', 'Sergej', '24.13.1995')
# ## ValueError: Invalid Date!

# %%
# Введите свое решение ниже
def check_date(day, month, year):

    def is_leap():
        if month == 2 and not day > 29:
            if year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
                return True
            
        if not isinstance(day, int):
            return False
        
        if  not 1 <= month <= 12:
            return False 
        
        if not year % 400 == 0 or (year % 4 == 0 and year % 100 != 0):
            if month == 2 and day > 28:
                return False 

        return True 
    

    return is_leap()

# %%
print(check_date(18, 9, 1999))
# True
print(check_date(29, 2, 2000))
# True
print(check_date(29, 2, 2021))
# False
print(check_date(13, 13, 2021))
# False
print(check_date(13.5, 12, 2021))
# False

# %%
def register(surname, name, date, middle_name = None, registry = None):


    def preprocessing_date(date):

        day,month,year = int(date[:2]), int(date[3:5]), int(date[6:10])

        return day, month, year
    

    
    if registry is None:

        registry = list()
    
    day, month, year = preprocessing_date(date)


    def check_day(day, month, year):

        if not all(isinstance(i, int) for i in (day, month, year)):
            return False
        
        if not 1900 <= year <= 2022:
            return False 
        
        if not 1 <= month <= 12:
            return False 
        
        if not 1 <= day <= 31:
            return False 
        
        if month in (9,4,6,11):
            if day > 30:
                return False
            
        if month == 2:
            if day > 28:
                return False
            
        return True 
        

    if not check_day(day, month, year):
        raise ValueError("Invalid Date!")
    

    registry.append((surname, name, middle_name, day, month, year))

    return registry

# %%
reg = register('Petrova', 'Maria', '13.03.2003', 'Ivanovna')
reg = register('Ivanov', 'Sergej', '24.09.1995', registry=reg)
reg = register('Smith', 'John', '13.02.2003', registry=reg)
print(reg)
## [('Petrova', 'Maria', 'Ivanovna', 13, 3, 2003), ('Ivanov', 'Sergej', None, 24, 9, 1995), ('Smith', 'John', None, 13, 2, 2003)]

reg = register('Ivanov', 'Sergej', '24.13.1995')
## ValueError: Invalid Date!

# %%
p1, p2, p3 = (2, 2), (4, 1.25), (1, 4.5)

# %%
def sides(p1,p2,p3):

    x1, y1 = p1 
    x2, y2 = p2
    x3, y3 = p3

    a = (((y1 - y2) ** 2) + ((x2 - x1) ** 2)) ** 0.5 
    b = (((y3 - y1) ** 2) + ((x1 - x3) ** 2)) ** 0.5 
    c = (((y3 - y2) ** 2) + ((x2 - x3) ** 2)) ** 0.5 

    return a, b, c

# %%
print(sides(p1=(2, 2), p2=(4, 1.25), p3=(1, 4.5)))

# %%
def calcul_perimetr(a,b,c):
    perimeter = a + b + c 
    return perimeter

# %%
def calcul_s(a,b,c):
    p = calcul_perimetr(a,b,c) / 2 
    s = (p * (p - a) * (p - b) * (p - c)) ** 0.5
    return s

# %%
print(calcul_perimetr(a=3, b=4, c=5))
print(calcul_s(a=3, b=4, c=5))

# %%
def triangle(p1,p2,p3):

    
    def sides(p1,p2,p3):
        
        x1, y1 = p1 
        x2, y2 = p2
        x3, y3 = p3

        a = (((y1 - y2) ** 2) + ((x2 - x1) ** 2)) ** 0.5 
        b = (((y3 - y1) ** 2) + ((x1 - x3) ** 2)) ** 0.5 
        c = (((y3 - y2) ** 2) + ((x2 - x3) ** 2)) ** 0.5 

        return a, b, c 
    
    def check_exist_triangle(a,b,c):
        if a + b > c:
            if a + c > b:
                if b + c > a:
                    return True
        return False 

    def calcul_perimetr(a,b,c):
        perimeter = a + b + c 
        return perimeter
    
    def calcul_s(a,b,c):
        p = perimeter / 2 
        s = (p * (p - a) * (p - b) * (p - c)) ** 0.5
        return s 

    a, b, c = sides(p1,p2,p3) 

    if not check_exist_triangle(a,b,c):
        raise ValueError("Треугольник не существует")
    else:
        perimeter = calcul_perimetr(a,b,c)
        s = calcul_s(a,b,c)
        result = {'a': a, 'b': b, 'c': c, 'perimeter': perimeter, 'area': s}
        return result

# %%
print(triangle(p1=(2, 2), p2=(4, 1.25), p3=(1, 4.5)))
## {'a': 2.1360009363293826, 'b': 2.692582403567252, 'c': 4.422951503238533, 'perimeter': 9.251534843135168, 'area': 2.1250000000000027}
print(triangle(p1=(1, 1), p2=(1, 4), p3=(5, 1)))
## {'a': 3.0, 'b': 4.0, 'c': 5.0, 'perimeter': 12.0, 'area': 6.0}
print(triangle(p1=(2.5, 2), p2=(4, 1), p3=(1, 3)))
## ValueError: Треугольник не существует

# %%
print(triangle(p1=(2, 2), p2=(4, 1.25), p3=(1, 4.5)))

# %%
def check_exist_triangle(a,b,c):
    if a + b > c:
        if a + c > b:
            if b + c > a:
                return True
    return False

# %%
print(check_exist_triangle(a=3, b=4, c=5))
## True
print(check_exist_triangle(a=1.8, b=1.8, c=3.6))
## False

# %%
1

# %% [markdown]
# Создавая окружность в нашем графическом приложении, пользователь сначала ставит точку P₁ — центр окружности. Затем тянет мышкой эту точку, и там, где растяжение остановится, будет создана точка P₂.
#
# Каждая точка имеет координаты x и y, которые задаются в виде кортежей: P₁=(x₁, y₁), P₂=(x₂, y₂).
#
#
#
# Например:
#
# p1, p2 = (3, 2.5), (4, 4.5)
# Чтобы вычислить все параметры окружности, нам необходимо знать её радиус.
#
# Напишите функцию radius(), которая принимает на вход две точки (их координаты заданы кортежами) и возвращает радиус окружности.
#
# Для вычисления радиуса воспользуйтесь теоремой Пифагора:
#
#
#
# Пример вызова функции:
#
#
# print(radius(p1=(3, 2.5), p2=(4, 4.5)))
# ## 2.23606797749979
#
# print(radius(p1=(0, 0), p2=(1, 1)))
# ## 1.4142135623730951

# %%
def radius(p1,p2):

    x1,y1 = p1 
    x2,y2 = p2 

    radius = (((x2 - x1) ** 2) + ((y2 - y1) ** 2)) ** 0.5 

    return radius

# %%
print(radius(p1=(3, 2.5), p2=(4, 4.5)))
## 2.23606797749979

print(radius(p1=(0, 0), p2=(1, 1)))
## 1.4142135623730951

# %%
pi = 3.1416

def circle(p1,p2):

    x1,y1 = p1 
    x2,y2 = p2 

    def radius():

        radius = (((x2 - x1) ** 2) + ((y2 - y1) ** 2)) ** 0.5 

        return radius 
    
    def calculate_circumference(radius):

        L = 2 * pi * radius 

        return L
    
    def calculate_area_circle(radius):

        S = pi * (radius ** 2)

        return S
    
    radius = radius()
    L = calculate_circumference(radius)
    S = calculate_area_circle(radius) 

    result = {'radius': round(radius,3),'circumference': round(L,3),'area': round(S,3)}
    
    return result

# %%
pi = 3.1416
print(circle(p1=(3, 2.5), p2=(4, 4.5)))
## {'radius': 2.236, 'circumference': 14.05, 'area': 15.708}

pi = 3.1416
print(circle(p1=(0, 0), p2=(1, 1)))
## {'radius': 1.414, 'circumference': 8.886, 'area': 6.283}

pi = 3.14
print(circle(p1=(3, 2.5), p2=(4, 4.5)))
## {'radius': 2.236, 'circumference': 14.043, 'area': 15.7}

# %%
def semi_axes(p1,p2,p3):
    x1,y1 = p1
    x2,y2 = p2
    x3,y3 = p3

    a = (((x2 - x1) ** 2) + ((y2 - y1) ** 2)) ** 0.5 
    b = (((x1 - x3) ** 2) + ((y3 - y1) ** 2)) ** 0.5 

    return a, b

# %%
print(semi_axes(p1=(3, 2.5), p2=(4.5, 2.5), p3=(3, 3.5)))
## (1.5, 1.0)

print(semi_axes(p1=(0, 0), p2=(0, 1), p3=(1, 0)))
## (1.0, 1.0)

# %%
def ellipse(p1,p2,p3):

    x1,y1 = p1
    x2,y2 = p2
    x3,y3 = p3

    def semi_axes():

        a = (((x2 - x1) ** 2) + ((y2 - y1) ** 2)) ** 0.5 
        b = (((x1 - x3) ** 2) + ((y3 - y1) ** 2)) ** 0.5 

        return a, b 
    
    def calculate_area_ellipse(a,b):

        S = pi * a * b
        
        return S 
    
    def calculate_length_ellipse(a,b):

        L = 2 * pi * (((a ** 2 + b ** 2) / 2) ** 0.5)

        return L 
    
    a,b = semi_axes()
    area = calculate_area_ellipse(a,b)
    length = calculate_length_ellipse(a,b)

    result = {'a': a, 'b': b, 'length': round(length,3), 'area': round(area,3)}
    
    return result

# %%
pi = 3.1416
print(ellipse(p1=(3, 2.5), p2=(4.5, 2.5), p3=(3, 3.5)))

## {'a': 1.5, 'b': 1.0, 'length': 8.01, 'area': 4.712}

pi = 3.1416
print(ellipse(p1=(0, 0), p2=(0, 1), p3=(1, 0)))

## {'a': 1.0, 'b': 1.0, 'length': 6.283, 'area': 3.142}

pi = 3.14
print(ellipse(p1=(0, 0), p2=(0, 1), p3=(1, 0)))
## {'a': 1.0, 'b': 1.0, 'length': 6.28, 'area': 3.14}

# %%
def sum_lst(lst):
    print(lst)

    if len(lst) == 0:
        return 0 
    
    return lst[0] + sum_lst(lst[1:])

# %%
my_lst = [10, 21, 24, 12]

# %%
print(sum_lst(my_lst))

# %% [markdown]
# Напишите рекурсивную функцию inv_sum_list(). На вход ей подаётся список из чисел, а она вычисляет сумму чисел, являющихся обратными к своим элементам. Обратным числу x называется число 1/x. Например, обратным числу 2 является 1/2 = 0.5.
#
# Например, если на вход программы подается список [10, 4, 8], то функция должна вернуть сумму 0.1 + 0.25 + 0.125 = 0.475.
#
# Если на вход функции передаётся пустой список, она должна возвращать 0.
#
# Пример вызова функции:
#
#
# print(inv_sum_list([10, 4, 8]))
# ## 0.475
#
# print(inv_sum_list([10, 1, 2, 4, 8]))
# ## 1.975
#
# print(inv_sum_list([]))
# ## 0

# %%
def inv_sum_list(x):

    if not x:
        return 0 
    
    return 1/x[0] + inv_sum_list(x[1:])

# %%
print(inv_sum_list([10, 4, 8]))
## 0.475

print(inv_sum_list([10, 1, 2, 4, 8]))
## 1.975

print(inv_sum_list([]))
## 0

# %% [markdown]
# Напишите рекурсивную функцию multiply_lst(lst), которая перемножает элементы заданного списка lst между собой. Если в функцию передаётся пустой список, она должна возвращать 1.
#
# Примеры вызова функции:
#
#
# print(multiply_lst([1, 5, 2, 1.5]))
# ## 15
# print(multiply_lst([]))
# ## 1

# %%
def multiply_lst(lst):

    if not lst:
        return 1 
    
    return lst[0] * multiply_lst(lst[1:])

# %%
print(multiply_lst([1, 5, 2, 1.5]))
## 15
print(multiply_lst([]))
## 1

# %%
def factorial(n):
    if n == 0:
        return 1 
    if n == 1:
        return 1 
    
    return factorial(n-1) * n

# %%
print(factorial(0))
print(factorial(3))
print(factorial(5))

# %% [markdown]
# Напишем функцию combination(n, k), которая позволит нам автоматически вычислять значение сочетания по формуле, приведённой выше, для любых n и k.
#
# При расчёте воспользуйтесь рекурсивной функцией factorial(), которую мы написали выше. Можете сделать её внутренней для функции combination() или независимой функцией, на ваш вкус. Главное, добавьте в свой код объявление функции factorial().
#
# Пример работы функции:
#
#
# print(combination(n=10, k=5))
# ## 252.0
# print(combination(n=12, k=3))
# ## 220.0
# print(combination(n=1, k=1))
# ## 1.0
# print(combination(n=0, k=0))
# ## 1.0

# %%
def combination(n, k):
    
    def factorial(n):
        if n == 0:
            return 1
        if n == 1:
            return 1
        
        return factorial(n-1) * n
    
    result = factorial(n) / (factorial(n - k) * factorial(k))

    return result

# %%
print(combination(n=10, k=5))
## 252.0
print(combination(n=12, k=3))
## 220.0
print(combination(n=1, k=1))
## 1.0
print(combination(n=0, k=0))
## 1.0

# %% [markdown]
# Числа Фибоначчи — пример последовательности, которую можно получить рекурсивно. Каждое число из последовательности является суммой двух предыдущих.
#
#
#
# Последовательность Фибоначчи активно применяется в комбинаторике и аналитике. О значении и вариантах применения чисел Фибоначчи вы можете прочитать в блоге Skillfactory.
#
# Можно записать рекурсивное выражение для расчёта n-ого числа из последовательности Фибоначчи:
#
#
#
# Напишите рекурсивную функцию fib(n), которая считает n-ое число Фибоначчи. Алгоритм работы функции:
#
# Если n=1 или n=2, вернуть 1, так как первый и второй элементы ряда Фибоначчи равны единице.
# Во всех остальных случаях вызвать эту же функцию с аргументами n-1 и n-2 и сложить результаты двух вызовов.
# Пример работы функци

# %%
def fib(n):
    if n == 1:
        return 1 
    if n == 2:
        return 1 

    return fib(n - 1) + fib (n - 2)

# %%
print(fib(1))
# 1
print(fib(2))
# 1
print(fib(6))
# 8

# %%
def even_odd(n):


    if n < 2:
        x = (n % 2 == 0)
        if x:
            return print("Число четное!")
        else:   
            return print("Число нечетное!")
    
    return even_odd(n - 2)

# %%
even_odd(8)

# %%
def check(letter, string):
    
    if not string:
        return 0 
    elif string[0] == letter:
        return 1 + check(letter, string[1:])
    else:
        return check(letter, string[1:])

# %%
print(check('b', 'abcdab'))

# %%
def even_odd(n):

    if n < 2:
        if n % 2 == 0:
            return print('Число четное')
        else:
            return print("Нечетное")

    return even_odd(n - 2)

# %%
even_odd(7)

# %% [markdown]
# Уровень 1: совсем база
#
# countdown(n)
# Вывести числа от n до 1.
# countdown(5)
# 5 4 3 2 1
# мы сделаем функцию которая вызовет сама себя и когда n == 1 мы вернм return 1 в остальных случаях будем вызывать функция от n - 1 пока не дойдем до 1 и соотвественно как мы только дойдем до нашего условия выхода n == 1  и сразу выйду такой план
#
#
#
# def countdown(n):
#
#     print(n)
#
#     if n == 1:
#         return
#
#     return countdown(n - 1)
#
# countdown(10)
#
#
# sum_n(n)
# Посчитать сумму от 1 до n.
#
#
# создаем функция сумму мы как будет считать а ну тут также только мы уже return n + снова вызываем функция только от n - 1 и вот уже будет n + n - 1  + функция и тд и отсюда следует сумма и как только дойдем до 1 тут уже напишем также как и в прошлом примере if n == 1 и он вернет 1 и тем самым и с 1 + всех числе посчитаем
#
# def sum_n(n):
#
#     if n == 1:
#         return 1
#
#     return n + sum_n(n - 1)
#
# sum_n(5)
#
#
# Да, давай лучше сделать нормальную лестницу, чтобы ты не уперся сразу в хард. Идея: сначала задачи, где рекурсия идет в одну сторону, потом строки/списки, потом ветвление типа Фибоначчи.
#
# Посчитать a в степени n.
# power(2, 4)  # 16
#
#
# так надо тепепь тут думать у нас есть два числа само число и степень двойки которое мы возводим это число и судя по подсказке которую нам дали
#
# return a * (power(a, b - 1))
#
# ну все да некст итерация a * a * (power(a, b - 1))
#
# и как только b == 0: * 1 число не поменяется после умножения и будет нужное количество итерация для опредления степени так все пишем
#
#
# def power(a,b):
#
#     if not b:
#         return 1
#
#     return a * power(a, b -1)
#
#
# power(2,4)
#
#
# count_letter(letter, string)
# Посчитать, сколько раз буква встречается в строке.
#
# Как это сделать
#
# ну буквы мы не будем менять в вызове return поэтому чтобы вызвать рекурсия мы воспользуемся
#
# if letter == string[0]:
#     return 1 + count_letter(letter, string[1:])
# else:
#     return count_letter(letter, string[1:])
#
#
#  def count_letter(letter, string):
#
#     if not string:
#         return 0
#     if letter == string[0]:
#         return 1 + count_letter(letter, string[1:])
#     else:
#         return count_letter(letter, string[1:])
#
# ну вот тут хз надо понять почему 0 и как он работает тут мне не очень понятно аа все забей все понятон 1 + функция и эта функция при вызове пустого списка вернет 0 и получится посчитаем количетсво элементов и вернем 0
#
#
# так ну как это сделать сейчас надо подум
#
# сначал мы создам и передает string
#
# потом а ну все логичено Return будет вызов функции + первый символ и мы когда будет делать рекурсию то первый символ свдиваегстя право
#
# функцикя + перпвый символ + первый символ  А ну выйдет из функции когда строка окажется пустой и вернем пусткую строку которую мы плюсанем к нашим символам
#
# def reverse(string):
#
#     if not string:
#         return ''
#
#     return reverse(string[1:]) + string[0]
#
# reverse('hello')
#
#
#
#
# тут вообще хз ну я думаю я ко всем потом вернусь еще раз перерешать так как сложно очень
#
# def palindrome(word):
#
#     if not word[:1] == word[-1:]:
#         return False
#
#     if len(word) < 1:
#         return True
#
#
#     return palindrome(word[1:-1])

# %% [markdown]
# подсказка сравнить первую и последнюю букву потом середину

# %% [markdown]
# Уровень 3: списки
# 7. sum_list(numbers)
# Посчитать сумму элементов списка.
#
# sum_list([1, 2, 3, 4])  # 10
# max_list(numbers)
# Найти максимум в списке.
# max_list([3, 10, 2, 7])  # 10
# contains(value, items)
# Проверить, есть ли элемент в списке.
# contains(7, [3, 10, 2, 7])  # True
# contains(5, [3, 10, 2, 7])  # False
# Уровень 4: чуть сложнее
# 10. fib(n)
# Число Фибоначчи.
#
# fib(6)  # 8
# digits_sum(n)
# Сумма цифр числа.
# digits_sum(1234)  # 10
# Подсказка:
#
# последняя цифра: n % 10
# оставшееся число: n // 10
# gcd(a, b)
# НОД двух чисел по алгоритму Евклида.
# gcd(12, 8)  # 4
# gcd(18, 12) # 6
# Подсказка:
#
# gcd(a, b) = gcd(b, a % b)
# Я бы тебе на сегодня дал только первые 4:
#
# countdown
# sum_n
# power
# count_letter
# Для каждой пиши себе 3 строки перед кодом:
#
# 1. Что является базовым случаем?
# 2. Как уменьшить задачу?
# 3. Что должен вернуть текущий вызов?
# Это прям тренирует рекурсивное мышление.

# %% [markdown]
# Уровень 3: списки
# 7. sum_list(numbers)
# Посчитать сумму элементов списка.
#
# sum_list([1, 2, 3, 4])  # 10
# max_list(numbers)
# Найти максимум в списке.
# max_list([3, 10, 2, 7])  # 10
# contains(value, items)
# Проверить, есть ли элемент в списке.
# contains(7, [3, 10, 2, 7])  # True
# contains(5, [3, 10, 2, 7])  # False

# %%
def sum_list(list):

    if not list:
        return 0

    return list[0] + sum_list(list[1:])

# %%
sum_list([1, 2, 3, 4, 5])

# %% [markdown]
# 1. Базовый случай
# 2. Как задача уменьшается
# 3. Что возвращает функция

# %% [markdown]
# 1) countdown(n)
# Вывести числа от n до 1
#
#     ну тут очевидно в ретурн вызывает снова функия от n - 1
#     перед этим просто перечатаем текущее значение n через prin
#     а условие когда мы дойдет до 0 return ничего не возращай

# %%
def countdown(n):
    
    if not n: 
        return
    
    print(n)

    return countdown(n-1)

countdown(5)

# %% [markdown]
# sum_n(n)
# Посчитать сумму чисел от 1 до n.
#
# ну тут аналогично с прошлым только мы уже в return выводим n + функция и потом заходим
#
# эту функцию считаемт дальше n + n - 1 + снова заходим в функия и это уже в стеке
#
# и пока не дойдем до 1 и тут тоже соотвественно если дойдем до 1 по факту в нашем ласт дереве вернем return 1 и начнем возвращаться обратно по ка не посчитаем все числа 5 + 4 + 3 + 2 + 1 как-то так

# %%
def sum_n(n):

    if n == 1:
        return 1 

    return n + sum_n(n-1)

# %%
sum_n(5)

# %% [markdown]
# power(a, n)
# Возвести число a в степень n.
# power(2, 4)  # 16
#
# на удивление честно я тогда сам не догадался решить и почему-то просто запомнил но сейчас в целом я понял суть
#
# тут насколько я помню ретюрн через * и тут прикол в том что мы именно может по факту преставить хд что это обычный цикл for через -1 и у нас в данном случае хд n работает как шаг итерации и на каждом шагу мы умножаем наше чисто a само на себя что и является по факту степенью числа
#
# допустти возьмем power (2,4)
#
# 2 * power(2, 4-1)
#
# 2 * 2 * ....(2, 3-1)'
#
# 2 * 2 * 2 * .... (2, 2-1)
#
# 2 * 2 * 2 * 2 * 1 все таки нам нужно вернеть не a как я хотел изнаачально а просто 1 чтобы все перемнодиось на 1 и результат неизменился
#
# так ладно я чет ошибся похоже где-то
#
# первая итерация 2 * функцию 4 -1
# вторая итерация 2 * 2 * функция 3 - 1
# третья итерация 2 * 2 * 2 * функция 2 -1 все да надо от 0 получается делать if так если if n == 1 то мы вернем просто 1 без 2 и бьулет по итогу функция ошибочно на 1 степень меньше возвращать бля сложно
# 4-ая итерация 2 * 2 * 2 * 1 так ч

# %%
def power(a, n):

    if n == 0:
        return 1 

    return a * power(a, n - 1)

power(2,4)

# %% [markdown]
# count_letter(letter, string)
# Посчитать количество заданных букв в строке.
#
# count_letter("a", "banana")  # 3
#
# вообще не помню давай вспоминать как  это можно сделетаь
#
# понятно ну очевидно нужно сравнить letter с первой буквой которую мы будет отрезать и заходит снова функцию if если это прокает тогда мы 1 + функция else просто функция
# и второе условие установки пишет когда слово '' return а что вернуть ну давай 0 вернем похер а я хз что ретурнать вообще идей нету
#
# а то но будет по итогу в конце 0 возврщаать если return 0 поставить а надо чтобы он возвраща посчитаненеый ответ ниже
#
# ток так знаю
#
# так теперь я пытаюсь понять как это работает хдд
#
# все идем по итерациям
#
# 1) передаем в функцию наши b и banana
#
#     а ну все тут просто я дал переменной score
#     1 + функция (anana)
#
# 2)  1 + функция

# %%
score = 0 

def count_letter(letter, string): 

    global score 

    if not string:
        return score 
    
    if letter == string[0]:
        score = 1 + count_letter(letter, string[1:])
        return score 
    else:
        return count_letter(letter, string[1:])


count_letter("a", "banana")

// это уже с подсказкйо как можно сделать проще намного и я тут понял сверху мой вариант из головы

def count_letter(letter,string):

    if not string:
        return 0 
    
    if letter == string[0]:
        return 1 + count_letter(letter, string[1:])
    else:
        return count_letter(letter, string[1:])

# %% [markdown]
# reverse_string(string)
# Развернуть строку.
#
# ну тут сначала вызов функции потом + первую функцию
#
# а стопаем когда будет пустая строка как и обычно в целом
#
# функция + h
# фунция + e + h
# функция + l + e + h
#
#  "" + ... l + e + h
#
#  olleh

# %%
def reverse_string(string):

    if not string:
        
        return ''

    return reverse_string(string[1:]) + string[0]

reverse_string("hello")  # "olleh"

# %% [markdown]
# is_palindrome(string)
# Проверить, одинаково ли строка читается слева направо и справа налево.
#
# так ну проверяем первую букву и последюнн если они == следовательно
#
# надо будет вернуть true а я хз кстати как это сделать мб сложвить + true + true + true и так до конца

# %%
word = 'тестим' 

word[1:-1]

# %%
result = False

def is_palindrome(string):
    
    global result 

    if not string:
        return result 

    if string[0] == string[-1]:
        result = True 
        return is_palindrome(string[1:-1])
    
    result = False
    return is_palindrome(string[1:-1])

# %%
is_palindrome('аааб')

# %%
def is_palindorme(string):

    if not string:
        return True 
    
    if string[0] != string[-1]:
        return False 
    
    return is_palindorme(string[1:-1])

# %% [markdown]
# sum_list(numbers)
# Посчитать сумму элементов списка.
#
# sum_list([1, 2, 3, 4])  # 10
#
# а ну все тут как со списком крч тожек самое делаем срез списка и все в целом

# %%
def sum_list(numbers):

    if not numbers:
        return 0 

    return numbers[0] + sum_list(numbers[1:])

# %% [markdown]
# max_list(numbers)
# Найти максимальный элемент списка.
# max_list([3, 10, 2, 7])  # 10

# %%
maximum = -999 

def max_list(numbers):

    global maximum 

    if len(numbers) == 1:
        return maximum 

    if maximum < numbers[1]:
        maximum = numbers[1]

    return max_list(numbers[1:])

# %%
max_list([3, 10, 2, 7])  # 10

# %%
def max_list(numbers):

    if len(numbers) == 1:
        return numbers[0]

    tail_maximum = max_list(numbers[1:])

    if numbers[0] > tail_maximum:
        return numbers[0]

    return tail_maximum

# %% [markdown]
# max_list([3, 10, 2, 7])
#
# передаем в нашу функцию
#
# видим первое условие if len(numbers) == 1
#
# очевидно нет
#
# идем дальше
#
# tail = maximum = max_list(numbers[1:]) происходит срез и вызов нашей функции и дальше оказывается мы не идем так как мы сделали рекурсивную функцию и она вызывает обратну нашу функцию
#
# идем дальше получчается опять if len  не прокает снова делаем срезу и уже заходим в функция с двумя элементами
#
# потом снова делаем срез
# и уже осталось одно число следовательон вызов функции tail_maximum = (max_list([7])) вернулся 7 так как условие if прокнуло
# следовательно на данный момент tail_maximum = 7
#
# дальше возвращаемся в стек (max_list([2,7])) а вот тут мы уже дальше да идем после того как обратно по стеку

# %% [markdown]
# ну тут я еще понимаю в целом вроде как и я это уже делал
#
# тут можно 1 число + вызываем функция со срезом и получиться что
#
# первом (нулевое) число из списка который в аргументу будет
#
# например тут sum_list([3, 10, 2, 7])  # 22
#
# 3 + функция со срезом
#
# 3 + 10 + функция со срезом
#
# 3 + 10 + 2 + функция со срезом
#
# 3 + 10 + 2 + 7 + ... сейчас подумаю условие остановки цикла ну вернем 0 просто и плюсанем ноль
#
# def sum_list(numbers):
#
#     if not numbers:
#         return 0
#
#     return numbers[0] + sum_list(numbers[1:])

# %%
def sum_list(numbers):

    if not numbers:
        return 0 

    return numbers[0] + sum_list(numbers[1:])

# %%
def multiply_list(numbers):

    if not numbers:
        return 1
    
    return numbers[0] + multiply_list(numbers[1:])

# %%
def count_even(numbers):

    if not numbers:
        return 0 


    if numbers[0] % 2:
        return count_even(numbers[1:])
    else:
        return 1 + count_even(numbers[1:])

# %%
count_even([1])  # 2

# %% [markdown]
# а ну +- похожая логика
#
# def count_greater(numbers, limit):
#     if not numbers:
#         return 0
#
#     if numbers[0] > limit:
#         return 1 + count_greater(numbers[1:], limit)
#
#     return count_greater(numbers[1:], limit)

# %%
def count_greater(numbers, limit):
    if not numbers:
        return 0 
    
    if numbers[0] > limit:
        return 1 + count_greater(numbers[1:], limit)
    
    return count_greater(numbers[1:], limit)

# %%
count_greater([3, 10, 2, 7], 5)  # 2

# %%
def only_positive(numbers):

    if not numbers:
        return []

    if numbers[0] > 0:
        return [numbers[0]] + only_positive(numbers[1:])
    
    return only_positive(numbers[1:])

# %%
only_positive([-3, 10, 0, -2, 7])  # [10, 7]

# %%
def all_positive(numbers):

    if not numbers:
        return True 
    
    if not numbers[0] > 0
        return False 
    
    return numbers[1:]

# %%
def contains(numbers, value):

    if not numbers:
        return False
    
    if numbers[0] == value:
        return True 
 
    return contains(numbers[1:], value)

# %% [markdown]
# так тут прям надо думать секунду

# %%
def larger(a, b):

    if a > b
        return a 
    
    return b

# %%
def max_list(numbers): 

    if len(numbers) == 1:
        return numbers[0]

    tail_maximum = max_list(numbers[1:])

    if tail_maximum > numbers[0]:
        return tail_maximum

    return numbers[0]
    
    # здесь нужно вернуть большее из:
    # numbers[0] и tail_maximum

# %%
def reverse_string(string):

    if not string:
        return ""
    
    return reverse_string(string[1:]) + string[0]

# %%
def is_palindrome(string):

    if not string:
        return True
    
    if string[0] != string[-1]:
        return False
    
    return is_palindrome(string[1:-1])

# %%
is_palindrome("")       # True

# %%
def digits_sum(numbers):

    if not numbers:
        return 0
    
    return numbers % 10 + digits_sum(numbers // 10)

# %%
def enter_account():
    def check_userdata():
        # Код для проверки логина и пароля return# Вызываем функцию check_userdata()
    check_userdata()
    # Код для входа в аккаунт

# Вызываем функцию для входа в аккаунт
enter_account()

# %%
def check_string(s):
    if len(s) <= 1:
        return True

    if s[0] == s[-1]:
        return check_string(s[1:-1])

    return False

# %% [markdown]
# Напишите рекурсивную функцию power(val, n), которая возводит число в заданную целую натуральную степень (или в степень 0).
#
# Использовать встроенный оператор ** для возведения в степень запрещено. Пользуйтесь только умножением *. Например, 2 ** 4 = (((2 * 2) * 2) * 2) = 16.
#
# В качестве первого аргумента функция принимает число, в качестве второго — желаемую степень.
#
# Примечание. В качестве базовых случаев для рекурсии возьмите условия, что любое число в степени 0 — 1, любое число в степени 1 — это же число.
#
# Пример работы функции:
#
#
# print(power(25, 0))
# # 1
# print(power(-5, 4))
# # 625

# %%
def power(val,n):

    if n == 0:
        return 1 


    return val * power(val, n-1)

# %%
print(power(-5, 4))

# %% [markdown]
# Задача №1
#
# Условие задачи
#
# Необходимо написать функцию add_brackets(), которая принимает на вход строку, содержащую только английские буквы (большие и маленькие). Функция должна добавлять в строку открывающиеся и закрывающиеся скобки по следующему образцу: "example" → "e(x(a(m)p)l)e".
#
# До середины добавляются открывающие скобки, после середины – закрывающие. Если длина строки равна чётному числу, в скобках, расположенных в середине, должно быть два символа: "card" → "c(ar)d" (но не "c(a()r)d").

# %% [markdown]
# арбуз
#
# а + ( функция ) + з
#
# а + ( + р ( б ) + у ) + з

# %%
def add_brackets(s):

    if len(s) <= 2:
        return s 
    
    return s[0] + '(' + add_brackets(s[1:-1]) + ')' + s[-1]

# %%
add_brackets('арбуз')

# %%
def add_brackets(s):
    # Вычисляем середину строки
    l = len(s) // 2
    # Если длина строки чётная
    if len(s) % 2 == 0:
        # В список исключений добавляются индексы l-1 и l
        for_exclude = [l-1, l]
    else: # Если нечётная
        # В список исключений добавляется индекс l
        for_exclude = [l]
    # Создаём пустую строку    
    result = ''
    # Создаём цикл по индексам строки
    for i in range(len(s)):
        # Если номер символа — в списке исключений, добавляем символ
        if i in for_exclude:
            result += s[i] 
        # Если номер символа меньше середины, добавляем символ и левую скобку
        elif i < l:
            result += s[i] + '(' 
        # Если мы перешли за середину строки, добавляем символ и правую скобку
        else:
            result += ')' + s[i]
    # Возвращаем результат
    return result

# %% [markdown]
# Задача №1
#
# Условие задачи
#
# Необходимо написать функцию add_brackets(), которая принимает на вход строку, содержащую только английские буквы (большие и маленькие). Функция должна добавлять в строку открывающиеся и закрывающиеся скобки по следующему образцу: "example" → "e(x(a(m)p)l)e".
#
# До середины добавляются открывающие скобки, после середины – закрывающие. Если длина строки равна чётному числу, в скобках, расположенных в середине, должно быть два символа: "card" → "c(ar)d" (но не "c(a()r)d").

# %%
def add_brackets(word):

    if len(word) <= 2:
        return word
    
    return word[0] + '(' + add_brackets(word[1:-1]) + ')' + word[-1]


add_brackets('еблаан')

# %% [markdown]
# Условие задачи
#
# Необходимо написать функцию add_brackets(), которая принимает на вход строку, содержащую только английские буквы (большие и маленькие). Функция должна добавлять в строку открывающиеся и закрывающиеся скобки по следующему образцу: "example" → "e(x(a(m)p)l)e".
#
# До середины добавляются открывающие скобки, после середины – закрывающие. Если длина строки равна чётному числу, в скобках, расположенных в середине, должно быть два символа: "card" → "c(ar)d" (но не "c(a()r)d").

# %%
def add_brackets(word):

    l = len(word) // 2 

    result = ''

    for i in range(len(word)):
        if i < l:
            result += word[i] + '('
        elif i > l:
            result += word[i] + ')'
        else:
            result += word[l]
    
    return result

# %%
add_brackets('card')

# %% [markdown]
# Дана строка, содержащая только английские буквы (большие и маленькие).
#
# Напишите рекурсивную функцию add_asterisk(). Она должна принимать в качестве аргумента строку и добавлять символ * (звёздочка) между буквами. Перед первой и после последней буквами символ * добавлять не нужно.
#
# Пример вызова функции:
#
#
# print(add_asterisk('hello'))
# ## h*e*l*l*o
# print(add_asterisk('LItBeoFLcSGBOFQxMHoIuDDWcqcVgkcRoAeocXO'))
# ## L*I*t*B*e*o*F*L*c*S*G*B*O*F*Q*x*M*H*o*I*u*D*D*W*c*q*c*V*g*k*c*R*o*A*e*o*c*X*O
# print(add_asterisk('gkafkafkKdaflkfa'))
# ## g*k*a*f*k*a*f*k*K*d*a*f*l*k*f*a

# %% [markdown]
# h * функция
#
# h * e * функция
#
# h * e  * l * функция
#
# h * e * l * l * функция  вот тут прокает условия и возвщрает
#
# h * e * l * l * прсто word[0]

# %%
def add_asterisk(word):

    if len(word) < 2:
        return word[0]
    
    return word[0] + '*' + add_asterisk(word[1:])

# %%
add_asterisk('hello')

# %%
matrix = [
    [1, 1, 0],
    [4, 2, 1],
    [0, 2, 1]
]

# %%
def flatten(lst):
    result = []

    for elem in lst:
        if isinstance(elem, list):
            result += flatten(elem)
        else:
            result.append(elem)

    return result

# %%
flatten(matrix)

# %%
def flatten(lst):
    result = []

    for i in lst:
        if isinstance(i, list):
            result += flatten(lst)
        else: 
            result.append(i)
    
    return result

# %%
|

# %%
matrix = [
    [1, 1, 0],
    [4, 2, 1],
    [0, 2, 1]
]

# %%
def matrix_list(x):
    result = []

    for i in x:
        if isinstance(i, list):
            result += matrix_list(i)
        else:
            result.append(i)
    f
    return result

# %%
matrix_list(matrix)

# %% [markdown]
# Другая важная операция в нейронных сетях — это суммирование элементов исходной матрицы.
#
# Напишите функцию sum_list(). Она принимает на вход вложенный список, элементами которого являются числа, и возвращает сумму всех элементов.
#
# Примеры вызова функции:
#
#
# matrix = [
#     [1, 1, 0],
#     [4, 2, 1],
#     [0, 2, 1]
# ]
# print(sum_list(matrix))
# ## 12
#
# matrix = [
#     [1, 1, [1, 2, 3], 0],
#     [4, 2, 1, [10, 52, 2]],
#     [0, 2, 1]
# ]
# print(sum_list(matrix))
# ## 82

# %%
matrix = [
    [1, 1, 0],
    [4, 2, 1],
    [0, 2, 1]
]

# %%
def sum_list(x):
     
    score = 0 

    for i in x:
        if isinstance(i,list):
            score += sum_matrix(i)
        else:
            score += i 
    
    return score

# %%
sum_matrix(matrix)

# %% [markdown]
# forum_messages = {
#     1: {'parrent_link': None, 'child_link': [2, 3]},
#     2: {'parrent_link': 1, 'child_link': [4]},
#     3: {'parrent_link': 1, 'child_link': []},
#     4: {'parrent_link': 2, 'child_link': []}
# }
#
# 1. Кто находится на нулевом уровне?  дети с id 2 и id 3
# 2. Кто дети у id=1?  id 2  id 3
# 3. Кто родитель у id=4? id 2
# 4. На каком уровне id=4? 2 уровень
# 5. У кого нет детей? у id 3  1id родителя

# %% [markdown]
# Задание 2
#
# forum_messages = {
#     10: {'parrent_link': None, 'child_link': [11, 12]},
#     11: {'parrent_link': 10, 'child_link': []},
#     12: {'parrent_link': 10, 'child_link': [13]},
#     13: {'parrent_link': 12, 'child_link': [14]},
#     14: {'parrent_link': 13, 'child_link': []}
# }
# Попробуй сам:
#
# 1. Кто корень?  10 id
# 2. Кто дети у id=10?   id 11 и id 12
# 3. Кто родитель у id=13?  id 12
# 4. На каком уровне id=14?  на 3 уровне по идеи
# 5. У кого пустой child_link? у id 11 и id 12

# %% [markdown]
# 1. Найти сообщение по msg_id
# 2. Запомнить его родителя
# 3. Запомнить его детей
# 4. Удалить само сообщение из словаря
# 5. Если родитель существует и он еще есть в messages:
#    удалить msg_id из child_link родителя
# 6. Для каждого ребенка:
#    повторить всё то же самое
# 7. Вернуть messages

# %%
forum_messages = {
    1: {'parrent_link': None, 'child_link': [3, 4]},
    2: {'parrent_link': None, 'child_link': [5]},
    3: {'parrent_link': 1, 'child_link': [6]},
    4: {'parrent_link': 1, 'child_link': []},
    5: {'parrent_link': 2, 'child_link': []},
    6: {'parrent_link': 3, 'child_link': []}
}

# %%
# Функция для удаления сообщения на форуме и всех его потомков
def delete_message(messages, msg_id):
    # Удаляем из словаря сообщение с идентификатором msg_id
    # Метод pop() возвращает значение, лежащее по удаляемому ключу
    result = messages.pop(msg_id)
    # Получаем идентификатор родителя
    parrent_link = result['parrent_link']
    # Получаем список идентификаторов потомков
    child_link = result['child_link']
    # Если у сообщения был родитель и он ещё не был удален
    # Эта запись будет аналогична parrent_link is not None
    if parrent_link and parrent_link in messages:
        # Обращаемся к словарю messages по ключу родителя
        # Удаляем потомка из списка потомков
        messages[parrent_link]['child_link'].remove(msg_id)
    # Если у сообщения были потомки
    # Эта запись будет аналогична child_link == [<значение_1>, <значение_2>, ...]
    if child_link:
        # В цикле проходимся по всем потомкам 
        for child_id in child_link:
            # И повторяем те же самые действия для каждого из них
            # (рекурсивно вызываем функцию delete_message)
            delete_message(messages, msg_id=child_id)
    return messages

# %%
def delete_messagae(text, id_del):
    
    result = text.pop(id_del)

    parents = result['parrent_link']

    kids = result['child_link'] 

    if parents is not None:
        text[parents]['child_link'].remove[id_del]
    
    if kids:
        for i in kids:
            delete_message(text, id_del = i)
    
    return text

# %% [markdown]
# forum_messages = {
#     1: {'parrent_link': None, 'child_link': [3, 4]},
#     2: {'parrent_link': None, 'child_link': [5]},
#     3: {'parrent_link': 1, 'child_link': [6]},
#     4: {'parrent_link': 1, 'child_link': []},
#     5: {'parrent_link': 2, 'child_link': []},
#     6: {'parrent_link': 3, 'child_link': []}
# }

# %%
def delete_message(text, id_del):
    result = text.pop(id_del)

    parent = result['parrent_link']
    kids = result['child_link']

    if parent is not None and parent in text:
        text[parent]['child_link'].remove(id_del)

    for kid in kids:
        delete_message(text, kid)

    return text

# %% [markdown]
# Пусть у нас есть словарь input_dict следующего вида:
#
#
# input_dict = {
#     'key1': {
#         'key2': ['value1', 'value2'],
#         'key3': {
#             'key4': ['value3']
#         }
#     },
#     'key5': {
#         'key6': {
#             'key7': ['value3', 'value5', 'value6']
#         }
#     }
# }
# Мы хотим напечатать этот словарь следующим образом:
#
#
# key1 ->
#   key2 ->
#     ['value1', 'value2']
#   key3 ->
#     key4 ->
#       ['value3']
# key5 ->
#   key6 ->
#     key7 ->
#       ['value3', 'value5', 'value6']
# Для этого мы написали рекурсивную функцию print_dict():
#
#
# def print_dict(input_data, level=0):
#     # Если input_data — словарь
#     if type(input_data) is dict:
#         # Создаём цикл по ключам словаря
#         for key in input_data:
#             # Выводим ключ в формате "<пробелы> <имя ключа> ->"
#             print('  ' * level + '{} ->'.format(key))
#             # Повторяем те же операции для каждого значения словаря
#             print_dict(input_data[key], level=level)
#     else: # В противном случае
#         # Выводим значения в формате "<пробелы> <значения>"
#         print('  ' * level + str(input_data))
# Однако мы где-то допустили ошибку в функции и она печатает словарь в следующем виде:
#
#
# key1 ->
# key2 ->
# ['value1', 'value2']
# key3 ->
# key4 ->
# ['value3']
# key5 ->
# key6 ->
# key7 ->
# ['value3', 'value5', 'value6']
# Разберитесь в функции print_dict() и исправьте её так, чтобы словарь печатался в нужном формате.

# %%
input_dict = {
    'key1': {
        'key2': ['value1', 'value2'], 
        'key3': {
            'key4': ['value3']
        }
    }, 
    'key5': {
        'key6': {
            'key7': ['value3', 'value5', 'value6']
        }
    }
}

# %% [markdown]
# Мы хотим напечатать этот словарь следующим образом:

# %% [markdown]
# key1 ->
#   key2 ->
#     ['value1', 'value2']
#   key3 ->
#     key4 ->
#       ['value3']
# key5 ->
#   key6 ->
#     key7 ->
#       ['value3', 'value5', 'value6']

# %% [markdown]
# Для этого мы написали рекурсивную функцию print_dict():

# %%
def print_dict(x):

    for i, y in enumerate(x):

        if isinstance(y, dict):
            print(f"{' ' * i}{y}")

        if isinstance(y, list):
            print(f"{' ' * i} ->{y}")

# %%
print_dict(input_dict)

# %%
def print_dict(x):
    lvl = 0 

    if isinstance(x, dict):
        for i in x:
            print(f'{' '* lvl} ->{i}')
            lvl += 1 
            print_dict(x[i])


print_dict(input_dict)

# %%
def print_dict(input_data, level=0):
    # Если input_data — словарь 
    if type(input_data) is dict:
        # Создаём цикл по ключам словаря
        for key in input_data:
            # Выводим ключ в формате "<пробелы> <имя ключа> ->"
            print('  ' * level + '{} ->'.format(key))
            # Повторяем те же операции для каждого значения словаря
            print_dict(input_data[key], level = level + 1)  
    else: # В противном случае
        # Выводим значения в формате "<пробелы> <значения>"
        print('  ' * level + str(input_data))

# %%
print_dict(input_dict)

# %%
d = print 

d('xyeq')

# %%
words_list = ["We're", 'in', 'a', 'small', 'village', 'near', 'Chicago', 'My', "cousin's", 'getting', 'married.']

# %%
def len_lst(x):
    len_lst_on_def = []

    for i in x:
        len_lst_on_def.append(len(i))
    
    return len_lst_on_def

# %%
len_lst(words_list)

# %%
test = map(len, words_list)

# %%
print(list(test))

# %%
expenses = [(101, 203, 167), (214, 351, 752), (255, 2537), (852, 362, 366)]

new_lst = []

for i in expenses:
    new_lst.append(max(i))
    
    
print (new_lst)

# %%
test = list(map(max, expenses))

# %% [markdown]
# Дан список чисел old_list, где все числа имеют строковый тип данных. Чтобы работать с ними, вам нужно превратить их в целое число. Напишите код, который позволит это сделать. Новое значение списка присвойте переменной new_list. В решении используйте функцию map().
#
# Примеры работы программы:
#
#
# old_list = ['1', '2', '3', '4', '5', '6', '7']
#
# ## new_list = [1, 2, 3, 4, 5, 6, 7]
# old_list = ['101', '203', '33', '45', '51', '46', '77']
#
# ## new_list = [101, 203, 33, 45, 51, 46, 77]

# %%
old_list = ['1', '2', '3', '4', '5', '6', '7']

new_list = list(map(int,old_list))

# %%
print(new_list)

# %% [markdown]
# Вам передали информацию о расходах за шесть месяцев. Данные содержатся в списке expenses. В этом списке расходы по каждому месяцу хранятся в отдельных списках. С помощью map создайте новый список expenses_sum, содержащий суммы расходов по каждому месяцу.
#
# Примеры работы программы:
#
#
# expenses = [[2356, 4537, 8678], [7395, 1298, 6500, 4791],[6341, 3408], [1105, 8374, 5914], [1024, 7333], [3500, 2008, 9375, 6144]]
# ## expenses_sum = [15571, 19984, 9749, 15393, 8357, 21027]
#
# expenses = [[101, 203, 167], [214, 351, 135, 752],[255, 2537], [852, 362, 366]]
# ## expenses_sum = [471, 1452, 2792, 1580]

# %%
expenses = [[2356, 4537, 8678], [7395, 1298, 6500, 4791],[6341, 3408], [1105, 8374, 5914], [1024, 7333], [3500, 2008, 9375, 6144]]  
expenses_sum = list(map(sum, expenses))
expenses_sum

# %%
# Список зарплат
salaries = [1500, 2200, 3500, 1200]

# %%
def salary_tax(i):
    if i <= 1000:
        return i * 0.05
    elif i >= 2000:
        return i * 0.15
    else:
        return i * 0.1
    

testt = list(map(salary_tax, salaries))

# %%
testt = list(map(salary_tax, salaries))

# %%
testt

# %%
quotes_dict = {
    'Преступление и наказание': 'А знаешь ли... что низкие потолки и тесные комнаты душу и ум теснят.', 
    'Война и мир': 'И нет величия там, где нет простоты, добра и правды.', 
    'Анна Каренина': 'Если искать совершенства, то никогда не будешь доволен.', 
    'Детство': 'Правил у нас много, а правды нет.', 
    'Колесо времени': 'Ничто так на соединяет людей, как улыбка.'
}

# %%
print(list(quotes_dict.items()))

# %%
def preprocessing_quotes(x):
    name, text = x 
    text = text.lower()
    text = text.replace(',','')
    text = text.replace('.','')
    words = text.split(' ')
    return (name,words)

# Проверяем, как работает функция

# %%
test_text = ('Детство', 'Правил у нас много, а правды нет.')

print(preprocessing_quotes(test_text))

# %%
result = list(map(preprocessing_quotes, quotes_dict.items()))

# %%
print(result)

# %% [markdown]
# У вас есть словарь prices, содержащий цены на литровые упаковки соков в интернет-магазине. Вам необходимо применить к этим ценам скидку 5 % и округлить полученное значение до двух знаков после запятой. Новый словарь положите в переменную new_prices. В решении используйте функцию map().
#
# Примеры работы программы:
#
#
# prices = {'яблоко': 99, 'апельсин': 99, 'вишня': 147, 'персик': 145, 'грейпфрут': 139}
# ## new_prices = {'яблоко': 94.05, 'апельсин': 94.05, 'вишня': 139.65, 'персик': 137.75, 'грейпфрут': 132.05}
#
# prices = {'Штаны': 2100, 'Кофта': 1520, 'Свитер': 3520, 'Галстук': 780, 'Ремень': 1390}
# ## new_prices = {'Штаны': 1995.0, 'Кофта': 1444.0, 'Свитер': 3344.0, 'Галстук': 741.0, 'Ремень': 1320.5}
# П

# %%
prices = {'яблоко': 99, 'апельсин': 99, 'вишня': 147, 'персик': 145, 'грейпфрут': 139}

# %%
def discount (i):
    name, price = i 
    price = round(price * 0.95, 2)
    return (name, price)

result = dict(map(discount, prices.items()))

result

# %%
number_list = [11, 12, 13, 14, 15, 16]

# %%
result = list(map(lambda x: x ** 3, number_list))

# %%
result

# %%
str_list = ['шалаш', 'казак', 'палиндром', 'рвал дед лавр']

# %%
result = list(map(lambda x: x[::-1], str_list))

# %%
result

# %%
number_list = [11, 12, 13, 14, 15, 16]
result = list(map(lambda i: i ** 3, number_list))
print(result)

# %%
str_list = ['шалаш', 'казак', 'палиндром', 'рвал дед лавр']

resultt = list(map(lambda i: i[::-1], str_list))

print(resultt)

# %% [markdown]
# Есть список кортежей. Один кортеж соответствует одному объекту (в Data Science его часто называется наблюдением) и состоит из трёх элементов (признаков объекта):
#
# имени человека;
# его роста (в метрах);
# веса (в килограммах).
# data = [('Amanda', 1.61, 51), ('Patricia', 1.65, 61), ('Marcos', 1.91, 101)]
# Необходимо создать список, состоящий из индексов массы тела для каждого человека. Индекс массы тела достаточно будет округлить до одного знака после запятой.

# %%
data = [('Amanda', 1.61, 51), ('Patricia', 1.65, 61), ('Marcos', 1.91, 101)]

# %%
bmi = lambda x: (x[0], x[1], x[2], round(x[2] / (x[1] ** 2),1))

# %%
bmi(('Amanda', 1.61, 51))

# %%
result = list(map(bmi, data))

# %%
print(result)

# %% [markdown]
# Представьте, что мы пытаемся выгрузить несколько новостей с сайта kommersant.ru. У вас есть список путей до интересующих вас статей.
#
# Пример такого списка:
#
#
# docs = [
# '//doc/5041434?query=data%20science',
# '//doc/5041567?query=data%20science',
# '//doc/4283670?query=data%20science',
# '//doc/3712659?query=data%20science',
# '//doc/4997267?query=data%20science',
# '//doc/4372673?query=data%20science',
# '//doc/3779060?query=data%20science',
# '//doc/3495410?query=data%20science',
# '//doc/4308832?query=data%20science',
# '//doc/4079881?query=data%20science'
# ]
# Как вы видите, представленные ссылки на статьи — неполные: в них не хватает адреса самого сайта — "https://www.kommersant.ru".
#
# Ваша задача составить новый список links, в котором будут храниться полные ссылки до статей на сайте «Коммерсанта». Например, полная ссылка на первую статью будет иметь вид: "https://www.kommersant.ru//doc/5041434?query=data%20science".
#
# Для решения задачи используйте функцию map().
#
# К каждому элементу списка docs (размер списка может быть любым) примените функцию-преобразование, которая добавляет к ссылке на начальную страницу сайта путь до статьи из списка docs.
#
# Результат работы функции map() оберните в список и занесите в переменную links.
#
# Примеры работы программы:
#
#
# docs = ['//doc/5041434?query=data%20science','//doc/5041567?query=data%20science', '//doc/4283670?query=data%20science','//doc/3712659?query=data%20science', '//doc/4997267?query=data%20science'
# ]
# ## links = ['https://www.kommersant.ru//doc/5041434?query=data%20science', 'https://www.kommersant.ru//doc/5041567?query=data%20science', 'https://www.kommersant.ru//doc/4283670?query=data%20science', 'https://www.kommersant.ru//doc/3712659?query=data%20science', 'https://www.kommersant.ru//doc/4997267?query=data%20science']
#
# docs = ['//doc/5041434?query=data%20science','//doc/5041567?query=data%20science','//doc/4283670?query=data%20science','//doc/3712659?query=data%20science','//doc/4997267?query=data%20science','//doc/4372673?query=data%20science','//doc/3779060?query=data%20science','//doc/3495410?query=data%20science','//doc/4308832?query=data%20science','//doc/4079881?query=data%20science'
# ]
# ## links = ['https://www.kommersant.ru//doc/5041434?query=data%20science', 'https://www.kommersant.ru//doc/5041567?query=data%20science', 'https://www.kommersant.ru//doc/4283670?query=data%20science', 'https://www.kommersant.ru//doc/3712659?query=data%20science', 'https://www.kommersant.ru//doc/4997267?query=data%20science', 'https://www.kommersant.ru//doc/4372673?query=data%20science', 'https://www.kommersant.ru//doc/3779060?query=data%20science', 'https://www.kommersant.ru//doc/3495410?query=data%20science', 'https://www.kommersant.ru//doc/4308832?query=data%20science', 'https://www.kommersant.ru//doc/4079881?query=data%20science']

# %%
docs = [  
'//doc/5041434?query=data%20science',  
'//doc/5041567?query=data%20science',  
'//doc/4283670?query=data%20science',  
'//doc/3712659?query=data%20science',  
'//doc/4997267?query=data%20science',  
'//doc/4372673?query=data%20science',  
'//doc/3779060?query=data%20science',  
'//doc/3495410?query=data%20science',  
'//doc/4308832?query=data%20science',  
'//doc/4079881?query=data%20science'  
]

# %%
links = list(map(lambda x: "https://www.kommersant.ru" + x, docs))

# %%
print(links)

# %% [markdown]
# Допустим, мы решаем задачу оценки стоимости недвижимости.
#
# В списке data представлены усреднённые данные по домам в районах Бостона. Каждый вложенный в список кортеж описывает средние данные по одному району (для примера представлены данные о семи участках). В этом кортеже представлены следующие признаки (в порядке следования):
#
# x₁ — уровень преступности на душу населения по городам;
#
# x₂ — среднее количество комнат в доме;
#
# x₃ — доля зданий, построенных до 1940 г. и занимаемых владельцами;
#
# x₄ — полная ставка налога на имущество за каждые 10 000 долларов стоимости;
#
# x₅ — процент населения с низким статусом.
#
# Пример данных:
#
#
# data = [(0.00632, 6.575, 65.2, 296.0, 4.98),
# (0.02731, 6.421, 78.9, 242.0, 9.14),
# (0.02729, 7.185, 61.1, 242.0, 4.03),
# (0.03237, 6.998, 45.8, 222.0, 2.94),
# (0.06905, 7.147, 54.2, 222.0, 5.33),
# (0.02985, 6.43, 58.7, 222.0, 5.21),
# (0.08829, 6.012, 66.6, 311.0, 12.43)]
# Добавим в наш набор данных новый признак, который будет равен произведению трёх признаков — x₁, x₄ и x₅.
#
# В результате выполнения программы у вас должен получиться список кортежей. Каждый кортеж должен состоять из шести элементов: первые пять — исходные признаки, а последний, шестой элемент — сгенерированный признак, округлённый до второго знака после запятой.
#
# Результирующий список кортежей занесите в переменную updated_data.
#
# Например, для исходного списка data, представленного выше, у вас должен получиться следующий список updated_data:
#
#
# [(0.00632, 6.575, 65.2, 296.0, 4.98, 9.32),
# (0.02731, 6.421, 78.9, 242.0, 9.14, 60.41),
# (0.02729, 7.185, 61.1, 242.0, 4.03, 26.61),
# (0.03237, 6.998, 45.8, 222.0, 2.94, 21.13),
# (0.06905, 7.147, 54.2, 222.0, 5.33, 81.7),
# (0.02985, 6.43, 58.7, 222.0, 5.21, 34.53),
# (0.08829, 6.012, 66.6, 311.0, 12.43, 341.31)]

# %%
data = [(0.00632, 6.575, 65.2, 296.0, 4.98),  
(0.02731, 6.421, 78.9, 242.0, 9.14),  
(0.02729, 7.185, 61.1, 242.0, 4.03),  
(0.03237, 6.998, 45.8, 222.0, 2.94),  
(0.06905, 7.147, 54.2, 222.0, 5.33),  
(0.02985, 6.43, 58.7, 222.0, 5.21),  
(0.08829, 6.012, 66.6, 311.0, 12.43)]

# new_sign = lambda x: (x[0], x[1], x[2], x[3], x[4], round(x[0] * x[3] * x[4], 2))

new_sign = lambda x: (*x, round(x[0] * x[3] * x[4], 2))

updated_data = list(map(new_sign, data))

print(updated_data)

# %%
new_sign = lambda x: (x[0], x[1], x[2], x[3], x[4], round(x[0] * x[3] * x[4], 2))

# %%
result_plus_new_sigh = list(map(new_sign, data))

# %%
print(result_plus_new_sigh)

# %%
words_list = ["We're", 'in', 'a', 'small', 'village', 'near', 'Chicago', 'My', "cousin's", 'getting', 'married.']

# %%
even_list = []

for i in words_list:

    if not len(i) % 2:
        even_list.append(i)


even_list

# %%
def even_list(x):
    return len(x) % 2 == 0

even = filter(even_list, words_list)

print(list(even))

# %%
words_list = ["We're", 'in', 'a', 'small', 'village', 'near', 'Chicago', 'My', "cousin's", 'getting', 'married.']

# %%
def even_lst(x):
    return len(x) % 2 == 0

even = list(filter(even_lst, words_list))

print(even)

# %%
even = list(filter(lambda x: len(x) % 2 == 0, words_list))

# %%
print(even)

# %%
str_tuple = ("Москва", "15.1 см", "зацвело", "было пол 5 утра", "рассвет")

# %%
only_str = tuple(filter(lambda x: x.isalpha(), str_tuple)) 

print(only_str)

# %%
data = [
    ("FPW-2.0_D", "Бонус: Тренажер по HTML", 10, 100, 10),
    ("FPW-2.0", "Бонус: Тренажер по JavaScript", 9.2, 70, 180),
    ("FPW-2.0_D", "Бонус: Тренажер по React", 8.5, 66.67, 68),
    ("FPW-2.0", "Бонусный: IT в современном мире", 8.64, 83.74, 856),
    ("FPW-2.0", "Бонусный: Введение", 8.73, 56.24, 745),
    ("FPW-2.0", "Бонус: D1. Знакомство с Django (NEW)", 9.76, 95.24, 21),
    ("FPW-2.0_D", "Бонус: D2. Модели (NEW)", 9.44, 77.78, 18)
]

# %%
def sort_data(x):
    return x[0] == "FPW-2.0" and x[3] >= 70 and x[4] > 50

result_sort_data = list(filter(sort_data, data))

print(result_sort_data)

# %%
def filter_module(module):
    # Распаковываем кортеж на пять переменных
    code, name, avg_votes, nessa, count = module
    # Создаём условия 
    cond_1 = code == "FPW-2.0"
    cond_2 = nessa >= 70
    cond_3 = count > 50
    # Условия должны выполняться одновременно
    return cond_1 and cond_2 and cond_3

# %% [markdown]
# У вас есть список prices стоимости аренды помещения под магазин за месяц. Вам необходимо создать список filtered_prices из стоимости, которая не выше 30000, чтобы уложиться в бюджет. В решении примените filter() и lambda.
#
# Примеры работы программы:
#
#
# prices = [34562, 66572, 25683, 17683, 56389, 28973]
# ## filtered_prices = [25683, 17683, 28973]
#
# prices = [21490, 24901, 24901, 34901, 24142, 64521]
# ## filtered_prices = [21490, 24901, 24901, 24142]

# %%
prices = [34562, 66572, 25683, 17683, 56389, 28973] 

filtered_prices = list(filter(lambda x: x <= 30000, prices))

print(filtered_prices)

# %% [markdown]
# Допустим, вы работаете в отделе разработки в МФЦ. Центр предоставляет некоторый спектр услуг многодетным семьям. Необходимо создать функциональность, которая позволяет отфильтровать среди всех запрашиваемых пользователем услуг (их количество произвольное) только те, которые предоставляются многодетным семьям.
#
# При решении задачи вам понадобится список услуг, предоставляемых многодетным семьям:
#
#
# family_list = [
#     'certificate of a large family',
#     'social card',
#     'maternity capital',
#     'parking permit',
#     'tax benefit',
#     'reimbursement of expenses',
#     "compensation for the purchase of children's goods"
#  ]
# Реализуйте функцию filter_family(): на вход подаётся список с названием услуг МФЦ, а в результате возвращается список услуг, которые могут быть оказаны только многодетной семье.
#
# Для фильтрации входного списка аргументов используйте функцию filter().
#
# Примеры работы функции:
#
#
# print(filter_family(['newborn registration', 'parking permit',
#                      'maternity capital', 'tax benefit', 'medical policy']))
# ## ['parking permit', 'maternity capital', 'tax benefit']

# %%
family_list = [
    'certificate of a large family',
    'social card',
    'maternity capital',
    'parking permit',
    'tax benefit',
    'reimbursement of expenses',
    "compensation for the purchase of children's goods"
 ]

def filter_family(x):
    result = list(filter(lambda x: x in family_list, x))
    return result 

print(filter_family(['newborn registration', 'parking permit', 
                     'maternity capital', 'tax benefit', 'medical policy']))

# %%
# Список из слов
words_list = ["We're", 'in', 'a', 'small', 'village', 'near', 'Chicago', 'My', "cousin's", 'getting', 'married.']

# %%
counts = []

for i in words_list:

    if len(i) >= 5:
        result_tuple = (i, i.lower().count('a'))
        counts.append(result_tuple)
    
print(counts)

# %%
# Список из слов
words_list = ["We're", 'in', 'a', 'small', 'village', 'near', 'Chicago', 'My', "cousin's", 'getting', 'married.'] 


filter_words_list = filter(lambda x: len(x) >= 5, words_list)

result = map(lambda x: (x, x.lower().count('a')), filter_words_list)

print(list(result))
# Out:
# [("We're", 0), ('small', 1), ('village', 1), ('Chicago', 1), ("cousin's", 0), ('getting', 0), ('married.', 1)]

# %% [markdown]
# имени человека;
# его роста (в метрах);
# веса (в килограммах).

# %%
# Выгрузка данных о параметрах человеческого тела
data = [
    ('Amanda', 1.61, 51),
    ('Patricia', 1.65, 61), 
    ('Marcos', 1.91, 101),
    ('Andrey', 1.79, 61),
    ('Nikos', 1.57, 78),
    ('Felicia', 1.63, 56),
    ('Lubov', 1.53, 34)
]

# %%
bmi = map(lambda x: (*x, x[2]/(x[1] ** 2)), data)

result = filter(lambda x: 18.5 <= x[3] <= 25, bmi)

print(list(result))

# %% [markdown]
# Мы снова занимаемся регистрацией пользователей. В нашем распоряжении есть список кортежей reg. В каждом кортеже хранится информация о зарегистрированном пользователе и его дате рождения в формате: Фамилия, Имя, день, месяц, год:
#
#
# reg = [('Ivanov', 'Sergej', 24, 9, 1995),
#       ('Smith', 'John', 13, 2, 2003),
#       ('Petrova', 'Maria', 13, 3, 2003)]
# Выберите из списка reg только те записи, в которых год рождения пользователя больше 2000 (2001, 2002 и т. д.). Из оставшихся записей составьте новый список кортежей, в котором фамилия и имя объединены в одну строку по следующему шаблону: Фамилия И.
#
# Обратите внимание на точку после сокращения имени!
#
# Например, для представленного списка reg результирующий список кортежей new_reg должен иметь вид:
#
#
# new_reg = [('Smith J.', 13, 2, 2003), ('Petrova M.', 13, 3, 2003)]
# Для решения задачи используйте конвейер из filter() и map().
#
# Обратите внимание: задана двумерная структура, то есть функции фильтрации и преобразования, указываемые в аргументах в filter() и map(), принимают на вход один кортеж и должны обрабатывать его.
#
# В результате работы программы должен быть создан обновленный список кортежей с именем переменной new_reg.

# %%
reg = [('Ivanov', 'Sergej', 24, 9, 1995),
      ('Smith', 'John', 13, 2, 2003),
      ('Petrova', 'Maria', 13, 3, 2003)]


result_filter = filter(lambda x: x[4] > 2000, reg)


new_reg = map(lambda x: ((x[0] + ' ' + x[1][0] + '.'), x[2], x[3], x[4]), result_filter)

print(list(new_reg))

# %%
# Объявляем функцию-преобразование для кортежа
def update_tuple(arg):
    # Выделяем фамилию из кортежа
    surname = arg[0]
    # Выделяем имя из кортежа
    name = arg[1]
    # Создаём новую запись: фамилия + пробел + первая буква имени + точка
    new_surname = surname + ' ' + name[0] + '.'
    # Возвращаем обновлённый кортеж
    return (new_surname, arg[2], arg[3], arg[4])

# Фильтруем записи по условию, что последний элемент кортежа > 2000
filter_reg = filter(lambda x: x[-1] > 2000, reg)
# Применяем функцию-преобразование к каждому кортежу из списка и создаём новый список
new_reg = list(map(update_tuple, filter_reg))

# %% [markdown]
# Вернёмся к задаче по оценке стоимости недвижимости.
#
# В списке data представлены усреднённые данные по домам в районах Бостона. Каждый вложенный в список кортеж описывает средние данные по одному району (для примера представлены данные о семи участках). В этом кортеже представлены следующие признаки (в порядке следования):
#
# x₁ — уровень преступности на душу населения по городам;
# x₂ — среднее количество комнат в доме;
# x₃ — доля зданий, построенных до 1940 г. и занимаемых владельцами;
# x₄ — полная ставка налога на имущество за каждые 10 000 долларов стоимости;
# x₅ — процент населения с низким статусом.
# Пример данных:
#
#
# data = [(0.00632, 6.575, 65.2, 296.0, 4.98),
#  (0.02731, 6.421, 78.9, 242.0, 9.14),
#  (0.02729, 7.185, 61.1, 242.0, 4.03),
#  (0.03237, 6.998, 45.8, 222.0, 2.94),
#  (0.06905, 7.147, 54.2, 222.0, 5.33),
#  (0.02985, 6.43, 58.7, 222.0, 5.21),
#  (0.08829, 6.012, 66.6, 311.0, 12.43)]
# Добавьте в набор данных новый признак, который будет равен произведению трёх признаков — x₁, x₄ и x₅. А затем выберите из исходного списка только те данные, для которых значение нового признака > 60.
#
# В результате выполнения программы у вас должен получиться список кортежей. Каждый кортеж должен состоять из шести элементов: первые пять — исходные признаки, а шестой элемент — сгенерированный признак, округлённый до двух знаков после запятой. Результирующий список кортежей занесите в переменную filtered_data.
#
# Например, для исходного списка data, представленного выше, у вас должен получиться следующий список filtered_data:
#
#
# [(0.02731, 6.421, 78.9, 242.0, 9.14, 60.41),
#  (0.06905, 7.147, 54.2, 222.0, 5.33, 81.7),
#  (0.08829, 6.012, 66.6, 311.0, 12.43, 341.31)]
# 36894

# %%
data = [(0.00632, 6.575, 65.2, 296.0, 4.98),
 (0.02731, 6.421, 78.9, 242.0, 9.14),
 (0.02729, 7.185, 61.1, 242.0, 4.03),
 (0.03237, 6.998, 45.8, 222.0, 2.94),
 (0.06905, 7.147, 54.2, 222.0, 5.33),
 (0.02985, 6.43, 58.7, 222.0, 5.21),
 (0.08829, 6.012, 66.6, 311.0, 12.43)]

# %%
map_data = list(map(lambda x: (*x, round((x[0]*x[3]*x[4]),2)), data))

filtered_data = list(filter(lambda x: x[5] > 60, map_data))

# %%
print(filtered_data)

# %%
import numpy as np

# %% [markdown]
# Далее нам нужно написать функцию которая возвращает количество попыток: Задачем count = 0, затем пишем функцию которая принимает x = number

# %%
import numpy as np


def test(x:int = 1) -> int:
    
    count = 0 
    
    while True:
        count += 1
        random_x = np.random.randint(1,101)
        if x == random_x:
            break 
    
    return count 
        
        

def test_two(test):
    
    np.random.seed(1)
    
    random_y = np.random.randint(1,101, size = 1000)
    
    lst_clean = []
    
    for i in random_y:
        
        lst_clean.append(test(i))
    
    result = np.mean(lst_clean)
    
    return result 
        
        
print(test_two(test))
